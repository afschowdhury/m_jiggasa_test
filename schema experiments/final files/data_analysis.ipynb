# %% [markdown]
# ## Importing data

# %% [markdown]
# ### From `json`

# %%
import pandas as pd
import json 


with open("data/data_v4.json","r") as f:
    data = json.load(f)


data
# Out:
# [{'context': ' ১৯৭০ সালের ১২ নভেম্বর পূর্ব-বাংলায় ভয়াবহ ঝড় এবং জলোচ্ছ্বাসে ১০ লাখ মানুষ মারা যায়। বঙ্গবন্ধু তার নির্বাচনি প্রচারণা স্থগিত করে ত্রাণ কাজে ঝাঁপিয়ে পড়েন।',
#   'qas': [{'qtns': ['পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?',
#      '১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?',
#      'কত মানুষ ১৯৭০ এ মারা যায় ?',
#      nan],
#     'exact_answer': '১০ লাখ মানুষ ',
#     'answer': '১৯৭০ এর ঝড়ে ১০ লাখ মানুষ মারা যায় এই বাংলায় ।',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '11-12-1970',
#     'year': 1970.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'জলোচ্ছ্বাস',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন কেন?',
#      '১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?',
#      ' ',
#      ' '],
#     'exact_answer': 'প্রাকৃতিক দুর্যোগ এর জন্য ',
#     'answer': 'বঙ্গবন্ধু তার নির্বাচনি প্রচারণা স্থগিত করেন প্রাকৃতিক দুর্যোগ এর জন্য  ',
#     'tags': [nan, 'ইতিহাস'],
#     'date': nan,
#     'year': 1970.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'জলোচ্ছ্বাস',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?', nan, nan, nan],
#     'exact_answer': 'প্রাকৃতিক দুর্যোগ এর জন্য ',
#     'answer': '১৯৭০ সালে পূর্ব-বাংলায় ভয়াবহ ঝড় এবং জলোচ্ছ্বাসে ১০ লাখ মানুষ মারা যায়।',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '11-12-1970',
#     'year': 1970.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'জলোচ্ছ্বাস',
#     'mujib_relavant': 'NO'}]},
#  {'context': "১৯৫৩ সালের নভেম্বর মাসে তৎকালীন প্রধান বিরোধী দল 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ' এর অধিবেশনে দলের সাধারণ সম্পাদক নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান। ৫ ডিসেম্বর আওয়ামী লীগের নেতৃত্বে অন্যান্য বিরোধী দলকে সঙ্গে নিয়ে গঠিত হয় যুক্তফ্রন্ট। দেশজুড়ে প্রচারণা শুরু করেন বঙ্গবন্ধু।",
#   'qas': [{'qtns': [" কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান ?",
#      " বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন  ?",
#      " বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন কত সালে  ?",
#      nan],
#     'exact_answer': '১৯৫৩ সালের নভেম্বর মাসে',
#     'answer': "পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ' এর অধিবেশনে দলের সাধারণ সম্পাদক নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান ১৯৫৩ সালে ",
#     'tags': [nan, 'পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ যোগদান'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#      'পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৩ সাালে',
#     'answer': 'বঙ্গবন্ধু শেখ মুজিবুর রহমান দেশজুড়ে যুক্তফ্রন্টের গঠনের প্রচারণা শুরু করেন বঙ্গবন্ধু',
#     'tags': [nan, 'রাজনীতিতে অণুপ্রবেশ'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['১৯৫৩ সালে বঙ্গবন্ধু কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#      'শেখ মজীব  কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#      nan,
#      nan],
#     'exact_answer': 'পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ।',
#     'answer': "১৯৫৩ সালে নভেম্বর মাসে  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ' এর অধিবেশনে দলের সাধারণ সম্পাদক নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান",
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['১৯৫৩ সালের কোন মাসে পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#      '১৯৫৩ সালের কখন পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#      ' মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় কখন  ?',
#      nan],
#     'exact_answer': ' নভেম্বর মাসে',
#     'answer': "১৯৫৩ সালে নভেম্বর মাসে  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ' এর অধিবেশনে হয় ",
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['তৎকালীন পধান বিরোধী দল কোনটি ছিলো?',
#      '১৯৫৩ সালের  কোনটি বিরোধী দল ছিল ?',
#      nan,
#      nan],
#     'exact_answer': 'পূর্ব পাকিস্তান আওয়ামী মুসলীম লীগ।',
#     'answer': '১৯৫৩ সালে আওয়ামী মুসলিম লীগ বিরোধী দল ছিল',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ দলের কোন পদে নির্বাচিত হন শেখ মুজিবুর রহমান?',
#      'শেখ মুজিবুর রহমান পূর্ব পাকিস্তান মুসলিম লীগ দলের কোন পদে নির্বাচিত হন ?',
#      ' মুসলিম লীগ দলের কোন পদে শেখ মজীব ছিলেন  ?',
#      nan],
#     'exact_answer': 'সাধারন সম্পাদক',
#     'answer': 'শেখ মুজিব ১৯৫৩ সালে আওয়ামী মুসলিম লীগ বিরোধী দলের সাদারন সম্পাদক ছিলেন',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ কোন ধরণের দল ছিলো?',
#      ' লীগ কোন ধরণের দল ছিলো?',
#      nan,
#      nan],
#     'exact_answer': 'বিরোধী দল।',
#     'answer': '১৯৫৩ সালে আওয়ামী মুসলিম লীগ বিরোধী দল ছিল',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': [' যুক্তফ্রন্ট গঠিত হয় কত সালে?',
#      ' কত সালে যুক্তফ্রন্ট গঠিত হয় ?',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৩ সালে',
#     'answer': '১৯৫৩ সালে  ৫ ডিসেম্বর আওয়ামী লীগের নেতৃত্বে অন্যান্য বিরোধী দলকে সঙ্গে নিয়ে গঠিত হয় যুক্তফ্রন্ট',
#     'tags': [nan, 'ইতিহাস'],
#     'date': nan,
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['১৯৫৩ সালের কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#      ' কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#      'যুক্তফ্রন্টগঠিত হয় কত তারিখ ?',
#      nan],
#     'exact_answer': 'ডিসেম্বর মাসের ৫ তারিখ',
#     'answer': '১৯৫৩ সালে  ৫ ডিসেম্বর আওয়ামী লীগের নেতৃত্বে অন্যান্য বিরোধী দলকে সঙ্গে নিয়ে গঠিত হয় যুক্তফ্রন্ট',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '12-05-1953',
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কার নেতৃত্বে যুক্তফ্রন্ট গঠিত হয় ?',
#      ' যুক্তফ্রন্ট এর  নেতৃত্ব দেন কোন দল?',
#      'কোন রাজনীতিক দল যুক্তফ্রন্ট গঠন করে ',
#      nan],
#     'exact_answer': 'আওয়ামী লীগ',
#     'answer': '১৯৫৩ সালে  ৫ ডিসেম্বর আওয়ামী লীগের নেতৃত্বে অন্যান্য বিরোধী দলকে সঙ্গে নিয়ে গঠিত হয় যুক্তফ্রন্ট',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '12-05-1953',
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কাদের নিয়ে যুক্তফ্রন্ট গঠিত হয়?',
#      'কারা যুক্তফ্রন্ট গঠন করে?',
#      nan,
#      nan],
#     'exact_answer': 'অন্যান্য বিরোধী দলগুলো নিয়ে',
#     'answer': '১৯৫৩ সালে  ৫ ডিসেম্বর আওয়ামী লীগের নেতৃত্বে অন্যান্য বিরোধী দলকে সঙ্গে নিয়ে গঠিত হয় যুক্তফ্রন্ট',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '12-05-1953',
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': [' দেশজুড়ে যুক্তফ্রন্ট প্রচারনা শুরু করেন কে?',
#      ' কে যুক্তফ্রন্টের প্রচারনা শুরু করে?',
#      ' যুক্তফ্রন্টের গঠনের প্রচারনা শুরু করে কে?',
#      nan],
#     'exact_answer': 'বঙ্গবন্ধু শেখ মুজিবুর রহমান ',
#     'answer': 'বঙ্গবন্ধু শেখ মুজিবুর রহমান দেশজুড়ে যুক্তফ্রন্টের গঠনের প্রচারণা শুরু করেন বঙ্গবন্ধু।',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '12-05-1953',
#     'year': 1953.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুক্তফ্রন্ট গঠন',
#     'mujib_relavant': 'YES'}]},
#  {'context': '১৯৫৪  সালের মার্চ মাসে প্রদেশিক পরিষদের সাধারণ নির্বাচনে ২৩৭টি মুসলিম আসনের মধ্যে তৎকালীন আওয়ামী মুসলিম লীগ নেতৃত্বাধীন যুক্তফ্রন্ট ২২৩টি আসনে বিজয়ী হয়। আওয়ামী লীগ বিজয়ী হয় ১৪৫টি আসনে। পাকিস্তান মুসলিম লীগের ধর্মব্যবসায়ীদের প্রত্যাখান করে বাংলার জনগণ। মাত্র ৯টি আসন পেয়ে ধুয়ে মুছে সাফ হয়ে যায় মুসলিম লীগ। বঙ্গবন্ধু মুসলিম লীগের প্রভাবশালী এক নেতাকে ১৩ হাজার ভোটের বিশাল ব্যবধানে পরাজিত করেন। দেশজুড়ে প্রচার-প্রচারণা, অক্লান্ত শ্রম এবং তেজোদীপ্ত নেতৃত্বের কারণে আওয়ামী লীগের প্রধান মুখপাত্রে পরিণত হয় বঙ্গবন্ধু। জনগণের কাছে ন্যায্য অধিকার আদায় এবং শোষণের বিরুদ্ধে আন্দোলনের প্রাণপুরুষ হয়ে ওঠেন তিনি। শপথ নেন শেরে বাংলার নেতৃত্বাধীন যুক্তফ্রন্ট মন্ত্রিসভার কনিষ্ঠ মন্ত্রী হিসেবে। কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান তিনি। কিন্তু পাকিস্তানের কেন্দ্রীয় সরকার ষড়যন্ত্র করে এই মন্ত্রিসভাকে পদচ্যুত এবং গ্রেফতার করে শেখ মুজিবুর রহমানকে।  ',
#   'qas': [{'qtns': ['যুক্তফ্রন্ট নির্বাচন কতসালে হয় ?',
#      ' কতসালে যুক্তফ্রন্ট নির্বাচন হয় ?',
#      ' কতসালে  প্রদেশিক পরিষদের সাধারণ নির্বাচন হয় ?',
#      nan],
#     'exact_answer': ' ১৯৫৪ সালে',
#     'answer': '১৯৫৪  সালের মার্চ মাসে প্রদেশিক পরিষদের সাধারণ নির্বাচন(যুক্তফ্রন্ট) হয় ',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['২২৩টি আসনে বিজয় হয় কোন দল?',
#      '১৯৫৪ এর নির্বাচনে কোন দল বিজয়ী হয় ?',
#      'প্রদেশিক পরিষদের সাধারণ নির্বাচনে কোন দল বিজয়ী হয় ?',
#      nan],
#     'exact_answer': ' যুক্তফ্রন্ট',
#     'answer': '১৯৫৪  সালের মার্চ মাসে প্রদেশিক পরিষদের সাধারণ নির্বাচনে আওয়ামী লীগ জয় লাভ করে',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#      '১৯৫৪ এর নির্বাচনে আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#      'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#      'কয়টি আসনে আওয়ামী লীগ  বিজয়ী হয় ?'],
#     'exact_answer': '১৪৫টি আসনে',
#     'answer': '১৯৫৪  সালের মার্চ মাসে প্রদেশিক পরিষদের সাধারণ নির্বাচনে আওয়ামী লীগ ১৪৫ আসনে জয় লাভ করে',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['মুসলীম লীগ কয়টি আসন পায় ?',
#      'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  মুসলীম লীগ কয়টি আসন লাভ করে ?',
#      '১৯৫৪ এর নির্বাচনে মুসলীম লীগ কয়টি আসন পায় ?',
#      nan],
#     'exact_answer': ' ৯টি',
#     'answer': '১৯৫৪  সালের মার্চ মাসে প্রদেশিক পরিষদের সাধারণ নির্বাচনে  মুসলিম লীগ ৯ টি জয় লাভ করে',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['যুক্তফ্রন্টে কয়টি মুসলিম আসন ছিলো?',
#      ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  কয়টি মুসলিম আসন ছিল  ?',
#      nan,
#      nan],
#     'exact_answer': ' ২৩৭টি',
#     'answer': '১৯৫৪  সালের মার্চ মাসে প্রদেশিক পরিষদের সাধারণ নির্বাচনে মুসলিম আসন ছিল ২৩৭ টি করে',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['আওয়ামী লীগের প্রধান মুখপাত্র কে?',
#      'আওয়ামী লীগের প্রধান  কে ছিলেন?',
#      'কে আওয়ামী লীগের প্রধান মুখপাত্র ছিলেন?',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': '১৯৫৪ সালে নেতৃত্বের কারণে আওয়ামী লীগের প্রধান মুখপাত্রে পরিণত হয় বঙ্গবন্ধু',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['যুক্তফ্রন্ট মন্ত্রীসভার কনিষ্ঠ মন্ত্রী হিসেবে শপথ নেন কে?',
#      'যুক্তফ্রন্ট মন্ত্রীসভার কম বয়সী মন্ত্রী হিসেবে শপথ নেন কে?',
#      'যুক্তফ্রন্টে কে সব চেয়ে কম বয়সী মন্ত্রী ছিলেন?',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': 'নেতৃত্বের কারণে আওয়ামী লীগের প্রধান মুখপাত্রে পরিণত হওয়া বঙ্গবন্ধু সবচেয়ে কম বয়সী মন্ত্রি ছিলেন ',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['স্বাধীনতা আন্দোলনের প্রাণ পুরুষ কে?',
#      'স্বাধীনতা আন্দোলনের প্রাধান পুরুষ কে?',
#      'স্বাধীনতা আন্দোলনের ডাক দেন কে?',
#      nan],
#     'exact_answer': 'বঙ্গবন্ধু',
#     'answer': 'স্বাধীনতা আন্দোলনের ডাক দেন শেখ মুজিবুর রাহমান',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান কে?',
#      ' কাকে কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব দেওয়া হয়?',
#      'কৃষি, মন্ত্রণালয়ের দায়িত্ব কে পান?',
#      'বন মন্ত্রণালয়ের দায়িত্ব কে পান?'],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': 'কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান শেখ মুজিবুর রাহমান',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['মুসলীম লীগের প্রভাবশালী নেতাকে ১৩ হাজার ভোটেরব্যবধানে পরাজিত করে কে?',
#      'মুসলীম লীগের প্রভাবশালী নেতাকে  পরাজিত করে কে?',
#      ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে মুসলীম লীগের প্রভাবশালী নেতাকে বিপুল ভোটেরব্যবধানে পরাজিত করে কে?',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': 'যুক্তফ্রন্ট নির্বাচনে  বঙ্গবন্ধু মুসলিম লীগের প্রভাবশালী এক নেতাকে ১৩ হাজার ভোটের বিশাল ব্যবধানে পরাজিত করেন',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' মন্ত্রীসভাকে পদচ্যুত করে কাকে গ্রেফতার করা হয় ?',
#      ' মন্ত্রীসভাকে ভাঙার পরে  কাকে গ্রেফতার করা হয় ?',
#      nan,
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': 'পাকিস্তানের কেন্দ্রীয় সরকার ষড়যন্ত্র করে মন্ত্রিসভাকে পদচ্যুত এবং গ্রেফতার করে শেখ মুজিবুর রহমানকে।  ',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['যুক্তফ্রন্ট কার নেতৃত্বাধীন ছিল?',
#      'যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? ',
#      ' কার নেতৃত্বে যুক্তফ্রন্ট জয় লাভ করে ?',
#      ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? '],
#     'exact_answer': 'শেরে বাংলা এ কে ফজলুল হক',
#     'answer': ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল মুজিবুর রাহমান',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়ী হয় ?',
#      nan,
#      nan,
#      nan],
#     'exact_answer': ' যুক্তফ্রন্ট',
#     'answer': '১৯৫৪ সালে প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়ী হয় যুক্তফ্রন্ট',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['শেখ মুজিবুর রহমান কোন মন্ত্রণালয়ের দায়িত্ব ?',
#      ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়রে পরে শেখ মুজিব কোন মন্ত্রণালয়ের দায়িত্ব পান ?',
#      nan,
#      nan],
#     'exact_answer': 'কৃষি, বন ও সমবায় মন্ত্রণালয়ের ',
#     'answer': 'কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান শেখ মুজিবুর রাহমান',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['বঙ্গবন্ধু মুসলীম লীগের প্রভাবশালী নেতাকে কত হাজার ভোটেরব্যবধানে পরাজিত করেন?',
#      'শেখ মুজিব মুসলীম লীগের  নেতাকে কত  ভোটের ব্যবধানে পরাজিত করেন?',
#      nan,
#      nan],
#     'exact_answer': '১৩ হাজার ভোটে',
#     'answer': 'যুক্তফ্রন্ট নির্বাচনে  বঙ্গবন্ধু মুসলিম লীগের প্রভাবশালী এক নেতাকে ১৩ হাজার ভোটের বিশাল ব্যবধানে পরাজিত করেন',
#     'tags': ['যুক্তফ্রন্ট', 'রাজনীতি'],
#     'date': nan,
#     'year': 1954.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#     'mujib_relavant': 'YES'}]},
#  {'context': "১৯৫৫ সালে  পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন বঙ্গবন্ধু। পূর্ব বাংলার নাম পূর্ব পাকি।স্তান করার প্রতিবাদ করেন বঙ্গবন্ধু। ১৭ জুন পল্টন ময়দানের জনসভা থেকে পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন তিনি।২৫ আগস্ট করাচিতে পাকিস্তান গণপরিষদে বঙ্গবন্ধু বলেন, 'পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে…আর যদি পূর্ব পাকিস্তান নাম রাখতেই হয়, তা হলে বাংলার মানুষের জনমত যাচাই করতে হবে। তারা নামের এই পরিবর্তন মেনে নেবে কিনা-সে জন্য গণভোট নিতে হবে।'সর্বশ্রেণির মানুষকে নিয়ে অধিকার আন্দোলন বেগবান করার জন্য, একই বছর ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসেবে নেওয়া হয়। ফলে ২১ অক্টোবর সম্মেলনে, আওয়ামী মুসলিম লীগের কাউন্সিল অধিবেশনে দলের নাম থেকে মুসলিম শব্দটি বাদ দিয়ে 'আওয়ামী লীগ' নামকরণ করা হয় এবং আবারো দলের সাধারণ সম্পাদক নির্বাচিত হন শেখ মুজিব। ",
#   'qas': [{'qtns': ['বঙ্গবন্ধু কত সালে পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন ?',
#      'কবে শেখ মুজীব গণপরিষদের সদস্য হন ? ',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৫ সালে',
#     'answer': '১৯৫৫ সালে পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন বঙ্গবন্ধু',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '17/06/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['পূর্ব বাংলার নাম পূর্ব পাকিস্তান করার প্রতিবাদ করেন কে ?',
#      'এঈ দেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বাধা দেন ? ',
#      'বাংলাদেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বিরোধিতা করেন  ? ',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': 'পুর্ব বাংলার নাম পূর্ব পাকি।স্তান করার প্রতিবাদ করেন বঙ্গবন্ধু',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '17/06/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন  কে ?',
#      'কে পূর্ব পাকিস্তানে স্বায়ত্ত শাসন দাবী করেন ? ',
#      nan,
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': '১৭ জুন পল্টন ময়দানের জনসভা থেকে পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন শেখ মুজিবুর রাহমান',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '17/06/1955',
#     'year': 1955.0,
#     'location': [nan, 'পল্টন ময়দান'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কোথায় শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন ?',
#      'শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন কোন জায়গায় ?',
#      nan,
#      nan],
#     'exact_answer': 'পল্টনে জনসভার ময়দানে',
#     'answer': '১৭ জুন পল্টন ময়দানের জনসভা থেকে পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন শেখ মুজিবুর রাহমান',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '17/06/1955',
#     'year': 1955.0,
#     'location': [nan, 'পল্টন ময়দান'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- কথাটি কে বলেছেন ?',
#      '"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- উক্তিটি কার  ?',
#      ' কে বলেছেন ""পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"  ?',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': "২৫ আগস্ট করাচিতে পাকিস্তান গণপরিষদে বঙ্গবন্ধু বলেন, 'পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে…আর যদি পূর্ব পাকিস্তান নাম রাখতেই হয়, তা হলে বাংলার মানুষের জনমত যাচাই করতে হবে। তারা নামের এই পরিবর্তন মেনে নেবে কিনা-সে জন্য গণভোট নিতে হবে।'",
#     'tags': [nan, 'ইতিহাস'],
#     'date': '25/08/1955',
#     'year': 1955.0,
#     'location': [nan, 'করাচী '],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['ধর্মনিরপেক্ষতা কোন দলের মূলনীতি ?',
#      'কোন রাজনৈতিক দল তাদের মূলনীতি করেছিলো ধর্ম নীরপেক্ষতা ?',
#      nan,
#      nan],
#     'exact_answer': 'আওয়ামী মুসলিম লীগের',
#     'answer': "১৯৫৫ সালে 'সর্বশ্রেণির মানুষকে নিয়ে অধিকার আন্দোলন বেগবান করার জন্য, একই বছর ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসেবে নেওয়া হয়",
#     'tags': [nan, 'ইতিহাস'],
#     'date': '21/10/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কবে আওয়ামী লীগ ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#      'আওয়ামী লীগ কবে থেকে ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৫ সাাল থেকে',
#     'answer': "১৯৫৫ সালে 'সর্বশ্রেণির মানুষকে নিয়ে অধিকার আন্দোলন বেগবান করার জন্য, একই বছর ধর্মনিরপেক্ষতাকে আওয়ামী লীগ দলের মূলনীতি হিসেবে নেওয়া হয়",
#     'tags': [nan, 'ইতিহাস'],
#     'date': '21/10/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['আওয়ামী মুসলিম লীগ থেকে কবে দলের নাম মুসলিম লীগ করা হয় ? ',
#      'কবে থেকে আওয়ামী মুসলিম লীগ থেকে দলের নাম মুসলিম লীগ করা হয় ? ',
#      nan,
#      nan],
#     'exact_answer': '২১ অক্টোবর, ১৯৫৫ সাল ',
#     'answer': "২১ অক্টোবর সম্মেলনে, আওয়ামী মুসলিম লীগের কাউন্সিল অধিবেশনে দলের নাম থেকে মুসলিম শব্দটি বাদ দিয়ে 'আওয়ামী লীগ' নামকরণ করা হয়",
#     'tags': [nan, 'ইতিহাস'],
#     'date': '21/10/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['২য় বারের মতো শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#      ' ১ম বারের পরে  শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৫ সালেে',
#     'answer': '১৯৫৫ আলে ২য় বারের মোতো শেখ মুজীব কবে আবাএ আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন  ',
#     'tags': [nan, 'ইতিহাস'],
#     'date': '21/10/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['আওয়াামী লীগ থেকে কেনো মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#      'কী কারনে আওয়াামী লীগ থেকে  মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#      'কিসের জন্য আওয়াামী লীগ থেকে মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#      nan],
#     'exact_answer': 'ধর্মীয় নিরপেক্ষতার জন্য',
#     'answer': "ধর্মীয় নিরপেক্ষতার জন্য ২১ অক্টোবর সম্মেলনে, আওয়ামী মুসলিম লীগের কাউন্সিল অধিবেশনে দলের নাম থেকে মুসলিম শব্দটি বাদ দিয়ে 'আওয়ামী লীগ' নামকরণ করা হয়",
#     'tags': [nan, 'ইতিহাস'],
#     'date': '21/10/1955',
#     'year': 1955.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ নামকরণ',
#     'mujib_relavant': 'NO'}]},
#  {'context': '১৯৫৬ সালে পূর্ব পাকিস্তানে আওয়ামী লীগের নেতৃত্বে এক প্রাদেশিক সরকার গঠিত হয় এবং আবারো শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন বঙ্গবন্ধু। মুক্তিসংগ্রামের জন্য সারা দেশের জনগণকে প্রস্তুত করতে এবং আওয়ামী লীগকে শক্তিশালী করে গড়ে তোলার লক্ষ্যে, ১৯৫৭ সালে মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন তিনি। এরপর আওয়ামী লীগের কর্মী সংগ্রহ এবং পাকিস্তান সরকারের শোষণ ও বৈষম্যমূলক আচরণ সম্পর্কে দেশবাসীকে সচেতন করতে দেশের প্রতিটি প্রান্তে চষে বেড়াতে থাকেন তিনি। ',
#   'qas': [{'qtns': ['কত সালে প্রাদেশিক সরকার গঠীত হয় ?',
#      ' প্রাদেশিক সরকার কত সালে গঠীত হয় ?',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৬ সালে',
#     'answer': '১৯৫৬ সালে পূর্ব পাকিস্তানে আওয়ামী লীগের নেতৃত্বে  প্রাদেশিক সরকার গঠিত হয়',
#     'tags': ['ইতিহাস', 'রাজনীতি'],
#     'date': nan,
#     'year': 1956.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'প্রাদেশিক সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কোন দল প্রাদেশিক সরকার গঠন করে ?',
#      'কারা প্রাদেশিক সরকার গঠন করে ?',
#      'প্রাদেশিক সরকার কোন রাজনৈতিক দল গঠন করে ?',
#      nan],
#     'exact_answer': 'আওয়ামী লীগ',
#     'answer': '১৯৫৬ সালে পূর্ব পাকিস্তানে আওয়ামী লীগের নেতৃত্বে এক প্রাদেশিক সরকার গঠিত হয়',
#     'tags': ['ইতিহাস', 'রাজনীতি'],
#     'date': nan,
#     'year': 1956.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'প্রাদেশিক সরকার গঠন',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['প্রাদেশিক সরকার গঠনের পরে বঙ্গবন্ধু কোন মন্ত্রী হন ?',
#      'শেখ মুজিবুর রহমান প্রাদেশিক সরকার গঠনের পরে কোন মন্ত্রী হন ?',
#      'শেখ মুজিবুর রহমান কোন দফতরের মন্ত্রী হন প্রাদেশিক সরকার গঠনের পরে ?',
#      nan],
#     'exact_answer': 'শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রি',
#     'answer': '১৯৫৬ সালে প্রাদেশিক শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন বঙ্গবন্ধু',
#     'tags': ['ইতিহাস', 'রাজনীতি'],
#     'date': nan,
#     'year': 1956.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'প্রাদেশিক সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['১৯৫৬ সালে শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#      'প্রাদেশিক সরকার গঠনের পরে  শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#      '১৯৫৬ সালে শিল্প ও বাণিজ্য, শ্রম  দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#      '১৯৫৬ সালে  দুর্নীতি দমন বিষয়ক মন্ত্রী হন  কে?'],
#     'exact_answer': 'বঙ্গবন্ধু',
#     'answer': 'শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন বঙ্গবন্ধু',
#     'tags': ['ইতিহাস', 'রাজনীতি'],
#     'date': nan,
#     'year': 1956.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'প্রাদেশিক সরকার গঠন',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#      ' প্রাদেশিক সরকার গঠনের পরে কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৭ সালে',
#     'answer': '১৯৫৭ সালে মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন শেখ মুজিবুর রাহমান',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1956.0,
#     'location': [nan, 'পূর্ব বাংলা'],
#     'people': [nan, nan, nan],
#     'event': 'মন্ত্রীসভা ত্যাগ',
#     'mujib_relavant': 'YES'}]},
#  {'context': '১৯৫৮ সালে পাকিস্তানে সামরিক শাসন জারি, রাজনীতি নিষিদ্ধ এবং বঙ্গবন্ধুকে আবারো গ্রেফতার করা হয়। জেলের ভয়ে এসময় জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন। কিন্তু রাজনীতি না ছাড়ায় ১৯৬৩ সাল পর্যন্ত বারবার মিথ্যা মামলায় জেল খাটতে হয় বঙ্গবন্ধুকে। \n',
#   'qas': [{'qtns': ['কত সালে পাকিস্তানে সামরিক শাসন জারি করা হয় ?',
#      'পূর্ব পাকিস্তানে সামরিক শাসন কবে জারি হয় ?',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৮ সালে',
#     'answer': '১৯৫৮ সালে পাকিস্তানে সামরিক শাসন জারি, রাজনীতি নিষিদ্ধ করা হয়',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1958.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'সামরিক শাসন জারি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কত সালে পাকিস্তানে রাজনীতি নিষিদ্ধ করা হয়?',
#      ' পাকিস্তানে কত সালে রাজনীতি নিষিদ্ধ করা হয়?',
#      nan,
#      nan],
#     'exact_answer': '১৯৫৮ সালে',
#     'answer': '১৯৫৮ সালে পাকিস্তানে সামরিক শাসন জারি, রাজনীতি নিষিদ্ধ করা হয়',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1958.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'সামরিক শাসন জারি',
#     'mujib_relavant': 'NO'},
#    {'qtns': [' মিথ্যা মামলায় জেল খাটতে হয় কাকে?',
#      ' কে মিথ্যা মামলায় জেল খাটে ?',
#      '১৯৬৩ সালে ভূয়া মামলায় জেল খাটে কে ?',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': 'রাজনীতি না ছাড়ায় ১৯৬৩ সাল পর্যন্ত বারবার মিথ্যা মামলায় জেল খাটতে হয় বঙ্গবন্ধুকে।',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1958.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'সামরিক শাসন জারি',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কত সাল পর্যন্ত  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#      'কখন  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#      'কোন সালে  শেখ মুজিবুর রহমানকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#      nan],
#     'exact_answer': '১৯৬৩ সাল',
#     'answer': 'রাজনীতি না ছাড়ায় ১৯৬৩ সাল পর্যন্ত বারবার মিথ্যা মামলায় জেল খাটতে হয় বঙ্গবন্ধুকে।',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1963.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'সামরিক শাসন জারি',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কত সালে জেলের ভয়ে জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#      'কোন সময়ে  জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#      'কত সালে জেলের ভয়ে লিখিত দিয়ে  জ্যেষ্ঠ রাজনীতিবাদরা রাজনীতি ছেড়ে দেন ? ',
#      'সামরিক শাসন আসলে  সালে জেলের ভয়ে  রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন কত সালে  ? '],
#     'exact_answer': '১৯৫৮ সালে',
#     'answer': '১৯৫৮ সালে জেলের ভয়ে এসময় জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন',
#     'tags': [nan, 'রাজনীতি'],
#     'date': nan,
#     'year': 1958.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'সামরিক শাসন জারি',
#     'mujib_relavant': 'NO'}]},
#  {'context': '১৯৬৪ সালের ২৫ জানুয়ারি ধানমন্ডি ৩২ নম্বর সড়কের বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন কারামুক্ত নেতা শেখ মুজিবুর রহমান। সেই বৈঠকে আবারো আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন তিনি। প্রায় পাঁচ বছরের অচলাবস্থা কাটিয়ে তেজস্বী পুরুষ শেখ মুজিবের হাত ধরে আবারো রাজপথে নেমে আসে আওয়ামী লীগ। স্বৈরাচার আইয়ুববিরোধী আন্দোলন জোরদার হয়ে ওঠে শেখ মুজিবের সাহসী নেতৃত্বে। ফলে ১৯৬৫ সালে পাকিস্তানি জান্তারা আবারো জেলে নেয় তাকে। \n',
#   'qas': [{'qtns': ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয় কত সালে ?',
#      ' কত সালে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয়?',
#      'আওয়ামী লীগে নেতাদের বৈঠক ডাকা হয় কত কবে ?',
#      nan],
#     'exact_answer': '১৯৬৪ সালে, ২৫ জানুয়ারি',
#     'answer': '১৯৬৪ সালের ২৫ জানুয়ারি ধানমন্ডি ৩২ নম্বর সড়কের বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন কারামুক্ত নেতা শেখ মুজিবুর রহমান',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়ক'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা কবে দেয়া হয়?',
#      'কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেয়া হয়?',
#      'শেখ মুজিব কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দিয়েছিলেন ?',
#      nan],
#     'exact_answer': '১৯৬৪ সালে, ২৫ জানুয়ারি',
#     'answer': '১৯৬৪ সালে বৈঠকে আবারো আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন শেখ মুজিবুর রাহমান ',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে  কে?',
#      'কোন নেতা আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে ?',
#      'কোন রাজনৈতিক নেতা আওয়ামী লীগের বড় নেতাদের  বৈঠক ডাকে ?',
#      nan],
#     'exact_answer': 'বঙ্গবন্ধু',
#     'answer': '১৯৬৪ সালের ২৫ জানুয়ারি ধানমন্ডি ৩২ নম্বর সড়কের বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন কারামুক্ত নেতা শেখ মুজিবুর রহমান',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন কে?',
#      'কে ঘোষণা দিয়ে আওয়ামী লীগকে পুনর্জীবিত করেন ?',
#      'আওয়ামী লীগকে পুনর্জীবিত করার ঘোষক কে?',
#      'কার ঘোষণায় আওয়ামী লীগ ৫ বছর পর  পুনর্জীবিত হয় ?'],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': '১৯৬৪ সালে বৈঠকে আবারো আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['বঙ্গবন্ধু কোথায় আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন ?',
#      '১৯৬৪ সালে শেখ মুজিবুর এর সাথে কোথায় আওয়ামী নেতাদের বৈঠক হয় ?',
#      nan,
#      nan],
#     'exact_answer': 'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবনে।',
#     'answer': '১৯৬৪ সালের ২৫ জানুয়ারি ধানমন্ডি ৩২ নম্বর সড়কের বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন কারামুক্ত নেতা শেখ মুজিবুর রহমান',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়ক'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কার হাত ধরে আওয়ামী লীগ আবারো রাজপথে আসে ?',
#      'আওয়ামী লিগের অচল অবস্থা কাটিয়ে তুলে রাজ পথে ফিরিয়ে আনেন কে ?',
#      'কে অচল আওয়ামী লিগকে পুনরায় উজ্জীবিত করেন ?',
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রহমান',
#     'answer': '১৯৬৪ সালে প্রায় পাঁচ বছরের অচলাবস্থা কাটিয়ে তেজস্বী পুরুষ শেখ মুজিবের হাত ধরে আবারো রাজপথে নেমে আসে আওয়ামী লীগ',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' শেখ মুজিবুর রহমানের বাসভবন কোথায় ছিল ?',
#      'বঙ্গবন্ধুর বাসভবন কোথায় ?',
#      nan,
#      nan],
#     'exact_answer': 'ধানমন্ডি ৩২ নম্বর সড়ক',
#     'answer': '১৯৬৪ সালের ২৫ জানুয়ারি ধানমন্ডি ৩২ নম্বর সড়কে  নেতা শেখ মুজিবুর রহমানের বাসা ',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়ক'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['১৯৬৪ সালে কত বছর পরে আওয়ামী লীগ পুনরায় রাজ পথে নামে ?',
#      'অচল আওয়ামী লীগ কত বছর পর ১৯৬৪ সালে রাস্তায় নামে ?',
#      nan,
#      nan],
#     'exact_answer': '৫ বছর ',
#     'answer': '১৯৬৪ সালে প্রায় পাঁচ বছরের অচলাবস্থা কাটিয়ে তেজস্বী পুরুষ শেখ মুজিবের হাত ধরে আবারো রাজপথে নেমে আসে আওয়ামী লীগ',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['১৯৬৪ সালেে কার বিরুদ্ধে জোরদার আন্দোলন হয় ?',
#      ' কার বিরুদ্ধে ১৯৬৪ সালেে জোরদার আন্দোলন হয় ?',
#      nan,
#      nan],
#     'exact_answer': 'স্বৈরাচার আইয়ুবের ',
#     'answer': '১৯৬৪ সালে স্বৈরাচার আইয়ুববিরোধী আন্দোলন জোরদার হয়ে ওঠে শেখ মুজিবের সাহসী নেতৃত্বে',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['স্বৈরাচার আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#      '১৯৬৪ সালে  আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#      ' আইয়ুববিরোধী আন্দোলনের  নেতা কে ছিলেন ?',
#      nan],
#     'exact_answer': 'বঙ্গবন্ধু  শেখ মুজিবুর রহমান',
#     'answer': '১৯৬৪ সালে স্বৈরাচার আইয়ুববিরোধী আন্দোলন জোরদার হয়ে ওঠে শেখ মুজিবের সাহসী নেতৃত্বে',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['স্বৈরাচার আইয়ুববিরোধী আন্দোলন হয় কত সালে ?',
#      'কবে আইয়ুববিরোধী আন্দোলন হয়  ?',
#      ' আইয়ুববিরোধী আন্দোলনের সময় কাল কত  সালে ?',
#      nan],
#     'exact_answer': '১৯৬৪ সালে',
#     'answer': '১৯৬৪ সালে স্বৈরাচার আইয়ুববিরোধী আন্দোলন জোরদার হয়ে ওঠে শেখ মুজিবের সাহসী নেতৃত্বে',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['১৯৬৪ সালের কত তারিখে  ধানমন্ডির  বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন বঙ্গবন্ধু ?',
#      'নিজ  বাসভবনে আওয়ামী লীগের  নেতাদের নিয়ে কবে  বৈঠক ডাকেন বঙ্গবন্ধু ?',
#      nan,
#      nan],
#     'exact_answer': '১৯৬৪ সালের ২৫ জানুয়ারি ',
#     'answer': '১৯৬৪ সালের ২৫ জানুয়ারি ধানমন্ডি ৩২ নম্বর সড়কের বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন কারামুক্ত নেতা শেখ মুজিবুর রহমান',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '25/01/1964',
#     'year': 1964.0,
#     'location': [nan, 'ধানমন্ডি ৩২ নম্বর সড়ক'],
#     'people': [nan, nan, nan],
#     'event': 'আওয়ামী লীগ এর পুনরুত্থান',
#     'mujib_relavant': 'YES'}]},
#  {'context': "১৯৬৬সালের ৫ ফেব্রুয়ারি লাহোরে আয়োজিত বিরোধী দলগুলোর এক সম্মেলনে স্বায়ত্তশাসনের দাবিতে 'আমাদের বাঁচার দাবি' শিরোনামে 'ছয় দফা' পেশ করেন তিনি। এই দাবির সমর্থনে গণজোয়ার সৃষ্টি হয় বাংলার মাটিতে। এই তীব্র গণজোয়ারের মধ্যেই, ১ মার্চ উপমহাদেশের বৃহত্তর রাজনৈতিক দল আওয়ামী লীগের সভাপতি নির্বাচিত হন শেখ মুজিব। ছয় দফার প্রচারে তিন মাসে ৩২টি জনসভা করার পর, ৮ মে চূড়ান্তভাবে গ্রেফতার করা হয় তাকে। \n",
#   'qas': [{'qtns': ['১৯৬৬ সালে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#      ' বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#      ' বিরোধী দলগুলো কোথায় ১৯৬৬ সালে  সম্মেলন করেছিল  ?',
#      nan],
#     'exact_answer': 'পাকিস্তানের লাহোরে',
#     'answer': '১৯৬৬সালের ৫ ফেব্রুয়ারি লাহোরে আয়োজিত বিরোধী দলগুলোর এক সম্মেলনে  হয় ',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '02-05-1966',
#     'year': 1966.0,
#     'location': [nan, 'পাকিস্তানের লাহোর'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কত সালে লাহোরে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#      ' বিরোধী দলগুলোর সম্মেলন কত সালে  হয়েছিলো ?',
#      'লাহোরে কত সালে  বিরোধী দলগুলোর সম্মেলন  হয়েছিলো ?',
#      nan],
#     'exact_answer': '১৯৬৬ সালের ৫ ফেব্রুয়ারী ',
#     'answer': "১৯৬৬সালের ৫ ফেব্রুয়ারি লাহোরে আয়োজিত বিরোধী দলগুলোর এক সম্মেলনে স্বায়ত্তশাসনের দাবিতে 'আমাদের বাঁচার দাবি' শিরোনামে 'ছয় দফা' পেশ করেন",
#     'tags': [nan, 'রাজনীতি'],
#     'date': '02-05-1966',
#     'year': 1966.0,
#     'location': [nan, 'পাকিস্তানের লাহোর'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['ছয় দফা আন্দোলনের শিরোনাম কী ছিল ? ',
#      'ছয় দফা আন্দোলনের আরেক নাম কী ছিল ? ',
#      'ছয় দফা আন্দোলনের মুল কথা  কী ছিল ? ',
#      'ছয় দফা আন্দোলনকে কী নামে ডাকা হয়  ? '],
#     'exact_answer': "আমাদের বাঁচার দাবি'",
#     'answer': "১৯৬৬সালের ৫ ফেব্রুয়ারি লাহোরে আয়োজিত বিরোধী দলগুলোর এক সম্মেলনে স্বায়ত্তশাসনের দাবিতে 'আমাদের বাঁচার দাবি' শিরোনামে 'ছয় দফা' পেশ করেন",
#     'tags': [nan, 'রাজনীতি'],
#     'date': '02-05-1966',
#     'year': 1966.0,
#     'location': [nan, 'পাকিস্তানের লাহোর'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কোন আন্দোলন কে আমাদের বাঁচার দাবি বলা হয় ?',
#      ' আমাদের বাঁচার দাবি বলা হয় কোন আন্দোলনকে ?',
#      'লাাহোরে কোন আন্দোলন শুরু হয় ?',
#      nan],
#     'exact_answer': 'ছয় দফা আন্দোলন',
#     'answer': "১৯৬৬সালের ৫ ফেব্রুয়ারি লাহোরে স্বায়ত্তশাসনের দাবিতে 'আমাদের বাঁচার দাবি' শিরোনামে 'ছয় দফা'  পেশ করা হয়",
#     'tags': [nan, 'রাজনীতি'],
#     'date': '02-05-1966',
#     'year': 1966.0,
#     'location': [nan, 'পাকিস্তানের লাহোর'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['ছয় দফা দাবি পেশ করেন কে ? ',
#      'ছয় দফা আন্দোলনের সুত্রপাত কে ঘটান  ? ',
#      'ছয় দফা দাবির নেতৃত্ব করেন কে ? ',
#      nan],
#     'exact_answer': 'বঙ্গবন্ধু  শেখ মুজিবুর রহমান',
#     'answer': 'ছয় দফার নেতৃত্ব দেন শেখ মুজিবুর রাহমান',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '02-05-1966',
#     'year': 1966.0,
#     'location': [nan, 'পাকিস্তানের লাহোর'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' শেখ মুজিবুর রহমান কবে আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#      '  কবে বঙ্গবন্ধু শেখ মুজিবুর রহমান আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#      ' কবে আওয়ামী লীগের সভাপতি হিসেবে দায়িত্ব পান  শেখ মুজিবুর রহমান ?',
#      nan],
#     'exact_answer': '১ লা মার্চ, ১৯৬৬ সালে',
#     'answer': '১৯৬৬ সালে ১ মার্চ উপমহাদেশের বৃহত্তর রাজনৈতিক দল আওয়ামী লীগের সভাপতি নির্বাচিত হন শেখ মুজিব',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '03-01-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['ছয় দফা দাবি আদায়ে ৩ মাসে কতটি জনসভা করা হয় ১৯৬৬ সালে ?',
#      'ছয় দফা দাবি আদায়ে আওয়ামী লীগ কতটি জনসভা করে  ১৯৬৬ সালে ?',
#      nan,
#      nan],
#     'exact_answer': '৩২ টি জনসভা ',
#     'answer': 'ছয় দফার প্রচারে তিন মাসে ৩২টি জনসভা করা হয়',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '03-01-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['ছয় দফা দাবি চলাকালীন কত তারিখ বঙ্গবন্ধু চূড়ান্তভাবে গ্রেফতার হয়?',
#      'ছয় দফা দাবি চলাকালীন কবে শেখ মুজিবকে গ্রেফতার হয়?',
#      nan,
#      nan],
#     'exact_answer': '৮ মে, ১৯৬৬ সালে ',
#     'answer': '১৯৬৬ সালে  ৮ মে চূড়ান্তভাবে গ্রেফতার করা হয় শেখ মুজিবুর রাহমানকে',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '03-08-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'}]},
#  {'context': '১৯৬৬ সালের ৭ জুন ছয় দফার সমর্থনে এবং শেখ মুজিবের মুক্তির দাবিতে রাজপথে ছাত্রদের পাশাপাশি শ্রমিকরাও দুর্বার আন্দোলন গড়ে তোলে। শেখ মুজিব, ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত হয় এসময়। ৭ জুনের হরতাল সম্পর্কে বঙ্গবন্ধু শেখ মুজিবুর রহমান নিজের ডায়েরি কারাগারের রোজনামচাতে লিখেছেন, ‘১২টার পরে খবর পাকাপাকি পাওয়া গেল যে, হরতাল হয়েছে। জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে। তারা ছয় দফা সমর্থন করে আর মুক্তি চায়। বাঁচতে চায়, খেতে চায়, ব্যক্তিস্বাধীনতা চায়, শ্রমিকের ন্যায্য দাবি, কৃষকদের বাঁচার দাবি তারা চায়, এর প্রমাণ এই হরতালের মধ্যে হয়েই গেল।’',
#   'qas': [{'qtns': ['৬ দফার সমর্থনে ১৯৬৬ এঁর কত তারিখ ছাত্ররা রাস্তায় নামে ?',
#      'ছাত্ররা কবে ৬ দফা আদায় এ রাস্তায় নামে ?',
#      '৬ দফার সমরথনে কবে জনগন রাস্তায় নামে ?',
#      nan],
#     'exact_answer': '১৯৬৬ সালের ৬ জুন',
#     'answer': '১৯৬৬ সালের ৭ জুন ছয় দফার সমর্থনে এবং শেখ মুজিবের মুক্তির দাবিতে রাজপথে ছাত্রদের পাশাপাশি শ্রমিকরাও দুর্বার আন্দোলন গড়ে তোলে',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '06-06-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['কে ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত করেন ? ',
#      'ব্যাঙালির অধিকার ও ৬ দফা এক সত্তায় পরিনত করেন কে ?',
#      nan,
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রাহমান',
#     'answer': 'শেখ মুজিব  ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত হয় ',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '06-06-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' ‘১২টার পরে খবর পাকাপাকি পাওয়া গেল যে, হরতাল হয়েছে। জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে। তারা ছয় দফা সমর্থন করে আর মুক্তি চায়। বাঁচতে চায়, খেতে চায়, ব্যক্তিস্বাধীনতা চায়, শ্রমিকের ন্যায্য দাবি, কৃষকদের বাঁচার দাবি তারা চায়, এর প্রমাণ এই হরতালের মধ্যে হয়েই গেল।’ এইটা কত তারিখ সম্বন্ধে বলা হয়েছে ? ',
#      '১৯৬৬ সালের কতও তারিখ জনগন হরতাল পালন করে ? ',
#      nan,
#      nan],
#     'exact_answer': '১৯৬৬ সাালের ৭ জুন',
#     'answer': 'জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে ১৯৬৬ সালের ৭ জুন',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '06-07-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['১৯৬৬ সালের কয় তারিখ হরতাল পালন করা হয় ?',
#      'কবে হারতাল পালন করা হয় ?',
#      '৬ দফার দাবিতে কবে হারতাল পালন করা হয় ?',
#      nan],
#     'exact_answer': '৭ জুন ১৯৬৬ সালে ',
#     'answer': 'ছয় দফার দাবি তে জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে ১৯৬৬ সালের ৭ জুন',
#     'tags': [nan, 'রাজনীতি'],
#     'date': '06-07-1966',
#     'year': 1966.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'ছয় দফা দাবি',
#     'mujib_relavant': 'NO'}]},
#  {'context': '\n ১৯৬৮ সালের ৩ জানুয়ারি জেলে থাকা অবস্থায় পাকিস্তান সরকার বঙ্গবন্ধুকে এক নম্বর আসামি করে তার নামে একটি রাষ্ট্রদ্রোহী মামলা দায়ের করে। এই মামলা ইতিহাসে আগরতলা ষড়যন্ত্র মামলা নামে পরিচিত। কিন্তু শেখ মুজিবকে মুক্ত করার জন্য আপামর ছাত্র-শ্রমিক-কৃষক-জনতা একসাথে রাজপথে নেমে আসে। ৬ দফার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা। শুরু হয় ইতিহাসের সর্ববৃহৎ গণআন্দোলন।',
#   'qas': [{'qtns': ['আগরতলা মামলার প্রধান আসামি কে ?',
#      'আগড়তলা ষড়যন্ত্র মামলার প্রধান আসামি কে ?',
#      nan,
#      nan],
#     'exact_answer': 'শেখ মুজিবুর রাহমান',
#     'answer': '\n ১৯৬৮ সালের ৩ জানুয়ারি জেলে থাকা পাকিস্তান সরকার বঙ্গবন্ধুকে এক নম্বর আসামি করে  একটি রাষ্ট্রদ্রোহী মামলা দায়ের করে',
#     'tags': ['রাজনীতি', 'ইতিহাস'],
#     'date': '01-03-1968',
#     'year': 1968.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আগরতলা ষড়যন্ত্র মামলা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['আগরতলা মামলা কত সালে দায়ের করা হয় ?',
#      'কবে আগরতলা ষড়যন্ত্র মামলা দেওয়া হয় ?',
#      'আগরতলাা মামলা কত সালের কত তারিখ দায়ের করা হয় ?',
#      'আগরতলা মামলা দায়ের করার তারিখ কত ?'],
#     'exact_answer': '১৯৬৮ সালের ৩ রা জানুয়ারী',
#     'answer': '\n ১৯৬৮ সালের ৩ জানুয়ারি জেলে থাকা পাকিস্তান সরকার বঙ্গবন্ধুকে এক নম্বর আসামি করে  একটি রাষ্ট্রদ্রোহী মামলা দায়ের করে',
#     'tags': ['রাজনীতি', 'ইতিহাস'],
#     'date': '01-03-1968',
#     'year': 1968.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আগরতলা ষড়যন্ত্র মামলা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['আগরতলা মামলার সময় শেখ মুজিব কোথায় ছিলেন?',
#      'শেখ মুজিব কোথায় ছিলেন যখন ষড়যন্ত্র মামলা দায়ের করা হয় ?',
#      nan,
#      nan],
#     'exact_answer': 'কারাগার',
#     'answer': '\n ১৯৬৮ সালের ৩ জানুয়ারি জেলে থাকা পাকিস্তান সরকার বঙ্গবন্ধুকে এক নম্বর আসামি করে  একটি রাষ্ট্রদ্রোহী মামলা দায়ের করে',
#     'tags': ['রাজনীতি', 'ইতিহাস'],
#     'date': '01-03-1968',
#     'year': 1968.0,
#     'location': [nan, 'পাকিস্তানের কারাগার'],
#     'people': [nan, nan, nan],
#     'event': 'আগরতলা ষড়যন্ত্র মামলা',
#     'mujib_relavant': 'YES'},
#    {'qtns': [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#      'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#      nan,
#      nan],
#     'exact_answer': '১১ দফা দাবি আদায়',
#     'answer': '৬ দফার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা। শুরু হয় ইতিহাসের সর্ববৃহৎ গণআন্দোলন।',
#     'tags': ['রাজনীতি', 'ইতিহাস'],
#     'date': '01-03-1968',
#     'year': 1968.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আগরতলা ষড়যন্ত্র মামলা',
#     'mujib_relavant': 'NO'},
#    {'qtns': [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কত সালে হয় ?',
#      'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কবে হয় ?',
#      nan,
#      nan],
#     'exact_answer': '১৯৬৮ সালের ৩ রা জানুয়ারী',
#     'answer': '১৯৬৮ সালের ৩ রা জুন ৬ দফার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা। শুরু হয় ইতিহাসের সর্ববৃহৎ গণআন্দোলন।',
#     'tags': ['রাজনীতি', 'ইতিহাস'],
#     'date': '01-03-1968',
#     'year': 1968.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আগরতলা ষড়যন্ত্র মামলা',
#     'mujib_relavant': 'NO'},
#    {'qtns': ['৬ দফার সমর্থনে ছাত্ররা কত দফা দাবি জানায় ?',
#      '৬ দফা সফল করতে কত দফা দাবি জানানো হয় ?',
#      nan,
#      nan],
#     'exact_answer': '১১ দফাা',
#     'answer': '১৯৬৮ সালের ৩ রা জুন ৬ দফার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা। শুরু হয় ইতিহাসের সর্ববৃহৎ গণআন্দোলন।',
#     'tags': ['রাজনীতি', 'ইতিহাস'],
#     'date': '01-03-1968',
#     'year': 1968.0,
#     'location': [nan, 'পূর্ব পাকিস্তান'],
#     'people': [nan, nan, nan],
#     'event': 'আগরতলা ষড়যন্ত্র মামলা',
#     'mujib_relavant': 'NO'},
# ...
#      nan],
#     'exact_answer': '২৯তম',
#     'answer': '১৯৭৪ সালের ২৫ সেপ্টেম্বর প্রথম বাঙালি নেতা হিসেবে জাতিসংঘের ২৯তম সাধারণ পরিষদে বাংলায় বক্তৃতা দেন বঙ্গবন্ধু শেখ মুজিবুর রহমান।',
#     'tags': [nan, 'ইতিহাস'],
#     'date': nan,
#     'year': 1974.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'জাতিসংঘে ভাষণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['জাতিসংঘের কোন পরিষদে বাংলায় বক্তৃতা দেন বঙ্গবন্ধু শেখ মুজিবুর রহমান?',
#      'জাতিসংঘের কোন পরিষদে ভাষণ দেন বঙ্গবন্ধু শেখ মুজিবুর রহমান?',
#      nan,
#      nan],
#     'exact_answer': 'সাধারণ পরিষদে',
#     'answer': '১৯৭৪ সালের ২৫ সেপ্টেম্বর প্রথম বাঙালি নেতা হিসেবে জাতিসংঘের ২৯তম সাধারণ পরিষদে বাংলায় বক্তৃতা দেন বঙ্গবন্ধু শেখ মুজিবুর রহমান।',
#     'tags': [nan, 'ইতিহাস'],
#     'date': nan,
#     'year': 1974.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'জাতিসংঘে ভাষণ',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['জাতিসংঘের সাধারণ পরিষদে শেখ মুজিবুর রহমান কোন ভাষায় বক্তৃতা দেন?',
#      'জাতিসংঘে শেখ মুজিবুর রহমান কোন ভাষায় বক্তৃতা দেন?',
#      nan,
#      nan],
#     'exact_answer': 'বাংলায়',
#     'answer': '১৯৭৪ সালের ২৫ সেপ্টেম্বর প্রথম বাঙালি নেতা হিসেবে জাতিসংঘের ২৯তম সাধারণ পরিষদে বাংলায় বক্তৃতা দেন বঙ্গবন্ধু শেখ মুজিবুর রহমান।',
#     'tags': [nan, 'ইতিহাস'],
#     'date': nan,
#     'year': 1974.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'জাতিসংঘে ভাষণ',
#     'mujib_relavant': 'YES'}]},
#  {'context': "১৯৭২সালের ৪ নভেম্বর, স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান। একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতাকে মূলনীতি হিসেবে ঘোষণা করেন তিনি। গণপরিষদের ভাষণে বঙ্গবন্ধু বলেন, 'ধর্মনিরপেক্ষতা মানে ধর্মহীনতা নয়। মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না। আমাদের আপত্তি শুধু এই যে, ধর্মকে কেউ রাজনৈতিক অস্ত্র হিসেবে ব্যবহার করতে পারবে না। পঁচিশ বছর আমরা দেখেছি- ধর্মের নামে জুয়াচুরি, ধর্মের নামে শোষণ, ধর্মের নামে বেঈমানি, ধর্মের নামে অত্যাচার, এই বাংলাদেশের মাটিতে এসব চলেছে। ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না। সংবিধানে ধর্মনিরপেক্ষতার মাধ্যমে সাড়ে সাত কোটি মানুষের ধর্মীয় অধিকার রক্ষার করার ব্যবস্থা করা হয়েছে।'",
#   'qas': [{'qtns': ['স্বাধীনতা অর্জনের কয় বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান?',
#      'কয় বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু?',
#      'কত দিনের মধ্যে নতুন শাসন বানান শেখ মুজিব?',
#      nan],
#     'exact_answer': 'এক বছর',
#     'answer': '১৯৭২সালের ৪ নভেম্বর, স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান। একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতাকে মূলনীতি হিসেবে ঘোষণা করেন তিনি।',
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': '11-04-1972',
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন কে ?',
#      'বাংলাদেশের জন্য নতুন শাসন ব্যবস্থা কে বানান?',
#      'দেশের জন্য নতুন শাসন কে বানান?',
#      'দেশের জন্য নতুন শাসন কে তৈরি করেন?'],
#     'exact_answer': 'বঙ্গবন্ধু শেখ মুজিবুর রহমান',
#     'answer': '১৯৭২সালের ৪ নভেম্বর, স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান। একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতাকে মূলনীতি হিসেবে ঘোষণা করেন তিনি।',
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['বঙ্গবন্ধু শেখ মুজিবুর রহমান একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য কি কি মূলনীতি ঘোষণা করেন?',
#      'রাষ্ট্র পরিচালনার জন্য শেখ মুজিব কি কি মূলনীতি ঘোষণা করেন?',
#      'বাংলাদেশের জন্য শেখ মুজিব কি কি মূলনীতি বানান ?',
#      'দেশের জন্য শেখ মুজিবের বানানো মূলনীতি গুলো কি কি?'],
#     'exact_answer': 'জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতা',
#     'answer': '১৯৭২সালের ৪ নভেম্বর, স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান। একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতাকে মূলনীতি হিসেবে ঘোষণা করেন তিনি।',
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['বঙ্গবন্ধু শেখ মুজিবুর রহমান একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য কয়টি মূলনীতি ঘোষণা করেন?',
#      'রাষ্ট্র পরিচালনার জন্য শেখ মুজিব কয়টি মূলনীতি ঘোষণা করেন?',
#      'রাষ্ট্রের জন্য শেখ মুজিব কয়টি মূলনীতি বানান ?',
#      nan],
#     'exact_answer': '৪টি',
#     'answer': '১৯৭২সালের ৪ নভেম্বর, স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান। একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য ৪ টি মূলনীতি তথা জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতাকে মূলনীতি হিসেবে ঘোষণা করেন তিনি।',
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কবে বঙ্গবন্ধু শেখ মুজিবুর রহমান নতুন শাসনতন্ত্র প্রণয়ন করেন ?',
#      'কত সালে বঙ্গবন্ধু নতুন শাসন ব্যবস্থা তৈরি করেন?',
#      'কবে শেখ মুজিব দেশের জন্য নতুন শাসন ব্যবস্থা বানান?',
#      nan],
#     'exact_answer': '১৯৭২ সালের ৪ নভেম্বর',
#     'answer': '১৯৭২সালের ৪ নভেম্বর, স্বাধীনতা অর্জনের এক বছরের মধ্যে নতুন শাসনতন্ত্র প্রণয়ন করেন বঙ্গবন্ধু শেখ মুজিবুর রহমান। একটি মানবিক সমাজ গঠনের উদ্দেশ্যে রাষ্ট্র পরিচালনার জন্য ৪ টি মূলনীতি তথা জাতীয়বাদ, সমাজতন্ত্র, গণতন্ত্র এবং ধর্মনিরেপক্ষতাকে মূলনীতি হিসেবে ঘোষণা করেন তিনি।',
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['"ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না। সংবিধানে ধর্মনিরপেক্ষতার মাধ্যমে সাড়ে সাত কোটি মানুষের ধর্মীয় অধিকার রক্ষার করার ব্যবস্থা করা হয়েছে।"--উক্তিটি কার?',
#      '"ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না।"-কে বলেছিলেন?',
#      '"পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না।"-ভাষণটি কার?',
#      'কে পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করতে নিষেধ করেছিলেন?'],
#     'exact_answer': 'বঙ্গবন্ধু শেখ মুজিবুর রহমান',
#     'answer': "১৯৭২ সালের ৪ নভেম্বর গণপরিষদের ভাষণে বঙ্গবন্ধু বলেন, 'ধর্মনিরপেক্ষতা মানে ধর্মহীনতা নয়। মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না। আমাদের আপত্তি শুধু এই যে, ধর্মকে কেউ রাজনৈতিক অস্ত্র হিসেবে ব্যবহার করতে পারবে না। পঁচিশ বছর আমরা দেখেছি- ধর্মের নামে জুয়াচুরি, ধর্মের নামে শোষণ, ধর্মের নামে বেঈমানি, ধর্মের নামে অত্যাচার, এই বাংলাদেশের মাটিতে এসব চলেছে। ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না। সংবিধানে ধর্মনিরপেক্ষতার মাধ্যমে সাড়ে সাত কোটি মানুষের ধর্মীয় অধিকার রক্ষার করার ব্যবস্থা করা হয়েছে।'",
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ["ধর্মনিরপেক্ষতা মানে ধর্মহীনতা নয়। মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না।'- গণপরিষদে ভাষণটি কে দিয়েছিলেন?",
#      "মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না।'- গণপরিষদে ভাষণটি কে দিয়েছিলেন?",
#      "মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে'-কথা গুলো কার?",
#      "মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে'-ভাষণ কার?"],
#     'exact_answer': 'বঙ্গবন্ধু শেখ মুজিবুর রহমান',
#     'answer': "১৯৭২ সালের ৪ নভেম্বর গণপরিষদের ভাষণে বঙ্গবন্ধু বলেন, 'ধর্মনিরপেক্ষতা মানে ধর্মহীনতা নয়। মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না। আমাদের আপত্তি শুধু এই যে, ধর্মকে কেউ রাজনৈতিক অস্ত্র হিসেবে ব্যবহার করতে পারবে না। পঁচিশ বছর আমরা দেখেছি- ধর্মের নামে জুয়াচুরি, ধর্মের নামে শোষণ, ধর্মের নামে বেঈমানি, ধর্মের নামে অত্যাচার, এই বাংলাদেশের মাটিতে এসব চলেছে। ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না। সংবিধানে ধর্মনিরপেক্ষতার মাধ্যমে সাড়ে সাত কোটি মানুষের ধর্মীয় অধিকার রক্ষার করার ব্যবস্থা করা হয়েছে।'",
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['ধর্মনিরপেক্ষতা নিয়ে গণপরিষদে দেওয়া বঙ্গবন্ধু শেখ মুজিবুর রহমান এর ভাষণটি কি ছিল?',
#      'ধর্মনিরপেক্ষতা বঙ্গবন্ধু শেখ মুজিবুর রহমান এর ভাষণটি কি ছিল?',
#      'ধর্মনিরপেক্ষতা নিয়ে বঙ্গবন্ধু শেখ মুজিবুর রহমান কি বলেছিলেন?',
#      'ধর্মনিরপেক্ষতা নিয়ে শেখ মুজিবুর রহমান কি কথা বলেছিলেন?'],
#     'exact_answer': "ধর্মনিরপেক্ষতা মানে ধর্মহীনতা নয়। মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না। আমাদের আপত্তি শুধু এই যে, ধর্মকে কেউ রাজনৈতিক অস্ত্র হিসেবে ব্যবহার করতে পারবে না। পঁচিশ বছর আমরা দেখেছি- ধর্মের নামে জুয়াচুরি, ধর্মের নামে শোষণ, ধর্মের নামে বেঈমানি, ধর্মের নামে অত্যাচার, এই বাংলাদেশের মাটিতে এসব চলেছে। ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না। সংবিধানে ধর্মনিরপেক্ষতার মাধ্যমে সাড়ে সাত কোটি মানুষের ধর্মীয় অধিকার রক্ষার করার ব্যবস্থা করা হয়েছে।'",
#     'answer': "১৯৭২ সালের ৪ নভেম্বর গণপরিষদের ভাষণে বঙ্গবন্ধু বলেন, 'ধর্মনিরপেক্ষতা মানে ধর্মহীনতা নয়। মুসলমানরা তাদের ধর্ম পালন করবে, হিন্দুরা তাদের ধর্ম পালন করবে, বৌদ্ধরা তাদের ধর্ম পালন করবে, খ্রিস্টানরা তাদের ধর্ম পালন করবে। কেউ বাধা দিতে পারবে না। আমাদের আপত্তি শুধু এই যে, ধর্মকে কেউ রাজনৈতিক অস্ত্র হিসেবে ব্যবহার করতে পারবে না। পঁচিশ বছর আমরা দেখেছি- ধর্মের নামে জুয়াচুরি, ধর্মের নামে শোষণ, ধর্মের নামে বেঈমানি, ধর্মের নামে অত্যাচার, এই বাংলাদেশের মাটিতে এসব চলেছে। ধর্ম অতি পবিত্র জিনিস। পবিত্র ধর্মকে রাজনৈতিক হাতিয়ার হিসেবে ব্যবহার করা চলবে না। সংবিধানে ধর্মনিরপেক্ষতার মাধ্যমে সাড়ে সাত কোটি মানুষের ধর্মীয় অধিকার রক্ষার করার ব্যবস্থা করা হয়েছে।'",
#     'tags': ['দেশ পরিচালনা', 'ইতিহাস'],
#     'date': nan,
#     'year': 1972.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'দেশ পরিচালনা',
#     'mujib_relavant': 'YES'}]},
#  {'context': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#   'qas': [{'qtns': ['কত সালে শেখ মুজিবুর রহমানের বিয়ে হয়?',
#      'বঙ্গবন্ধু কত সালে বিবাহ বন্ধনে আবদ্ধ হন?',
#      'কবে শেখ মুজিব বিয়ে করেন?',
#      nan],
#     'exact_answer': '১৯৩৮ সালে',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': ['ফজিলাতুন্নেসা', nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['বিয়ের সময় শেখ মুজিবুর রহমানের বয়স কত ছিলো?',
#      'বিয়ের সময় বঙ্গবন্ধুর বয়স কত ছিলো?',
#      'কয় বছর বয়সে শেখ মুজিব বিয়ে করেন?',
#      nan],
#     'exact_answer': 'আঠারো',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': ['ফজিলাতুন্নেসা', nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['কার সাথে শেখ মুজিবুর রহমানের বিয়ে হয়?',
#      'বঙ্গবন্ধু কার সাথে বিবাহ বন্ধনে আবদ্ধ হয়েছিলেন?',
#      'বঙ্গমাতার নাম কি?',
#      'শেখ মুজিব কাকে বিয়ে করেছিলেন?'],
#     'exact_answer': 'ফজিলাতুন্নেসা',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': ['ফজিলাতুন্নেসা', nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['শেখ মুজিবুর রহমানের কয় সন্তান ছিলো?',
#      'শেখ মুজিবের কতজন সন্তান ছিলো?',
#      'মুজিবের ছেলেমেয়ে কয়জন?',
#      nan],
#     'exact_answer': 'পাঁচ',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['শেখ মুজিবুর রহমানের কয় ছেলে ছিলো?',
#      'মুজিবের কতজন পুত্র সন্তান ছিলো?',
#      nan,
#      nan],
#     'exact_answer': 'তিন',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['শেখ মুজিবুর রহমানের কয় মেয়ে ছিলো?',
#      'মুজিবের কতজন কন্যা সন্তান ছিলো?',
#      nan,
#      nan],
#     'exact_answer': 'দুই',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['শেখ মুজিবুর রহমানের ছেলেমেয়ের নাম কি?',
#      'শেখ মুজিবের সন্তানদের নাম কি?',
#      'শেখ মুজিবের ছেলে মেয়ে কে কে?',
#      nan],
#     'exact_answer': 'দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': [nan, nan, nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['শেখ মুজিব রহমানের ছেলেদের নাম কি?',
#      'শেখ মুজিবের পুত্র সন্তানদের নাম কি?',
#      'শেখ মুজিবের পুত্র কে কে?',
#      nan],
#     'exact_answer': 'তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': ['শেখ কামাল', 'শেখ জামাল', 'শেখ রাসেল'],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'},
#    {'qtns': ['শেখ মুজিবুর রহমানের মেয়েদের নাম কি?',
#      'শেখ মুজিবের কন্যা সন্তানদের নাম কি?',
#      'শেখ মুজিবের কন্যা কে কে?',
#      nan],
#     'exact_answer': 'দুই কন্যা (শেখ হাসিনা, শেখ রেহানা)',
#     'answer': '১৯৩৮ সালে আঠার বছর বয়সে ফজিলাতুন্নেসার সাথে শেখ মুজিবু্র রহমানের বিয়ে হয়। এঁদের সন্তানরা হলেন দুই কন্যা (শেখ হাসিনা, শেখ রেহানা) ও তিন পুত্র (শেখ কামাল, শেখ জামাল ও শেখ রাসেল)।',
#     'tags': ['পরিচিতি তথ্য', 'ব্যাক্তিগত'],
#     'date': nan,
#     'year': 1938.0,
#     'location': [nan, nan],
#     'people': ['শেখ হাসিনা', 'শেখ রেহানা', nan],
#     'event': 'পরিবার',
#     'mujib_relavant': 'YES'}]}]

# %% [markdown]
# ### From `Excel Sheet`

# %%
df = pd.read_excel("data/final_data.xlsx")
df.columns
# Out:
# Index(['Unnamed: 0', 'Context No', 'Context', 'ContextQuesNo', 'Q1', 'Q2',
#        'Q3', 'Q4', 'Exact Answer', 'Answer', 'T1', 'T2', 'L1', 'L2', 'P1',
#        'P2', 'P3', 'Event', 'Date', 'Year', 'Mujib Relevant'],
#       dtype='object')

# %%
print(f"Length of the dataframe : {len(df)}") #including header
# Out:
# Length of the dataframe : 422

# %%
df.head()
# Out:
#    Unnamed: 0 Context No                                            Context  \
# 0           1          1   ১৯৭০ সালের ১২ নভেম্বর পূর্ব-বাংলায় ভয়াবহ ঝড...
# 1           2        NaN                                                NaN
# 2           3        NaN                                                NaN
# 3           4          2  ১৯৫৩ সালের নভেম্বর মাসে তৎকালীন প্রধান বিরোধী...
# 4           5        NaN                                                NaN
#
#    ContextQuesNo                                                 Q1  \
# 0            1.0       পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?
# 1            2.0  ১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন ...
# 2            3.0              কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?
# 3            1.0   কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এ...
# 4            2.0  পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন ক...
#
#                                                   Q2  \
# 0            ১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?
# 1  ১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?
# 2                                                NaN
# 3   বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পা...
# 4  পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অন...
#
#                                                   Q3   Q4  \
# 0                         কত মানুষ ১৯৭০ এ মারা যায় ?  NaN
# 1
# 2                                                NaN  NaN
# 3   বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লী...  NaN
# 4                                                NaN  NaN
#
#                  Exact Answer  \
# 0               ১০ লাখ মানুষ
# 1  প্রাকৃতিক দুর্যোগ এর জন্য
# 2  প্রাকৃতিক দুর্যোগ এর জন্য
# 3     ১৯৫৩ সালের নভেম্বর মাসে
# 4                  ১৯৫৩ সাালে
#
#                                               Answer  ...  \
# 0      ১৯৭০ এর ঝড়ে ১০ লাখ মানুষ মারা যায় এই বাংলায় ।  ...
# 1  বঙ্গবন্ধু তার নির্বাচনি প্রচারণা স্থগিত করেন প...  ...
# 2  ১৯৭০ সালে পূর্ব-বাংলায় ভয়াবহ ঝড় এবং জলোচ্ছ্...  ...
# 3  পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ' এর অধিবেশনে...  ...
# 4  বঙ্গবন্ধু শেখ মুজিবুর রহমান দেশজুড়ে যুক্তফ্রন্...  ...
#
#                                          T2   L1           L2   P1   P2   P3  \
# 0                                    ইতিহাস  NaN  পূর্ব বাংলা  NaN  NaN  NaN
# 1                                    ইতিহাস  NaN  পূর্ব বাংলা  NaN  NaN  NaN
# 2                                    ইতিহাস  NaN  পূর্ব বাংলা  NaN  NaN  NaN
# 3  পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ যোগদান  NaN  পূর্ব বাংলা  NaN  NaN  NaN
# 4                       রাজনীতিতে অণুপ্রবেশ  NaN  পূর্ব বাংলা  NaN  NaN  NaN
#
#              Event                 Date    Year  Mujib Relevant
# 0       জলোচ্ছ্বাস  1970-12-11 00:00:00  1970.0              NO
# 1       জলোচ্ছ্বাস                  NaN  1970.0             YES
# 2       জলোচ্ছ্বাস  1970-12-11 00:00:00  1970.0              NO
# 3  যুক্তফ্রন্ট গঠন                  NaN  1953.0             YES
# 4  যুক্তফ্রন্ট গঠন                  NaN  1953.0             YES
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Defining Plotting Function

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.style.available

plt.style.use(plt.style.available[4])

# %%
def plot_bar_plot(x,y,xlabel,ylabel,title,show_number=False,show_x=False,rotation='vertical',t_f_s = 20,figsize=(26,8)):
    
    
    
    fig , ax = plt.subplots(figsize=figsize)
    
    x = x
    y = y
    
    colors = plt.cm.Dark2(range(6))
    
    # prop = fm.FontProperties(fname='Nikosh.ttf')
    prop = fm.FontProperties(fname='data/fonts/Nikosh.ttf')


    bar_plot = ax.bar(x,y,color = colors)

    ax.set(xlabel= xlabel,
        ylabel = ylabel);
    
    if show_x:
        ax.set_xticks(ticks = x, fontproperties=prop,labels= x,rotation=rotation)#,fontproperties=font) 
    
    if show_number:
        ax.bar_label(bar_plot,padding=3)
    
    fig_name = "plots/"+title+".png"
        
    # fig.savefig(fig_name)
    fig.suptitle(t=title,
             size = t_f_s)
    fig.savefig(fig_name)

# %% [markdown]
# ## Question By Categories

# %%
ques_df = df[['Q1','Q2','Q3','Q4','Mujib Relevant']]
ques_df.head()
# Out:
#                                                   Q1  \
# 0       পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?
# 1  ১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন ...
# 2              কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?
# 3   কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এ...
# 4  পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন ক...
#
#                                                   Q2  \
# 0            ১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?
# 1  ১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?
# 2                                                NaN
# 3   বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পা...
# 4  পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অন...
#
#                                                   Q3   Q4 Mujib Relevant
# 0                         কত মানুষ ১৯৭০ এ মারা যায় ?  NaN             NO
# 1                                                                    YES
# 2                                                NaN  NaN             NO
# 3   বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লী...  NaN            YES
# 4                                                NaN  NaN            YES

# %%
mujib_relevant_ques = ques_df[ques_df['Mujib Relevant'] == "YES"]
mujib_relevant_ques
# Out:
#                                                     Q1  \
# 1    ১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন ...
# 3     কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এ...
# 4    পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন ক...
# 5    ১৯৫৩ সালে বঙ্গবন্ধু কোন দলের সাধারন সম্পাদক নি...
# 8    পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ দলের কোন পদ...
# ..                                                 ...
# 417                  শেখ মুজিবুর রহমানের কয় ছেলে ছিলো?
# 418                  শেখ মুজিবুর রহমানের কয় মেয়ে ছিলো?
# 419              শেখ মুজিবুর রহমানের ছেলেমেয়ের নাম কি?
# 420                  শেখ মুজিব রহমানের ছেলেদের নাম কি?
# 421                শেখ মুজিবুর রহমানের মেয়েদের নাম কি?
#
#                                                     Q2  \
# 1    ১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?
# 3     বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পা...
# 4    পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অন...
# 5      শেখ মজীব  কোন দলের সাধারন সম্পাদক নির্বাচিত হন?
# 8    শেখ মুজিবুর রহমান পূর্ব পাকিস্তান মুসলিম লীগ দ...
# ..                                                 ...
# 417                    মুজিবের কতজন পুত্র সন্তান ছিলো?
# 418                    মুজিবের কতজন কন্যা সন্তান ছিলো?
# 419                      শেখ মুজিবের সন্তানদের নাম কি?
# 420                শেখ মুজিবের পুত্র সন্তানদের নাম কি?
# 421                শেখ মুজিবের কন্যা সন্তানদের নাম কি?
#
#                                                     Q3   Q4 Mujib Relevant
# 1                                                                      YES
# 3     বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লী...  NaN            YES
# 4                                                  NaN  NaN            YES
# 5                                                  NaN  NaN            YES
# 8            মুসলিম লীগ দলের কোন পদে শেখ মজীব ছিলেন  ?  NaN            YES
# ..                                                 ...  ...            ...
# 417                                                NaN  NaN            YES
# 418                                                NaN  NaN            YES
# 419                       শেখ মুজিবের ছেলে মেয়ে কে কে?  NaN            YES
# 420                           শেখ মুজিবের পুত্র কে কে?  NaN            YES
# 421                           শেখ মুজিবের কন্যা কে কে?  NaN            YES
#
# [265 rows x 5 columns]

# %%
total_mujib_ques = len(mujib_relevant_ques)
total_unique_ques = len(ques_df)
total_no_mujib_ques = total_unique_ques- total_mujib_ques

# %%
plot_bar_plot(["# Unique Questions","# Mujib Relevant Question","# Not relevant To Mujib Questions"],
              [total_unique_ques,total_mujib_ques,total_no_mujib_ques],
              "Questions Category",
              "# of Questions",
              "Number of Questions ( Mujib relevant Vs Non-relevant)",
              show_number=True
              )

# %% [markdown]
# ## Number of Questions in Q1,Q2,Q3,Q4

# %%
q1 = df['Q1']
q2 = df['Q2'].dropna()
q3 = df['Q3'].dropna()
q4 = df['Q4'].dropna()

# %%
qs = [q1,q2,q3,q4]

for i, q in enumerate(qs):
    print(f"Lengts of Q{i+1} : {len(q)}")
# Out:
# Lengts of Q1 : 422
# Lengts of Q2 : 386
# Lengts of Q3 : 197
# Lengts of Q4 : 48

# %%
ques_number = {
    'Q1': len(q1),
    'Q2': len(q2),
    'Q3':len(q3),
    'Q4':len(q4)
}

# %%
plot_bar_plot(list(ques_number.keys()),
              list(ques_number.values()),
              "Q's",
              "# of Questions",
              "# of Questions in Q's",
              show_number=True)

# %% [markdown]
# ## Number of Questions vs Context

# %%
ctx_ques = []

for item in data:
    ctx = item['context']
    qtns = []
    for qas in item['qas']:
        qtns.append(qas['qtns'])
    ctx_ques.append({
        'ctx':ctx,
        'qtns': qtns
        
    })

# %%
qs_in_ctx = []
for item in ctx_ques:
    qs_in_ctx.append(len(item['qtns']))

# %%
len(ctx_ques) , len(qs_in_ctx)
# Out:
# (61, 61)

# %%
plot_bar_plot([*range(1,len(ctx_ques)+1,1)],
              qs_in_ctx,
              "Context #",
              "# of Questions",
              "Question Per Context",
              show_number=True,
              show_x=True)

# %% [markdown]
# ## Lenth of the Context

# %%
contexts = df['Context'].dropna()

# %%
print(f"Total Context : {len(contexts)}")
# Out:
# Total Context : 61

# %%
contexts.isna().sum(), df['Context'].isna().sum()
# Out:
# (0, 361)

# %%
words_in_context = [len(ctx) for ctx in contexts]
words_in_context
# Out:
# [157,
#  284,
#  843,
#  739,
#  484,
#  251,
#  430,
#  392,
#  559,
#  360,
#  216,
#  245,
#  229,
#  596,
#  297,
#  158,
#  207,
#  201,
#  158,
#  340,
#  376,
#  1001,
#  744,
#  991,
#  674,
#  988,
#  1272,
#  418,
#  232,
#  310,
#  490,
#  508,
#  234,
#  212,
#  188,
#  532,
#  738,
#  307,
#  313,
#  127,
#  847,
#  221,
#  848,
#  387,
#  283,
#  445,
#  593,
#  1107,
#  1097,
#  566,
#  312,
#  568,
#  253,
#  390,
#  1169,
#  226,
#  684,
#  967,
#  127,
#  876,
#  179]

# %%
s = 0
for i in words_in_context:
    s += i
    
print("Total Length of the context (whitespace, punctuation, words): ", s)
plot_bar_plot([*range(1,len(words_in_context)+1,1)],
              words_in_context,
              "Context #",
              "Length of the context",
              "Length of the context in the Contexts",
              show_number=True
              )
# Out:
# Total Length of the context (whitespace, punctuation, words):  29946

# %% [markdown]
# ## Bag Of Word

# %%
from collections import Counter
from tqdm.notebook import tqdm_notebook
word_ls = []

for sen in contexts.tolist():
    word_ls.extend(sen.split())
    # print(len(word_ls))
     

print(len(word_ls))
     

Counter = Counter(word_ls)
most_occured_20 = Counter.most_common(20)
# print(most_occured_20)
     

most_occured_50 = Counter.most_common(50)
print(most_occured_50)
# Out:
# 4373
# [('শেখ', 70), ('সালের', 53), ('এবং', 51), ('করে', 43), ('বঙ্গবন্ধু', 40), ('মুজিবুর', 39), ('মুসলিম', 35), ('হয়', 28), ('ও', 27), ('এই', 27), ('থেকে', 25), ('করা', 25), ('মার্চ', 24), ('লীগের', 22), ('করেন', 21), ('সালে', 21), ('ঘোষণা', 21), ('পাকিস্তান', 18), ('আওয়ামী', 18), ('এক', 18), ('হিসেবে', 18), ('বাংলাদেশের', 17), ('রহমান।', 16), ('বঙ্গবন্ধু।', 16), ('জন্য', 16), ('বঙ্গবন্ধুর', 16), ('করেন।', 15), ('তিনি।', 15), ('হয়।', 15), ('মুজিব।', 15), ('হন', 14), ('তিনি', 14), ('নিয়ে', 13), ('দিয়ে', 13), ('১৯৭১', 13), ('স্বাধীনতার', 13), ('করার', 12), ('ঢাকা', 12), ('পর', 12), ('প্রথম', 12), ('নির্বাচিত', 11), ('শুরু', 11), ('বাংলার', 11), ('হয়ে', 11), ('কিন্তু', 11), ('পাকিস্তানের', 11), ('ফলে', 11), ('বঙ্গবন্ধুকে', 11), ('সেই', 11), ('ছাত্রলীগের', 11)]

# %%
words_20 = [w[0] for w in most_occured_20]

words_20
# Out:
# ['শেখ',
#  'সালের',
#  'এবং',
#  'করে',
#  'বঙ্গবন্ধু',
#  'মুজিবুর',
#  'মুসলিম',
#  'হয়',
#  'ও',
#  'এই',
#  'থেকে',
#  'করা',
#  'মার্চ',
#  'লীগের',
#  'করেন',
#  'সালে',
#  'ঘোষণা',
#  'পাকিস্তান',
#  'আওয়ামী',
#  'এক']

# %%
w_c_20 = [w[1] for w in most_occured_20]
w_c_20
# Out:
# [70,
#  53,
#  51,
#  43,
#  40,
#  39,
#  35,
#  28,
#  27,
#  27,
#  25,
#  25,
#  24,
#  22,
#  21,
#  21,
#  21,
#  18,
#  18,
#  18]

# %% [markdown]
# ### BOG(Most 20)

# %%
plot_bar_plot(words_20,w_c_20,"Words","Word Count in Contexts","BOG (Bag Of Words[Most 20])",show_x=True,show_number=True)

# %%
words_50 = [w[0] for w in most_occured_50]

words_50
# Out:
# ['শেখ',
#  'সালের',
#  'এবং',
#  'করে',
#  'বঙ্গবন্ধু',
#  'মুজিবুর',
#  'মুসলিম',
#  'হয়',
#  'ও',
#  'এই',
#  'থেকে',
#  'করা',
#  'মার্চ',
#  'লীগের',
#  'করেন',
#  'সালে',
#  'ঘোষণা',
#  'পাকিস্তান',
#  'আওয়ামী',
#  'এক',
#  'হিসেবে',
#  'বাংলাদেশের',
#  'রহমান।',
#  'বঙ্গবন্ধু।',
#  'জন্য',
#  'বঙ্গবন্ধুর',
#  'করেন।',
#  'তিনি।',
#  'হয়।',
#  'মুজিব।',
#  'হন',
#  'তিনি',
#  'নিয়ে',
#  'দিয়ে',
#  '১৯৭১',
#  'স্বাধীনতার',
#  'করার',
#  'ঢাকা',
#  'পর',
#  'প্রথম',
#  'নির্বাচিত',
#  'শুরু',
#  'বাংলার',
#  'হয়ে',
#  'কিন্তু',
#  'পাকিস্তানের',
#  'ফলে',
#  'বঙ্গবন্ধুকে',
#  'সেই',
#  'ছাত্রলীগের']

# %%
w_c_50 = [w[1] for w in most_occured_50]
w_c_50
# Out:
# [70,
#  53,
#  51,
#  43,
#  40,
#  39,
#  35,
#  28,
#  27,
#  27,
#  25,
#  25,
#  24,
#  22,
#  21,
#  21,
#  21,
#  18,
#  18,
#  18,
#  18,
#  17,
#  16,
#  16,
#  16,
#  16,
#  15,
#  15,
#  15,
#  15,
#  14,
#  14,
#  13,
#  13,
#  13,
#  13,
#  12,
#  12,
#  12,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11]

# %% [markdown]
# ### BOG (Most 50)

# %%
plot_bar_plot(words_50,w_c_50,"Words","Word Count in Contexts","BOG (Bag Of Words[most 50])",show_x=True,show_number=True)

# %% [markdown]
# ## Number of Questions by People

# %%
p1 = list(df.P1.unique())
p1
# Out:
# [nan,
#  'আইয়ুব খান',
#  ' ',
#  'শেখ লুৎফর রহমান',
#  'সায়েরা খাতুন',
#  'পূর্ণ দাস',
#  'সুভাষচন্দ্র বসু',
#  'হামিদ মাস্টার',
#  'এ কে ফজলুল হক ',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'কবি কাজী নজরুল ইসলাম',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'জেনারেল মোহাম্মদ আলী জিন্নাহ',
#  'সালাম',
#  'শান্তিতে নোবেল বিজয়ী উইলিবান্ট',
#  'ব্রিটিশ লর্ড ফেন্যার ব্রোকওয়ে',
#  'ফজিলাতুন্নেসা',
#  'শেখ কামাল',
#  'শেখ হাসিনা']

# %%
p2 = list(df.P2.unique())
p2
# Out:
# [nan,
#  'আইয়ুব খান',
#  'ইয়াহিয়া খান ',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'ইয়াহিয়া খান',
#  ' নেলসন ম্যান্ডেলা',
#  'সিদ্দিক সালিক',
#  'এডওয়ার্ড হিথ',
#  'ডেভিড লোশাক',
#  'সৈয়দ নজরুল ইসলাম',
#  'তাজউদ্দিন আহমদ',
#  'সৈয়দ নজরুল ইসলাম',
#  'রমেশ চন্দ্র',
#  'সায়েরা খাতুন',
#  'বাঘা যতীন',
#  'কাজী নজ্রুল ইসলাম',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'হুমায়ুন কবির',
#  'বরকত',
#  'শেখ জামাল',
#  'শেখ রেহানা']

# %%
p3 = list(df.P3.unique())
p3
# Out:
# [nan, 'প্রিন্সিপাল ইব্রাহিম খাঁ', 'রফিক', 'শেখ রাসেল']

# %%
ppls = []


ppls.extend(p1)

# %%
ppls.extend(p2)

# %%
ppls.extend(p3)

# %%
len(ppls) , len(p1), len(p2) , len(p3)
# Out:
# (45, 20, 21, 4)

# %%
c_ppls = []

for i in ppls:
    if i not in c_ppls:
        c_ppls.append(i)

len(c_ppls), len(ppls)
# Out:
# (40, 45)

# %%
c_ppls
# Out:
# [nan,
#  'আইয়ুব খান',
#  ' ',
#  'শেখ লুৎফর রহমান',
#  'সায়েরা খাতুন',
#  'পূর্ণ দাস',
#  'সুভাষচন্দ্র বসু',
#  'হামিদ মাস্টার',
#  'এ কে ফজলুল হক ',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'কবি কাজী নজরুল ইসলাম',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'জেনারেল মোহাম্মদ আলী জিন্নাহ',
#  'সালাম',
#  'শান্তিতে নোবেল বিজয়ী উইলিবান্ট',
#  'ব্রিটিশ লর্ড ফেন্যার ব্রোকওয়ে',
#  'ফজিলাতুন্নেসা',
#  'শেখ কামাল',
#  'শেখ হাসিনা',
#  'ইয়াহিয়া খান ',
#  'হোসেন শহীদ সোহরাওয়ার্দী',
#  'ইয়াহিয়া খান',
#  ' নেলসন ম্যান্ডেলা',
#  'সিদ্দিক সালিক',
#  'এডওয়ার্ড হিথ',
#  'ডেভিড লোশাক',
#  'সৈয়দ নজরুল ইসলাম',
#  'তাজউদ্দিন আহমদ',
#  'সৈয়দ নজরুল ইসলাম',
#  'রমেশ চন্দ্র',
#  'বাঘা যতীন',
#  'কাজী নজ্রুল ইসলাম',
#  'হুমায়ুন কবির',
#  'বরকত',
#  'শেখ জামাল',
#  'শেখ রেহানা',
#  'প্রিন্সিপাল ইব্রাহিম খাঁ',
#  'রফিক',
#  'শেখ রাসেল']

# %%
people_q_dict = dict()

for i in c_ppls:
    if type(i) != str:
        text = "people_q_dict['missing'] = []"
        exec(text)
    else:
        text = "people_q_dict['"+i+"'] = []"
        exec(text)

# %%
for ppl in people_q_dict.keys():
    for item in data:
        for  qas in  item['qas']:
            for p in qas['people']:
                if type(p) != str:
                    p = "missing"
                    # continue
                if p == ppl:
                    people_q_dict[ppl].append(qas['qtns'])

# %%
people_q_dict
# Out:
# {'missing': [['পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?',
#    '১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?',
#    'কত মানুষ ১৯৭০ এ মারা যায় ?',
#    nan],
#   ['পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?',
#    '১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?',
#    'কত মানুষ ১৯৭০ এ মারা যায় ?',
#    nan],
#   ['পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?',
#    '১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?',
#    'কত মানুষ ১৯৭০ এ মারা যায় ?',
#    nan],
#   ['১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন কেন?',
#    '১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?',
#    ' ',
#    ' '],
#   ['১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন কেন?',
#    '১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?',
#    ' ',
#    ' '],
#   ['১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন কেন?',
#    '১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?',
#    ' ',
#    ' '],
#   ['কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?', nan, nan, nan],
#   ['কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?', nan, nan, nan],
#   ['কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?', nan, nan, nan],
#   [" কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান ?",
#    " বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন  ?",
#    " বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন কত সালে  ?",
#    nan],
#   [" কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান ?",
#    " বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন  ?",
#    " বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন কত সালে  ?",
#    nan],
#   [" কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান ?",
#    " বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন  ?",
#    " বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন কত সালে  ?",
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    'পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    'পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    'পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    nan,
#    nan],
#   ['১৯৫৩ সালে বঙ্গবন্ধু কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    'শেখ মজীব  কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    nan,
#    nan],
#   ['১৯৫৩ সালে বঙ্গবন্ধু কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    'শেখ মজীব  কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    nan,
#    nan],
#   ['১৯৫৩ সালে বঙ্গবন্ধু কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    'শেখ মজীব  কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    nan,
#    nan],
#   ['১৯৫৩ সালের কোন মাসে পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    '১৯৫৩ সালের কখন পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    ' মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় কখন  ?',
#    nan],
#   ['১৯৫৩ সালের কোন মাসে পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    '১৯৫৩ সালের কখন পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    ' মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় কখন  ?',
#    nan],
#   ['১৯৫৩ সালের কোন মাসে পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    '১৯৫৩ সালের কখন পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    ' মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় কখন  ?',
#    nan],
#   ['তৎকালীন পধান বিরোধী দল কোনটি ছিলো?',
#    '১৯৫৩ সালের  কোনটি বিরোধী দল ছিল ?',
#    nan,
#    nan],
#   ['তৎকালীন পধান বিরোধী দল কোনটি ছিলো?',
#    '১৯৫৩ সালের  কোনটি বিরোধী দল ছিল ?',
#    nan,
#    nan],
#   ['তৎকালীন পধান বিরোধী দল কোনটি ছিলো?',
#    '১৯৫৩ সালের  কোনটি বিরোধী দল ছিল ?',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ দলের কোন পদে নির্বাচিত হন শেখ মুজিবুর রহমান?',
#    'শেখ মুজিবুর রহমান পূর্ব পাকিস্তান মুসলিম লীগ দলের কোন পদে নির্বাচিত হন ?',
#    ' মুসলিম লীগ দলের কোন পদে শেখ মজীব ছিলেন  ?',
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ দলের কোন পদে নির্বাচিত হন শেখ মুজিবুর রহমান?',
#    'শেখ মুজিবুর রহমান পূর্ব পাকিস্তান মুসলিম লীগ দলের কোন পদে নির্বাচিত হন ?',
#    ' মুসলিম লীগ দলের কোন পদে শেখ মজীব ছিলেন  ?',
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ দলের কোন পদে নির্বাচিত হন শেখ মুজিবুর রহমান?',
#    'শেখ মুজিবুর রহমান পূর্ব পাকিস্তান মুসলিম লীগ দলের কোন পদে নির্বাচিত হন ?',
#    ' মুসলিম লীগ দলের কোন পদে শেখ মজীব ছিলেন  ?',
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ কোন ধরণের দল ছিলো?',
#    ' লীগ কোন ধরণের দল ছিলো?',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ কোন ধরণের দল ছিলো?',
#    ' লীগ কোন ধরণের দল ছিলো?',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ কোন ধরণের দল ছিলো?',
#    ' লীগ কোন ধরণের দল ছিলো?',
#    nan,
#    nan],
#   [' যুক্তফ্রন্ট গঠিত হয় কত সালে?',
#    ' কত সালে যুক্তফ্রন্ট গঠিত হয় ?',
#    nan,
#    nan],
#   [' যুক্তফ্রন্ট গঠিত হয় কত সালে?',
#    ' কত সালে যুক্তফ্রন্ট গঠিত হয় ?',
#    nan,
#    nan],
#   [' যুক্তফ্রন্ট গঠিত হয় কত সালে?',
#    ' কত সালে যুক্তফ্রন্ট গঠিত হয় ?',
#    nan,
#    nan],
#   ['১৯৫৩ সালের কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    ' কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    'যুক্তফ্রন্টগঠিত হয় কত তারিখ ?',
#    nan],
#   ['১৯৫৩ সালের কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    ' কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    'যুক্তফ্রন্টগঠিত হয় কত তারিখ ?',
#    nan],
#   ['১৯৫৩ সালের কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    ' কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    'যুক্তফ্রন্টগঠিত হয় কত তারিখ ?',
#    nan],
#   ['কার নেতৃত্বে যুক্তফ্রন্ট গঠিত হয় ?',
#    ' যুক্তফ্রন্ট এর  নেতৃত্ব দেন কোন দল?',
#    'কোন রাজনীতিক দল যুক্তফ্রন্ট গঠন করে ',
#    nan],
#   ['কার নেতৃত্বে যুক্তফ্রন্ট গঠিত হয় ?',
#    ' যুক্তফ্রন্ট এর  নেতৃত্ব দেন কোন দল?',
#    'কোন রাজনীতিক দল যুক্তফ্রন্ট গঠন করে ',
#    nan],
#   ['কার নেতৃত্বে যুক্তফ্রন্ট গঠিত হয় ?',
#    ' যুক্তফ্রন্ট এর  নেতৃত্ব দেন কোন দল?',
#    'কোন রাজনীতিক দল যুক্তফ্রন্ট গঠন করে ',
#    nan],
#   ['কাদের নিয়ে যুক্তফ্রন্ট গঠিত হয়?', 'কারা যুক্তফ্রন্ট গঠন করে?', nan, nan],
#   ['কাদের নিয়ে যুক্তফ্রন্ট গঠিত হয়?', 'কারা যুক্তফ্রন্ট গঠন করে?', nan, nan],
#   ['কাদের নিয়ে যুক্তফ্রন্ট গঠিত হয়?', 'কারা যুক্তফ্রন্ট গঠন করে?', nan, nan],
#   [' দেশজুড়ে যুক্তফ্রন্ট প্রচারনা শুরু করেন কে?',
#    ' কে যুক্তফ্রন্টের প্রচারনা শুরু করে?',
#    ' যুক্তফ্রন্টের গঠনের প্রচারনা শুরু করে কে?',
#    nan],
#   [' দেশজুড়ে যুক্তফ্রন্ট প্রচারনা শুরু করেন কে?',
#    ' কে যুক্তফ্রন্টের প্রচারনা শুরু করে?',
#    ' যুক্তফ্রন্টের গঠনের প্রচারনা শুরু করে কে?',
#    nan],
#   [' দেশজুড়ে যুক্তফ্রন্ট প্রচারনা শুরু করেন কে?',
#    ' কে যুক্তফ্রন্টের প্রচারনা শুরু করে?',
#    ' যুক্তফ্রন্টের গঠনের প্রচারনা শুরু করে কে?',
#    nan],
#   ['যুক্তফ্রন্ট নির্বাচন কতসালে হয় ?',
#    ' কতসালে যুক্তফ্রন্ট নির্বাচন হয় ?',
#    ' কতসালে  প্রদেশিক পরিষদের সাধারণ নির্বাচন হয় ?',
#    nan],
#   ['যুক্তফ্রন্ট নির্বাচন কতসালে হয় ?',
#    ' কতসালে যুক্তফ্রন্ট নির্বাচন হয় ?',
#    ' কতসালে  প্রদেশিক পরিষদের সাধারণ নির্বাচন হয় ?',
#    nan],
#   ['যুক্তফ্রন্ট নির্বাচন কতসালে হয় ?',
#    ' কতসালে যুক্তফ্রন্ট নির্বাচন হয় ?',
#    ' কতসালে  প্রদেশিক পরিষদের সাধারণ নির্বাচন হয় ?',
#    nan],
#   ['২২৩টি আসনে বিজয় হয় কোন দল?',
#    '১৯৫৪ এর নির্বাচনে কোন দল বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে কোন দল বিজয়ী হয় ?',
#    nan],
#   ['২২৩টি আসনে বিজয় হয় কোন দল?',
#    '১৯৫৪ এর নির্বাচনে কোন দল বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে কোন দল বিজয়ী হয় ?',
#    nan],
#   ['২২৩টি আসনে বিজয় হয় কোন দল?',
#    '১৯৫৪ এর নির্বাচনে কোন দল বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে কোন দল বিজয়ী হয় ?',
#    nan],
#   ['আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    '১৯৫৪ এর নির্বাচনে আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'কয়টি আসনে আওয়ামী লীগ  বিজয়ী হয় ?'],
#   ['আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    '১৯৫৪ এর নির্বাচনে আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'কয়টি আসনে আওয়ামী লীগ  বিজয়ী হয় ?'],
#   ['আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    '১৯৫৪ এর নির্বাচনে আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'কয়টি আসনে আওয়ামী লীগ  বিজয়ী হয় ?'],
#   ['মুসলীম লীগ কয়টি আসন পায় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  মুসলীম লীগ কয়টি আসন লাভ করে ?',
#    '১৯৫৪ এর নির্বাচনে মুসলীম লীগ কয়টি আসন পায় ?',
#    nan],
#   ['মুসলীম লীগ কয়টি আসন পায় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  মুসলীম লীগ কয়টি আসন লাভ করে ?',
#    '১৯৫৪ এর নির্বাচনে মুসলীম লীগ কয়টি আসন পায় ?',
#    nan],
#   ['মুসলীম লীগ কয়টি আসন পায় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  মুসলীম লীগ কয়টি আসন লাভ করে ?',
#    '১৯৫৪ এর নির্বাচনে মুসলীম লীগ কয়টি আসন পায় ?',
#    nan],
#   ['যুক্তফ্রন্টে কয়টি মুসলিম আসন ছিলো?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  কয়টি মুসলিম আসন ছিল  ?',
#    nan,
#    nan],
#   ['যুক্তফ্রন্টে কয়টি মুসলিম আসন ছিলো?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  কয়টি মুসলিম আসন ছিল  ?',
#    nan,
#    nan],
#   ['যুক্তফ্রন্টে কয়টি মুসলিম আসন ছিলো?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  কয়টি মুসলিম আসন ছিল  ?',
#    nan,
#    nan],
#   ['আওয়ামী লীগের প্রধান মুখপাত্র কে?',
#    'আওয়ামী লীগের প্রধান  কে ছিলেন?',
#    'কে আওয়ামী লীগের প্রধান মুখপাত্র ছিলেন?',
#    nan],
#   ['আওয়ামী লীগের প্রধান মুখপাত্র কে?',
#    'আওয়ামী লীগের প্রধান  কে ছিলেন?',
#    'কে আওয়ামী লীগের প্রধান মুখপাত্র ছিলেন?',
#    nan],
#   ['আওয়ামী লীগের প্রধান মুখপাত্র কে?',
#    'আওয়ামী লীগের প্রধান  কে ছিলেন?',
#    'কে আওয়ামী লীগের প্রধান মুখপাত্র ছিলেন?',
#    nan],
#   ['যুক্তফ্রন্ট মন্ত্রীসভার কনিষ্ঠ মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্ট মন্ত্রীসভার কম বয়সী মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্টে কে সব চেয়ে কম বয়সী মন্ত্রী ছিলেন?',
#    nan],
#   ['যুক্তফ্রন্ট মন্ত্রীসভার কনিষ্ঠ মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্ট মন্ত্রীসভার কম বয়সী মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্টে কে সব চেয়ে কম বয়সী মন্ত্রী ছিলেন?',
#    nan],
#   ['যুক্তফ্রন্ট মন্ত্রীসভার কনিষ্ঠ মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্ট মন্ত্রীসভার কম বয়সী মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্টে কে সব চেয়ে কম বয়সী মন্ত্রী ছিলেন?',
#    nan],
#   ['স্বাধীনতা আন্দোলনের প্রাণ পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের প্রাধান পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের ডাক দেন কে?',
#    nan],
#   ['স্বাধীনতা আন্দোলনের প্রাণ পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের প্রাধান পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের ডাক দেন কে?',
#    nan],
#   ['স্বাধীনতা আন্দোলনের প্রাণ পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের প্রাধান পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের ডাক দেন কে?',
#    nan],
#   ['কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান কে?',
#    ' কাকে কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব দেওয়া হয়?',
#    'কৃষি, মন্ত্রণালয়ের দায়িত্ব কে পান?',
#    'বন মন্ত্রণালয়ের দায়িত্ব কে পান?'],
#   ['কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান কে?',
#    ' কাকে কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব দেওয়া হয়?',
#    'কৃষি, মন্ত্রণালয়ের দায়িত্ব কে পান?',
#    'বন মন্ত্রণালয়ের দায়িত্ব কে পান?'],
#   ['কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান কে?',
#    ' কাকে কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব দেওয়া হয়?',
#    'কৃষি, মন্ত্রণালয়ের দায়িত্ব কে পান?',
#    'বন মন্ত্রণালয়ের দায়িত্ব কে পান?'],
#   ['মুসলীম লীগের প্রভাবশালী নেতাকে ১৩ হাজার ভোটেরব্যবধানে পরাজিত করে কে?',
#    'মুসলীম লীগের প্রভাবশালী নেতাকে  পরাজিত করে কে?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে মুসলীম লীগের প্রভাবশালী নেতাকে বিপুল ভোটেরব্যবধানে পরাজিত করে কে?',
#    nan],
#   ['মুসলীম লীগের প্রভাবশালী নেতাকে ১৩ হাজার ভোটেরব্যবধানে পরাজিত করে কে?',
#    'মুসলীম লীগের প্রভাবশালী নেতাকে  পরাজিত করে কে?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে মুসলীম লীগের প্রভাবশালী নেতাকে বিপুল ভোটেরব্যবধানে পরাজিত করে কে?',
#    nan],
#   ['মুসলীম লীগের প্রভাবশালী নেতাকে ১৩ হাজার ভোটেরব্যবধানে পরাজিত করে কে?',
#    'মুসলীম লীগের প্রভাবশালী নেতাকে  পরাজিত করে কে?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে মুসলীম লীগের প্রভাবশালী নেতাকে বিপুল ভোটেরব্যবধানে পরাজিত করে কে?',
#    nan],
#   [' মন্ত্রীসভাকে পদচ্যুত করে কাকে গ্রেফতার করা হয় ?',
#    ' মন্ত্রীসভাকে ভাঙার পরে  কাকে গ্রেফতার করা হয় ?',
#    nan,
#    nan],
#   [' মন্ত্রীসভাকে পদচ্যুত করে কাকে গ্রেফতার করা হয় ?',
#    ' মন্ত্রীসভাকে ভাঙার পরে  কাকে গ্রেফতার করা হয় ?',
#    nan,
#    nan],
#   [' মন্ত্রীসভাকে পদচ্যুত করে কাকে গ্রেফতার করা হয় ?',
#    ' মন্ত্রীসভাকে ভাঙার পরে  কাকে গ্রেফতার করা হয় ?',
#    nan,
#    nan],
#   ['যুক্তফ্রন্ট কার নেতৃত্বাধীন ছিল?',
#    'যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? ',
#    ' কার নেতৃত্বে যুক্তফ্রন্ট জয় লাভ করে ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? '],
#   ['যুক্তফ্রন্ট কার নেতৃত্বাধীন ছিল?',
#    'যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? ',
#    ' কার নেতৃত্বে যুক্তফ্রন্ট জয় লাভ করে ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? '],
#   ['যুক্তফ্রন্ট কার নেতৃত্বাধীন ছিল?',
#    'যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? ',
#    ' কার নেতৃত্বে যুক্তফ্রন্ট জয় লাভ করে ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? '],
#   [' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়ী হয় ?', nan, nan, nan],
#   [' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়ী হয় ?', nan, nan, nan],
#   [' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়ী হয় ?', nan, nan, nan],
#   ['শেখ মুজিবুর রহমান কোন মন্ত্রণালয়ের দায়িত্ব ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়রে পরে শেখ মুজিব কোন মন্ত্রণালয়ের দায়িত্ব পান ?',
#    nan,
#    nan],
#   ['শেখ মুজিবুর রহমান কোন মন্ত্রণালয়ের দায়িত্ব ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়রে পরে শেখ মুজিব কোন মন্ত্রণালয়ের দায়িত্ব পান ?',
#    nan,
#    nan],
#   ['শেখ মুজিবুর রহমান কোন মন্ত্রণালয়ের দায়িত্ব ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়রে পরে শেখ মুজিব কোন মন্ত্রণালয়ের দায়িত্ব পান ?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু মুসলীম লীগের প্রভাবশালী নেতাকে কত হাজার ভোটেরব্যবধানে পরাজিত করেন?',
#    'শেখ মুজিব মুসলীম লীগের  নেতাকে কত  ভোটের ব্যবধানে পরাজিত করেন?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু মুসলীম লীগের প্রভাবশালী নেতাকে কত হাজার ভোটেরব্যবধানে পরাজিত করেন?',
#    'শেখ মুজিব মুসলীম লীগের  নেতাকে কত  ভোটের ব্যবধানে পরাজিত করেন?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু মুসলীম লীগের প্রভাবশালী নেতাকে কত হাজার ভোটেরব্যবধানে পরাজিত করেন?',
#    'শেখ মুজিব মুসলীম লীগের  নেতাকে কত  ভোটের ব্যবধানে পরাজিত করেন?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কত সালে পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন ?',
#    'কবে শেখ মুজীব গণপরিষদের সদস্য হন ? ',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কত সালে পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন ?',
#    'কবে শেখ মুজীব গণপরিষদের সদস্য হন ? ',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কত সালে পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন ?',
#    'কবে শেখ মুজীব গণপরিষদের সদস্য হন ? ',
#    nan,
#    nan],
#   ['পূর্ব বাংলার নাম পূর্ব পাকিস্তান করার প্রতিবাদ করেন কে ?',
#    'এঈ দেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বাধা দেন ? ',
#    'বাংলাদেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বিরোধিতা করেন  ? ',
#    nan],
#   ['পূর্ব বাংলার নাম পূর্ব পাকিস্তান করার প্রতিবাদ করেন কে ?',
#    'এঈ দেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বাধা দেন ? ',
#    'বাংলাদেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বিরোধিতা করেন  ? ',
#    nan],
#   ['পূর্ব বাংলার নাম পূর্ব পাকিস্তান করার প্রতিবাদ করেন কে ?',
#    'এঈ দেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বাধা দেন ? ',
#    'বাংলাদেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বিরোধিতা করেন  ? ',
#    nan],
#   ['পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন  কে ?',
#    'কে পূর্ব পাকিস্তানে স্বায়ত্ত শাসন দাবী করেন ? ',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন  কে ?',
#    'কে পূর্ব পাকিস্তানে স্বায়ত্ত শাসন দাবী করেন ? ',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন  কে ?',
#    'কে পূর্ব পাকিস্তানে স্বায়ত্ত শাসন দাবী করেন ? ',
#    nan,
#    nan],
#   ['কোথায় শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন ?',
#    'শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন কোন জায়গায় ?',
#    nan,
#    nan],
#   ['কোথায় শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন ?',
#    'শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন কোন জায়গায় ?',
#    nan,
#    nan],
#   ['কোথায় শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন ?',
#    'শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন কোন জায়গায় ?',
#    nan,
#    nan],
#   ['"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- কথাটি কে বলেছেন ?',
#    '"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- উক্তিটি কার  ?',
#    ' কে বলেছেন ""পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"  ?',
#    nan],
#   ['"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- কথাটি কে বলেছেন ?',
#    '"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- উক্তিটি কার  ?',
#    ' কে বলেছেন ""পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"  ?',
#    nan],
#   ['"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- কথাটি কে বলেছেন ?',
#    '"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- উক্তিটি কার  ?',
#    ' কে বলেছেন ""পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"  ?',
#    nan],
#   ['ধর্মনিরপেক্ষতা কোন দলের মূলনীতি ?',
#    'কোন রাজনৈতিক দল তাদের মূলনীতি করেছিলো ধর্ম নীরপেক্ষতা ?',
#    nan,
#    nan],
#   ['ধর্মনিরপেক্ষতা কোন দলের মূলনীতি ?',
#    'কোন রাজনৈতিক দল তাদের মূলনীতি করেছিলো ধর্ম নীরপেক্ষতা ?',
#    nan,
#    nan],
#   ['ধর্মনিরপেক্ষতা কোন দলের মূলনীতি ?',
#    'কোন রাজনৈতিক দল তাদের মূলনীতি করেছিলো ধর্ম নীরপেক্ষতা ?',
#    nan,
#    nan],
#   ['কবে আওয়ামী লীগ ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    'আওয়ামী লীগ কবে থেকে ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    nan,
#    nan],
#   ['কবে আওয়ামী লীগ ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    'আওয়ামী লীগ কবে থেকে ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    nan,
#    nan],
#   ['কবে আওয়ামী লীগ ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    'আওয়ামী লীগ কবে থেকে ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    nan,
#    nan],
#   ['আওয়ামী মুসলিম লীগ থেকে কবে দলের নাম মুসলিম লীগ করা হয় ? ',
#    'কবে থেকে আওয়ামী মুসলিম লীগ থেকে দলের নাম মুসলিম লীগ করা হয় ? ',
#    nan,
#    nan],
#   ['আওয়ামী মুসলিম লীগ থেকে কবে দলের নাম মুসলিম লীগ করা হয় ? ',
#    'কবে থেকে আওয়ামী মুসলিম লীগ থেকে দলের নাম মুসলিম লীগ করা হয় ? ',
#    nan,
#    nan],
#   ['আওয়ামী মুসলিম লীগ থেকে কবে দলের নাম মুসলিম লীগ করা হয় ? ',
#    'কবে থেকে আওয়ামী মুসলিম লীগ থেকে দলের নাম মুসলিম লীগ করা হয় ? ',
#    nan,
#    nan],
#   ['২য় বারের মতো শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    ' ১ম বারের পরে  শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    nan,
#    nan],
#   ['২য় বারের মতো শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    ' ১ম বারের পরে  শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    nan,
#    nan],
#   ['২য় বারের মতো শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    ' ১ম বারের পরে  শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    nan,
#    nan],
#   ['আওয়াামী লীগ থেকে কেনো মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কী কারনে আওয়াামী লীগ থেকে  মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কিসের জন্য আওয়াামী লীগ থেকে মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    nan],
#   ['আওয়াামী লীগ থেকে কেনো মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কী কারনে আওয়াামী লীগ থেকে  মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কিসের জন্য আওয়াামী লীগ থেকে মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    nan],
#   ['আওয়াামী লীগ থেকে কেনো মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কী কারনে আওয়াামী লীগ থেকে  মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কিসের জন্য আওয়াামী লীগ থেকে মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    nan],
#   ['কত সালে প্রাদেশিক সরকার গঠীত হয় ?',
#    ' প্রাদেশিক সরকার কত সালে গঠীত হয় ?',
#    nan,
#    nan],
#   ['কত সালে প্রাদেশিক সরকার গঠীত হয় ?',
#    ' প্রাদেশিক সরকার কত সালে গঠীত হয় ?',
#    nan,
#    nan],
#   ['কত সালে প্রাদেশিক সরকার গঠীত হয় ?',
#    ' প্রাদেশিক সরকার কত সালে গঠীত হয় ?',
#    nan,
#    nan],
#   ['কোন দল প্রাদেশিক সরকার গঠন করে ?',
#    'কারা প্রাদেশিক সরকার গঠন করে ?',
#    'প্রাদেশিক সরকার কোন রাজনৈতিক দল গঠন করে ?',
#    nan],
#   ['কোন দল প্রাদেশিক সরকার গঠন করে ?',
#    'কারা প্রাদেশিক সরকার গঠন করে ?',
#    'প্রাদেশিক সরকার কোন রাজনৈতিক দল গঠন করে ?',
#    nan],
#   ['কোন দল প্রাদেশিক সরকার গঠন করে ?',
#    'কারা প্রাদেশিক সরকার গঠন করে ?',
#    'প্রাদেশিক সরকার কোন রাজনৈতিক দল গঠন করে ?',
#    nan],
#   ['প্রাদেশিক সরকার গঠনের পরে বঙ্গবন্ধু কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান প্রাদেশিক সরকার গঠনের পরে কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান কোন দফতরের মন্ত্রী হন প্রাদেশিক সরকার গঠনের পরে ?',
#    nan],
#   ['প্রাদেশিক সরকার গঠনের পরে বঙ্গবন্ধু কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান প্রাদেশিক সরকার গঠনের পরে কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান কোন দফতরের মন্ত্রী হন প্রাদেশিক সরকার গঠনের পরে ?',
#    nan],
#   ['প্রাদেশিক সরকার গঠনের পরে বঙ্গবন্ধু কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান প্রাদেশিক সরকার গঠনের পরে কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান কোন দফতরের মন্ত্রী হন প্রাদেশিক সরকার গঠনের পরে ?',
#    nan],
#   ['১৯৫৬ সালে শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    'প্রাদেশিক সরকার গঠনের পরে  শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে শিল্প ও বাণিজ্য, শ্রম  দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে  দুর্নীতি দমন বিষয়ক মন্ত্রী হন  কে?'],
#   ['১৯৫৬ সালে শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    'প্রাদেশিক সরকার গঠনের পরে  শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে শিল্প ও বাণিজ্য, শ্রম  দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে  দুর্নীতি দমন বিষয়ক মন্ত্রী হন  কে?'],
#   ['১৯৫৬ সালে শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    'প্রাদেশিক সরকার গঠনের পরে  শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে শিল্প ও বাণিজ্য, শ্রম  দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে  দুর্নীতি দমন বিষয়ক মন্ত্রী হন  কে?'],
#   [' কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    ' প্রাদেশিক সরকার গঠনের পরে কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    nan,
#    nan],
#   [' কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    ' প্রাদেশিক সরকার গঠনের পরে কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    nan,
#    nan],
#   [' কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    ' প্রাদেশিক সরকার গঠনের পরে কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে সামরিক শাসন জারি করা হয় ?',
#    'পূর্ব পাকিস্তানে সামরিক শাসন কবে জারি হয় ?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে সামরিক শাসন জারি করা হয় ?',
#    'পূর্ব পাকিস্তানে সামরিক শাসন কবে জারি হয় ?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে সামরিক শাসন জারি করা হয় ?',
#    'পূর্ব পাকিস্তানে সামরিক শাসন কবে জারি হয় ?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে রাজনীতি নিষিদ্ধ করা হয়?',
#    ' পাকিস্তানে কত সালে রাজনীতি নিষিদ্ধ করা হয়?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে রাজনীতি নিষিদ্ধ করা হয়?',
#    ' পাকিস্তানে কত সালে রাজনীতি নিষিদ্ধ করা হয়?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে রাজনীতি নিষিদ্ধ করা হয়?',
#    ' পাকিস্তানে কত সালে রাজনীতি নিষিদ্ধ করা হয়?',
#    nan,
#    nan],
#   [' মিথ্যা মামলায় জেল খাটতে হয় কাকে?',
#    ' কে মিথ্যা মামলায় জেল খাটে ?',
#    '১৯৬৩ সালে ভূয়া মামলায় জেল খাটে কে ?',
#    nan],
#   [' মিথ্যা মামলায় জেল খাটতে হয় কাকে?',
#    ' কে মিথ্যা মামলায় জেল খাটে ?',
#    '১৯৬৩ সালে ভূয়া মামলায় জেল খাটে কে ?',
#    nan],
#   [' মিথ্যা মামলায় জেল খাটতে হয় কাকে?',
#    ' কে মিথ্যা মামলায় জেল খাটে ?',
#    '১৯৬৩ সালে ভূয়া মামলায় জেল খাটে কে ?',
#    nan],
#   ['কত সাল পর্যন্ত  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কখন  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কোন সালে  শেখ মুজিবুর রহমানকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    nan],
#   ['কত সাল পর্যন্ত  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কখন  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কোন সালে  শেখ মুজিবুর রহমানকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    nan],
#   ['কত সাল পর্যন্ত  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কখন  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কোন সালে  শেখ মুজিবুর রহমানকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    nan],
#   ['কত সালে জেলের ভয়ে জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কোন সময়ে  জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কত সালে জেলের ভয়ে লিখিত দিয়ে  জ্যেষ্ঠ রাজনীতিবাদরা রাজনীতি ছেড়ে দেন ? ',
#    'সামরিক শাসন আসলে  সালে জেলের ভয়ে  রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন কত সালে  ? '],
#   ['কত সালে জেলের ভয়ে জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কোন সময়ে  জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কত সালে জেলের ভয়ে লিখিত দিয়ে  জ্যেষ্ঠ রাজনীতিবাদরা রাজনীতি ছেড়ে দেন ? ',
#    'সামরিক শাসন আসলে  সালে জেলের ভয়ে  রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন কত সালে  ? '],
#   ['কত সালে জেলের ভয়ে জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কোন সময়ে  জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কত সালে জেলের ভয়ে লিখিত দিয়ে  জ্যেষ্ঠ রাজনীতিবাদরা রাজনীতি ছেড়ে দেন ? ',
#    'সামরিক শাসন আসলে  সালে জেলের ভয়ে  রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন কত সালে  ? '],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয় কত সালে ?',
#    ' কত সালে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয়?',
#    'আওয়ামী লীগে নেতাদের বৈঠক ডাকা হয় কত কবে ?',
#    nan],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয় কত সালে ?',
#    ' কত সালে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয়?',
#    'আওয়ামী লীগে নেতাদের বৈঠক ডাকা হয় কত কবে ?',
#    nan],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয় কত সালে ?',
#    ' কত সালে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয়?',
#    'আওয়ামী লীগে নেতাদের বৈঠক ডাকা হয় কত কবে ?',
#    nan],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা কবে দেয়া হয়?',
#    'কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেয়া হয়?',
#    'শেখ মুজিব কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দিয়েছিলেন ?',
#    nan],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা কবে দেয়া হয়?',
#    'কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেয়া হয়?',
#    'শেখ মুজিব কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দিয়েছিলেন ?',
#    nan],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা কবে দেয়া হয়?',
#    'কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেয়া হয়?',
#    'শেখ মুজিব কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দিয়েছিলেন ?',
#    nan],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে  কে?',
#    'কোন নেতা আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে ?',
#    'কোন রাজনৈতিক নেতা আওয়ামী লীগের বড় নেতাদের  বৈঠক ডাকে ?',
#    nan],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে  কে?',
#    'কোন নেতা আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে ?',
#    'কোন রাজনৈতিক নেতা আওয়ামী লীগের বড় নেতাদের  বৈঠক ডাকে ?',
#    nan],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে  কে?',
#    'কোন নেতা আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে ?',
#    'কোন রাজনৈতিক নেতা আওয়ামী লীগের বড় নেতাদের  বৈঠক ডাকে ?',
#    nan],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন কে?',
#    'কে ঘোষণা দিয়ে আওয়ামী লীগকে পুনর্জীবিত করেন ?',
#    'আওয়ামী লীগকে পুনর্জীবিত করার ঘোষক কে?',
#    'কার ঘোষণায় আওয়ামী লীগ ৫ বছর পর  পুনর্জীবিত হয় ?'],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন কে?',
#    'কে ঘোষণা দিয়ে আওয়ামী লীগকে পুনর্জীবিত করেন ?',
#    'আওয়ামী লীগকে পুনর্জীবিত করার ঘোষক কে?',
#    'কার ঘোষণায় আওয়ামী লীগ ৫ বছর পর  পুনর্জীবিত হয় ?'],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন কে?',
#    'কে ঘোষণা দিয়ে আওয়ামী লীগকে পুনর্জীবিত করেন ?',
#    'আওয়ামী লীগকে পুনর্জীবিত করার ঘোষক কে?',
#    'কার ঘোষণায় আওয়ামী লীগ ৫ বছর পর  পুনর্জীবিত হয় ?'],
#   ['বঙ্গবন্ধু কোথায় আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন ?',
#    '১৯৬৪ সালে শেখ মুজিবুর এর সাথে কোথায় আওয়ামী নেতাদের বৈঠক হয় ?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কোথায় আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন ?',
#    '১৯৬৪ সালে শেখ মুজিবুর এর সাথে কোথায় আওয়ামী নেতাদের বৈঠক হয় ?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কোথায় আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন ?',
#    '১৯৬৪ সালে শেখ মুজিবুর এর সাথে কোথায় আওয়ামী নেতাদের বৈঠক হয় ?',
#    nan,
#    nan],
#   ['কার হাত ধরে আওয়ামী লীগ আবারো রাজপথে আসে ?',
#    'আওয়ামী লিগের অচল অবস্থা কাটিয়ে তুলে রাজ পথে ফিরিয়ে আনেন কে ?',
#    'কে অচল আওয়ামী লিগকে পুনরায় উজ্জীবিত করেন ?',
#    nan],
#   ['কার হাত ধরে আওয়ামী লীগ আবারো রাজপথে আসে ?',
#    'আওয়ামী লিগের অচল অবস্থা কাটিয়ে তুলে রাজ পথে ফিরিয়ে আনেন কে ?',
#    'কে অচল আওয়ামী লিগকে পুনরায় উজ্জীবিত করেন ?',
#    nan],
#   ['কার হাত ধরে আওয়ামী লীগ আবারো রাজপথে আসে ?',
#    'আওয়ামী লিগের অচল অবস্থা কাটিয়ে তুলে রাজ পথে ফিরিয়ে আনেন কে ?',
#    'কে অচল আওয়ামী লিগকে পুনরায় উজ্জীবিত করেন ?',
#    nan],
#   [' শেখ মুজিবুর রহমানের বাসভবন কোথায় ছিল ?',
#    'বঙ্গবন্ধুর বাসভবন কোথায় ?',
#    nan,
#    nan],
#   [' শেখ মুজিবুর রহমানের বাসভবন কোথায় ছিল ?',
#    'বঙ্গবন্ধুর বাসভবন কোথায় ?',
#    nan,
#    nan],
#   [' শেখ মুজিবুর রহমানের বাসভবন কোথায় ছিল ?',
#    'বঙ্গবন্ধুর বাসভবন কোথায় ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালে কত বছর পরে আওয়ামী লীগ পুনরায় রাজ পথে নামে ?',
#    'অচল আওয়ামী লীগ কত বছর পর ১৯৬৪ সালে রাস্তায় নামে ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালে কত বছর পরে আওয়ামী লীগ পুনরায় রাজ পথে নামে ?',
#    'অচল আওয়ামী লীগ কত বছর পর ১৯৬৪ সালে রাস্তায় নামে ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালে কত বছর পরে আওয়ামী লীগ পুনরায় রাজ পথে নামে ?',
#    'অচল আওয়ামী লীগ কত বছর পর ১৯৬৪ সালে রাস্তায় নামে ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালেে কার বিরুদ্ধে জোরদার আন্দোলন হয় ?',
#    ' কার বিরুদ্ধে ১৯৬৪ সালেে জোরদার আন্দোলন হয় ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালেে কার বিরুদ্ধে জোরদার আন্দোলন হয় ?',
#    ' কার বিরুদ্ধে ১৯৬৪ সালেে জোরদার আন্দোলন হয় ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালেে কার বিরুদ্ধে জোরদার আন্দোলন হয় ?',
#    ' কার বিরুদ্ধে ১৯৬৪ সালেে জোরদার আন্দোলন হয় ?',
#    nan,
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    '১৯৬৪ সালে  আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    ' আইয়ুববিরোধী আন্দোলনের  নেতা কে ছিলেন ?',
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    '১৯৬৪ সালে  আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    ' আইয়ুববিরোধী আন্দোলনের  নেতা কে ছিলেন ?',
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    '১৯৬৪ সালে  আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    ' আইয়ুববিরোধী আন্দোলনের  নেতা কে ছিলেন ?',
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলন হয় কত সালে ?',
#    'কবে আইয়ুববিরোধী আন্দোলন হয়  ?',
#    ' আইয়ুববিরোধী আন্দোলনের সময় কাল কত  সালে ?',
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলন হয় কত সালে ?',
#    'কবে আইয়ুববিরোধী আন্দোলন হয়  ?',
#    ' আইয়ুববিরোধী আন্দোলনের সময় কাল কত  সালে ?',
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলন হয় কত সালে ?',
#    'কবে আইয়ুববিরোধী আন্দোলন হয়  ?',
#    ' আইয়ুববিরোধী আন্দোলনের সময় কাল কত  সালে ?',
#    nan],
#   ['১৯৬৪ সালের কত তারিখে  ধানমন্ডির  বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    'নিজ  বাসভবনে আওয়ামী লীগের  নেতাদের নিয়ে কবে  বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালের কত তারিখে  ধানমন্ডির  বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    'নিজ  বাসভবনে আওয়ামী লীগের  নেতাদের নিয়ে কবে  বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালের কত তারিখে  ধানমন্ডির  বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    'নিজ  বাসভবনে আওয়ামী লীগের  নেতাদের নিয়ে কবে  বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    nan,
#    nan],
#   ['১৯৬৬ সালে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলো কোথায় ১৯৬৬ সালে  সম্মেলন করেছিল  ?',
#    nan],
#   ['১৯৬৬ সালে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলো কোথায় ১৯৬৬ সালে  সম্মেলন করেছিল  ?',
#    nan],
#   ['১৯৬৬ সালে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলো কোথায় ১৯৬৬ সালে  সম্মেলন করেছিল  ?',
#    nan],
#   ['কত সালে লাহোরে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কত সালে  হয়েছিলো ?',
#    'লাহোরে কত সালে  বিরোধী দলগুলোর সম্মেলন  হয়েছিলো ?',
#    nan],
#   ['কত সালে লাহোরে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কত সালে  হয়েছিলো ?',
#    'লাহোরে কত সালে  বিরোধী দলগুলোর সম্মেলন  হয়েছিলো ?',
#    nan],
#   ['কত সালে লাহোরে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কত সালে  হয়েছিলো ?',
#    'লাহোরে কত সালে  বিরোধী দলগুলোর সম্মেলন  হয়েছিলো ?',
#    nan],
#   ['ছয় দফা আন্দোলনের শিরোনাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের আরেক নাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের মুল কথা  কী ছিল ? ',
#    'ছয় দফা আন্দোলনকে কী নামে ডাকা হয়  ? '],
#   ['ছয় দফা আন্দোলনের শিরোনাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের আরেক নাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের মুল কথা  কী ছিল ? ',
#    'ছয় দফা আন্দোলনকে কী নামে ডাকা হয়  ? '],
#   ['ছয় দফা আন্দোলনের শিরোনাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের আরেক নাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের মুল কথা  কী ছিল ? ',
#    'ছয় দফা আন্দোলনকে কী নামে ডাকা হয়  ? '],
#   ['কোন আন্দোলন কে আমাদের বাঁচার দাবি বলা হয় ?',
#    ' আমাদের বাঁচার দাবি বলা হয় কোন আন্দোলনকে ?',
#    'লাাহোরে কোন আন্দোলন শুরু হয় ?',
#    nan],
#   ['কোন আন্দোলন কে আমাদের বাঁচার দাবি বলা হয় ?',
#    ' আমাদের বাঁচার দাবি বলা হয় কোন আন্দোলনকে ?',
#    'লাাহোরে কোন আন্দোলন শুরু হয় ?',
#    nan],
#   ['কোন আন্দোলন কে আমাদের বাঁচার দাবি বলা হয় ?',
#    ' আমাদের বাঁচার দাবি বলা হয় কোন আন্দোলনকে ?',
#    'লাাহোরে কোন আন্দোলন শুরু হয় ?',
#    nan],
#   ['ছয় দফা দাবি পেশ করেন কে ? ',
#    'ছয় দফা আন্দোলনের সুত্রপাত কে ঘটান  ? ',
#    'ছয় দফা দাবির নেতৃত্ব করেন কে ? ',
#    nan],
#   ['ছয় দফা দাবি পেশ করেন কে ? ',
#    'ছয় দফা আন্দোলনের সুত্রপাত কে ঘটান  ? ',
#    'ছয় দফা দাবির নেতৃত্ব করেন কে ? ',
#    nan],
#   ['ছয় দফা দাবি পেশ করেন কে ? ',
#    'ছয় দফা আন্দোলনের সুত্রপাত কে ঘটান  ? ',
#    'ছয় দফা দাবির নেতৃত্ব করেন কে ? ',
#    nan],
#   [' শেখ মুজিবুর রহমান কবে আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    '  কবে বঙ্গবন্ধু শেখ মুজিবুর রহমান আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    ' কবে আওয়ামী লীগের সভাপতি হিসেবে দায়িত্ব পান  শেখ মুজিবুর রহমান ?',
#    nan],
#   [' শেখ মুজিবুর রহমান কবে আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    '  কবে বঙ্গবন্ধু শেখ মুজিবুর রহমান আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    ' কবে আওয়ামী লীগের সভাপতি হিসেবে দায়িত্ব পান  শেখ মুজিবুর রহমান ?',
#    nan],
#   [' শেখ মুজিবুর রহমান কবে আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    '  কবে বঙ্গবন্ধু শেখ মুজিবুর রহমান আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    ' কবে আওয়ামী লীগের সভাপতি হিসেবে দায়িত্ব পান  শেখ মুজিবুর রহমান ?',
#    nan],
#   ['ছয় দফা দাবি আদায়ে ৩ মাসে কতটি জনসভা করা হয় ১৯৬৬ সালে ?',
#    'ছয় দফা দাবি আদায়ে আওয়ামী লীগ কতটি জনসভা করে  ১৯৬৬ সালে ?',
#    nan,
#    nan],
#   ['ছয় দফা দাবি আদায়ে ৩ মাসে কতটি জনসভা করা হয় ১৯৬৬ সালে ?',
#    'ছয় দফা দাবি আদায়ে আওয়ামী লীগ কতটি জনসভা করে  ১৯৬৬ সালে ?',
#    nan,
#    nan],
#   ['ছয় দফা দাবি আদায়ে ৩ মাসে কতটি জনসভা করা হয় ১৯৬৬ সালে ?',
#    'ছয় দফা দাবি আদায়ে আওয়ামী লীগ কতটি জনসভা করে  ১৯৬৬ সালে ?',
#    nan,
#    nan],
#   ['ছয় দফা দাবি চলাকালীন কত তারিখ বঙ্গবন্ধু চূড়ান্তভাবে গ্রেফতার হয়?',
#    'ছয় দফা দাবি চলাকালীন কবে শেখ মুজিবকে গ্রেফতার হয়?',
#    nan,
#    nan],
#   ['ছয় দফা দাবি চলাকালীন কত তারিখ বঙ্গবন্ধু চূড়ান্তভাবে গ্রেফতার হয়?',
#    'ছয় দফা দাবি চলাকালীন কবে শেখ মুজিবকে গ্রেফতার হয়?',
#    nan,
#    nan],
#   ['ছয় দফা দাবি চলাকালীন কত তারিখ বঙ্গবন্ধু চূড়ান্তভাবে গ্রেফতার হয়?',
#    'ছয় দফা দাবি চলাকালীন কবে শেখ মুজিবকে গ্রেফতার হয়?',
#    nan,
#    nan],
#   ['৬ দফার সমর্থনে ১৯৬৬ এঁর কত তারিখ ছাত্ররা রাস্তায় নামে ?',
#    'ছাত্ররা কবে ৬ দফা আদায় এ রাস্তায় নামে ?',
#    '৬ দফার সমরথনে কবে জনগন রাস্তায় নামে ?',
#    nan],
#   ['৬ দফার সমর্থনে ১৯৬৬ এঁর কত তারিখ ছাত্ররা রাস্তায় নামে ?',
#    'ছাত্ররা কবে ৬ দফা আদায় এ রাস্তায় নামে ?',
#    '৬ দফার সমরথনে কবে জনগন রাস্তায় নামে ?',
#    nan],
#   ['৬ দফার সমর্থনে ১৯৬৬ এঁর কত তারিখ ছাত্ররা রাস্তায় নামে ?',
#    'ছাত্ররা কবে ৬ দফা আদায় এ রাস্তায় নামে ?',
#    '৬ দফার সমরথনে কবে জনগন রাস্তায় নামে ?',
#    nan],
#   ['কে ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত করেন ? ',
#    'ব্যাঙালির অধিকার ও ৬ দফা এক সত্তায় পরিনত করেন কে ?',
#    nan,
#    nan],
#   ['কে ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত করেন ? ',
#    'ব্যাঙালির অধিকার ও ৬ দফা এক সত্তায় পরিনত করেন কে ?',
#    nan,
#    nan],
#   ['কে ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত করেন ? ',
#    'ব্যাঙালির অধিকার ও ৬ দফা এক সত্তায় পরিনত করেন কে ?',
#    nan,
#    nan],
#   [' ‘১২টার পরে খবর পাকাপাকি পাওয়া গেল যে, হরতাল হয়েছে। জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে। তারা ছয় দফা সমর্থন করে আর মুক্তি চায়। বাঁচতে চায়, খেতে চায়, ব্যক্তিস্বাধীনতা চায়, শ্রমিকের ন্যায্য দাবি, কৃষকদের বাঁচার দাবি তারা চায়, এর প্রমাণ এই হরতালের মধ্যে হয়েই গেল।’ এইটা কত তারিখ সম্বন্ধে বলা হয়েছে ? ',
#    '১৯৬৬ সালের কতও তারিখ জনগন হরতাল পালন করে ? ',
#    nan,
#    nan],
#   [' ‘১২টার পরে খবর পাকাপাকি পাওয়া গেল যে, হরতাল হয়েছে। জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে। তারা ছয় দফা সমর্থন করে আর মুক্তি চায়। বাঁচতে চায়, খেতে চায়, ব্যক্তিস্বাধীনতা চায়, শ্রমিকের ন্যায্য দাবি, কৃষকদের বাঁচার দাবি তারা চায়, এর প্রমাণ এই হরতালের মধ্যে হয়েই গেল।’ এইটা কত তারিখ সম্বন্ধে বলা হয়েছে ? ',
#    '১৯৬৬ সালের কতও তারিখ জনগন হরতাল পালন করে ? ',
#    nan,
#    nan],
#   [' ‘১২টার পরে খবর পাকাপাকি পাওয়া গেল যে, হরতাল হয়েছে। জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে। তারা ছয় দফা সমর্থন করে আর মুক্তি চায়। বাঁচতে চায়, খেতে চায়, ব্যক্তিস্বাধীনতা চায়, শ্রমিকের ন্যায্য দাবি, কৃষকদের বাঁচার দাবি তারা চায়, এর প্রমাণ এই হরতালের মধ্যে হয়েই গেল।’ এইটা কত তারিখ সম্বন্ধে বলা হয়েছে ? ',
#    '১৯৬৬ সালের কতও তারিখ জনগন হরতাল পালন করে ? ',
#    nan,
#    nan],
#   ['১৯৬৬ সালের কয় তারিখ হরতাল পালন করা হয় ?',
#    'কবে হারতাল পালন করা হয় ?',
#    '৬ দফার দাবিতে কবে হারতাল পালন করা হয় ?',
#    nan],
#   ['১৯৬৬ সালের কয় তারিখ হরতাল পালন করা হয় ?',
#    'কবে হারতাল পালন করা হয় ?',
#    '৬ দফার দাবিতে কবে হারতাল পালন করা হয় ?',
#    nan],
#   ['১৯৬৬ সালের কয় তারিখ হরতাল পালন করা হয় ?',
#    'কবে হারতাল পালন করা হয় ?',
#    '৬ দফার দাবিতে কবে হারতাল পালন করা হয় ?',
#    nan],
#   ['আগরতলা মামলার প্রধান আসামি কে ?',
#    'আগড়তলা ষড়যন্ত্র মামলার প্রধান আসামি কে ?',
#    nan,
#    nan],
#   ['আগরতলা মামলার প্রধান আসামি কে ?',
#    'আগড়তলা ষড়যন্ত্র মামলার প্রধান আসামি কে ?',
#    nan,
#    nan],
#   ['আগরতলা মামলার প্রধান আসামি কে ?',
#    'আগড়তলা ষড়যন্ত্র মামলার প্রধান আসামি কে ?',
#    nan,
#    nan],
#   ['আগরতলা মামলা কত সালে দায়ের করা হয় ?',
#    'কবে আগরতলা ষড়যন্ত্র মামলা দেওয়া হয় ?',
#    'আগরতলাা মামলা কত সালের কত তারিখ দায়ের করা হয় ?',
#    'আগরতলা মামলা দায়ের করার তারিখ কত ?'],
#   ['আগরতলা মামলা কত সালে দায়ের করা হয় ?',
#    'কবে আগরতলা ষড়যন্ত্র মামলা দেওয়া হয় ?',
#    'আগরতলাা মামলা কত সালের কত তারিখ দায়ের করা হয় ?',
#    'আগরতলা মামলা দায়ের করার তারিখ কত ?'],
#   ['আগরতলা মামলা কত সালে দায়ের করা হয় ?',
#    'কবে আগরতলা ষড়যন্ত্র মামলা দেওয়া হয় ?',
#    'আগরতলাা মামলা কত সালের কত তারিখ দায়ের করা হয় ?',
#    'আগরতলা মামলা দায়ের করার তারিখ কত ?'],
#   ['আগরতলা মামলার সময় শেখ মুজিব কোথায় ছিলেন?',
#    'শেখ মুজিব কোথায় ছিলেন যখন ষড়যন্ত্র মামলা দায়ের করা হয় ?',
#    nan,
#    nan],
#   ['আগরতলা মামলার সময় শেখ মুজিব কোথায় ছিলেন?',
#    'শেখ মুজিব কোথায় ছিলেন যখন ষড়যন্ত্র মামলা দায়ের করা হয় ?',
#    nan,
#    nan],
#   ['আগরতলা মামলার সময় শেখ মুজিব কোথায় ছিলেন?',
#    'শেখ মুজিব কোথায় ছিলেন যখন ষড়যন্ত্র মামলা দায়ের করা হয় ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কত সালে হয় ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কবে হয় ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কত সালে হয় ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কবে হয় ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কত সালে হয় ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কবে হয় ?',
#    nan,
#    nan],
#   ['৬ দফার সমর্থনে ছাত্ররা কত দফা দাবি জানায় ?',
#    '৬ দফা সফল করতে কত দফা দাবি জানানো হয় ?',
#    nan,
#    nan],
#   ['৬ দফার সমর্থনে ছাত্ররা কত দফা দাবি জানায় ?',
#    '৬ দফা সফল করতে কত দফা দাবি জানানো হয় ?',
#    nan,
#    nan],
#   ['৬ দফার সমর্থনে ছাত্ররা কত দফা দাবি জানায় ?',
#    '৬ দফা সফল করতে কত দফা দাবি জানানো হয় ?',
#    nan,
#    nan],
#   [' ১১ দফা দাবি কত সালে ঘোষণা করা হয় ?',
#    'কবে ১১ দফা দাবি জানায় এই দেশের মানুষ ?',
#    '৬ দফার সমর্থনে কবে ১১ দফা ঘোষণা করে ?',
#    nan],
#   [' ১১ দফা দাবি কত সালে ঘোষণা করা হয় ?',
#    'কবে ১১ দফা দাবি জানায় এই দেশের মানুষ ?',
#    '৬ দফার সমর্থনে কবে ১১ দফা ঘোষণা করে ?',
#    nan],
#   [' ১১ দফা দাবি কত সালে ঘোষণা করা হয় ?',
#    'কবে ১১ দফা দাবি জানায় এই দেশের মানুষ ?',
#    '৬ দফার সমর্থনে কবে ১১ দফা ঘোষণা করে ?',
#    nan],
#   ['কোন ঘটনার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা ?',
#    'কোন ঘটনাকে কেন্দ্র করে  ১১ দফা ঘোষণা করা হয়  ?',
#    nan,
#    nan],
#   ['কোন ঘটনার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা ?',
#    'কোন ঘটনাকে কেন্দ্র করে  ১১ দফা ঘোষণা করা হয়  ?',
#    nan,
#    nan],
#   ['কোন ঘটনার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা ?',
#    'কোন ঘটনাকে কেন্দ্র করে  ১১ দফা ঘোষণা করা হয়  ?',
#    nan,
#    nan],
#   ['কারা ১১ দফা দাবি জানায় ?', '১১ দফা দাবি কারা ঘোষণা করেছিল ?', nan, nan],
#   ['কারা ১১ দফা দাবি জানায় ?', '১১ দফা দাবি কারা ঘোষণা করেছিল ?', nan, nan],
#   ['কারা ১১ দফা দাবি জানায় ?', '১১ দফা দাবি কারা ঘোষণা করেছিল ?', nan, nan],
#   ['আগরতলা মামলা কত সালে তুলে নেওয়া হয় ?',
#    'কবে ষড়যন্ত্র মামলা তুলে নেওয়া হয় ?',
#    'মিথ্যা মামলা কবে ফিরিয়ে নেওয়া হয় ?',
#    nan],
#   ['আগরতলা মামলা কত সালে তুলে নেওয়া হয় ?',
#    'কবে ষড়যন্ত্র মামলা তুলে নেওয়া হয় ?',
#    'মিথ্যা মামলা কবে ফিরিয়ে নেওয়া হয় ?',
#    nan],
#   ['আগরতলা মামলা কত সালে তুলে নেওয়া হয় ?',
#    'কবে ষড়যন্ত্র মামলা তুলে নেওয়া হয় ?',
#    'মিথ্যা মামলা কবে ফিরিয়ে নেওয়া হয় ?',
#    nan],
#   ["রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' শিরোনামটি কোন মামলার ছিল?",
#    "কোন মামলার শিরোনাম ছিল 'রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' ?",
#    nan,
#    nan],
#   ["রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' শিরোনামটি কোন মামলার ছিল?",
#    "কোন মামলার শিরোনাম ছিল 'রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' ?",
#    nan,
#    nan],
#   ["রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' শিরোনামটি কোন মামলার ছিল?",
#    "কোন মামলার শিরোনাম ছিল 'রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' ?",
#    nan,
#    nan],
#   ['আগরতলা মাামলার শিরোনাম কি ছিল ?',
#    'ষড়যন্ত্র মামলা কি নামে পরিচিত ছিল ?',
#    nan,
#    nan],
#   ['আগরতলা মাামলার শিরোনাম কি ছিল ?',
#    'ষড়যন্ত্র মামলা কি নামে পরিচিত ছিল ?',
#    nan,
#    nan],
#   ['আগরতলা মাামলার শিরোনাম কি ছিল ?',
#    'ষড়যন্ত্র মামলা কি নামে পরিচিত ছিল ?',
#    nan,
#    nan],
#   ['কোন ঘটনার জন্য আগরতলা মামলা তুলে নেওয়া হয় ?',
#    'কি কারনে আগরতলা মামলা প্রত্যাহার করা হয় ? ',
#    'ষড়যন্ত্র মামলা তুলে নেওয়ার পিছনে কি কারন ছিল ? ',
#    nan],
#   ['কোন ঘটনার জন্য আগরতলা মামলা তুলে নেওয়া হয় ?',
#    'কি কারনে আগরতলা মামলা প্রত্যাহার করা হয় ? ',
#    'ষড়যন্ত্র মামলা তুলে নেওয়ার পিছনে কি কারন ছিল ? ',
#    nan],
#   ['কোন ঘটনার জন্য আগরতলা মামলা তুলে নেওয়া হয় ?',
#    'কি কারনে আগরতলা মামলা প্রত্যাহার করা হয় ? ',
#    'ষড়যন্ত্র মামলা তুলে নেওয়ার পিছনে কি কারন ছিল ? ',
#    nan],
#   ['কবে বঙ্গবন্ধু প্যারোলে মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় ?',
#    'শেখ মুজিবের জেল থেকে  মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় কবে ',
#    nan,
#    nan],
#   ['কবে বঙ্গবন্ধু প্যারোলে মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় ?',
#    'শেখ মুজিবের জেল থেকে  মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় কবে ',
#    nan,
#    nan],
#   ['কবে বঙ্গবন্ধু প্যারোলে মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় ?',
#    'শেখ মুজিবের জেল থেকে  মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় কবে ',
#    nan,
#    nan],
#   ['কি কারনে জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কিসের জন্য  জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কেনো  জনগন গণআন্দোলন করে ১৯৬৯ সালে ?',
#    nan],
#   ['কি কারনে জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কিসের জন্য  জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কেনো  জনগন গণআন্দোলন করে ১৯৬৯ সালে ?',
#    nan],
#   ['কি কারনে জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কিসের জন্য  জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কেনো  জনগন গণআন্দোলন করে ১৯৬৯ সালে ?',
#    nan],
#   ['ডাকসু কবে শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    'কবে শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    'সোহরাওয়ার্দী উদ্যানে কবে মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan],
#   ['ডাকসু কবে শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    'কবে শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    'সোহরাওয়ার্দী উদ্যানে কবে মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan],
#   ['ডাকসু কবে শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    'কবে শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    'সোহরাওয়ার্দী উদ্যানে কবে মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan],
#   ['কোথায় ডাকসু  শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    '১৯৬৯ সালে কোথায় শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan,
#    nan],
#   ['কোথায় ডাকসু  শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    '১৯৬৯ সালে কোথায় শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan,
#    nan],
#   ['কোথায় ডাকসু  শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    '১৯৬৯ সালে কোথায় শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan,
#    nan],
#   ['রেসকোর্স ময়দানের বর্তমান নাম কি ?',
#    'রেসকোর্স ময়দানের আগের  নাম কি ?',
#    nan,
#    nan],
#   ['রেসকোর্স ময়দানের বর্তমান নাম কি ?',
#    'রেসকোর্স ময়দানের আগের  নাম কি ?',
#    nan,
#    nan],
#   ['রেসকোর্স ময়দানের বর্তমান নাম কি ?',
#    'রেসকোর্স ময়দানের আগের  নাম কি ?',
#    nan,
#    nan],
#   ['সোহরাওয়ার্দী উদ্যানের পুরাতন নাম কি ?',
#    'সোহরাওয়ার্দী উদ্যানের পূর্ব নাম কি ?',
#    nan,
#    nan],
#   ['সোহরাওয়ার্দী উদ্যানের পুরাতন নাম কি ?',
#    'সোহরাওয়ার্দী উদ্যানের পূর্ব নাম কি ?',
#    nan,
#    nan],
#   ['সোহরাওয়ার্দী উদ্যানের পুরাতন নাম কি ?',
#    'সোহরাওয়ার্দী উদ্যানের পূর্ব নাম কি ?',
#    nan,
#    nan],
#   ["শেখ মুজিবকে কবে 'বঙ্গবন্ধু' উপাধিতে ভূষিত করা হয়? ",
#    " কবে 'বঙ্গবন্ধু' উপাধি দেওয়া  হয়? ",
#    nan,
#    nan],
#   ["শেখ মুজিবকে কবে 'বঙ্গবন্ধু' উপাধিতে ভূষিত করা হয়? ",
#    " কবে 'বঙ্গবন্ধু' উপাধি দেওয়া  হয়? ",
#    nan,
#    nan],
#   ["শেখ মুজিবকে কবে 'বঙ্গবন্ধু' উপাধিতে ভূষিত করা হয়? ",
#    " কবে 'বঙ্গবন্ধু' উপাধি দেওয়া  হয়? ",
#    nan,
#    nan],
#   ['কবে স্বৈরাচার প্রধান জেনারেল আইয়ুব খান পদত্যাগে বাধ্য হয় ?',
#    ' জেনারেল আইয়ুব খান কবে পদত্যাগ করেন  ?',
#    ' জেনারেল আইয়ুব খান কবে ক্ষমতা  ছাড়েন  ?',
#    ' জেনারেল আইয়ুব খান কবে গদি  ছাড়েন  ?'],
#   ['কবে স্বৈরাচার প্রধান জেনারেল আইয়ুব খান পদত্যাগে বাধ্য হয় ?',
#    ' জেনারেল আইয়ুব খান কবে পদত্যাগ করেন  ?',
#    ' জেনারেল আইয়ুব খান কবে ক্ষমতা  ছাড়েন  ?',
#    ' জেনারেল আইয়ুব খান কবে গদি  ছাড়েন  ?'],
#   ['কার দাবির মুখে আইয়ুব খান পদত্যাগ করেন ?',
#    'কে  আইয়ুব খানকে  পদত্যাগ করতে বাধ্য করেন ?',
#    nan,
#    nan],
#   ['কার দাবির মুখে আইয়ুব খান পদত্যাগ করেন ?',
#    'কে  আইয়ুব খানকে  পদত্যাগ করতে বাধ্য করেন ?',
#    nan,
#    nan],
#   ['আইয়ুব খানের পরে কে ক্ষমতায় আসেন ?',
#    'আইয়ুব খানের ক্ষমতাচ্যুত হওয়ার পরে কে ক্ষমতায় আসেন ? ',
#    nan,
#    nan],
#   ['আইয়ুব খানের পরে কে ক্ষমতায় আসেন ?',
#    'আইয়ুব খানের ক্ষমতাচ্যুত হওয়ার পরে কে ক্ষমতায় আসেন ? ',
#    nan,
#    nan],
#   ['কে ক্ষমতা নেওয়ার পরে সামরিক শাসন জারি করে ?',
#    'সামরিক শাসন জারি করেন কে ?',
#    'সামরিক শাসনের পথে হাঁটেন কে ?',
#    nan],
#   ['কে ক্ষমতা নেওয়ার পরে সামরিক শাসন জারি করে ?',
#    'সামরিক শাসন জারি করেন কে ?',
#    'সামরিক শাসনের পথে হাঁটেন কে ?',
#    nan],
#   ['ইয়াহিয়া খান কবে ক্ষমতা লাভ করে ?',
#    'কবে ইয়াহিয়া খান ক্ষমতা লাভ করে ?',
#    'ইয়াহিয়া খান ক্ষমতায় আসেন কবে  ?',
#    nan],
#   ['ইয়াহিয়া খান কবে ক্ষমতা লাভ করে ?',
#    'কবে ইয়াহিয়া খান ক্ষমতা লাভ করে ?',
#    'ইয়াহিয়া খান ক্ষমতায় আসেন কবে  ?',
#    nan],
#   ['ইয়াাহিয়া খান কার পরে ক্ষমতায় আসেন ?',
#    'ইয়াহিয়া খানের আগে ক্ষমতায় কে ছিল  ?',
#    'ইয়াহিয়া খান পূর্ব শাসক  কে ছিল  ?',
#    nan],
#   ['জাতীয় নির্বাচন কবে হওয়ার কথা ?', nan, nan, nan],
#   ['জাতীয় নির্বাচন কবে হওয়ার কথা ?', nan, nan, nan],
#   ['কে জাতীয় নির্বাচন অনুষ্ঠানের প্রতিশ্রুতি দেয়?',
#    'জাতীয় নির্বাচন হওয়ার কথা কে জানান ?',
#    nan,
#    nan],
#   ['কে জাতীয় নির্বাচন অনুষ্ঠানের প্রতিশ্রুতি দেয়?',
#    'জাতীয় নির্বাচন হওয়ার কথা কে জানান ?',
#    nan,
#    nan],
#   ['এই দেশের নাম বাংলাদেশ রাখেন কে ?',
#    'বাংলাদেশ নামকরন করেন কে ?',
#    ' কে বাংলাদেশ রাখেন এই দেশের নাম ?',
#    nan],
#   ['এই দেশের নাম বাংলাদেশ রাখেন কে ?',
#    'বাংলাদেশ নামকরন করেন কে ?',
#    ' কে বাংলাদেশ রাখেন এই দেশের নাম ?',
#    nan],
#   ['এই দেশের নাম বাংলাদেশ রাখেন কে ?',
#    'বাংলাদেশ নামকরন করেন কে ?',
#    ' কে বাংলাদেশ রাখেন এই দেশের নাম ?',
#    nan],
#   ['কত তারিখে বাংলাদেশ নামকরন করা হয় ?',
#    'বাংলাদেশ নামকরন করা হয় কবে  ?',
#    'কবে বাংলাদেশ নামটি আসে ?',
#    nan],
#   ['কত তারিখে বাংলাদেশ নামকরন করা হয় ?',
#    'বাংলাদেশ নামকরন করা হয় কবে  ?',
#    'কবে বাংলাদেশ নামটি আসে ?',
#    nan],
#   ['কত তারিখে বাংলাদেশ নামকরন করা হয় ?',
#    'বাংলাদেশ নামকরন করা হয় কবে  ?',
#    'কবে বাংলাদেশ নামটি আসে ?',
#    nan],
#   [' কবে হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল ?',
#    'হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল  কত তারিখ?',
#    'সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী কবে?',
#    nan],
#   [' কবে হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল ?',
#    'হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল  কত তারিখ?',
#    'সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী কবে?',
#    nan],
#   ['"একমাত্র ‘বঙ্গোপসাগর’ ছাড়া আর কোনও কিছুর নামের সঙ্গে ‘বাংলা’ কথাটির অস্তিত্ব খুঁজিয়া পাওয়া যায় নাই।"-উক্তিতি কার ?\n',
#    '"আজ হইতে পাকিস্তানের পূর্বাঞ্চলীয় প্রদেশটির নাম ‘পূর্ব পাকিস্তান’ এর পরিবর্তে শুধুমাত্র ‘বাংলাদেশ’।\'- উক্তিটি কার ?\n',
#    nan,
#    nan],
#   ['"একমাত্র ‘বঙ্গোপসাগর’ ছাড়া আর কোনও কিছুর নামের সঙ্গে ‘বাংলা’ কথাটির অস্তিত্ব খুঁজিয়া পাওয়া যায় নাই।"-উক্তিতি কার ?\n',
#    '"আজ হইতে পাকিস্তানের পূর্বাঞ্চলীয় প্রদেশটির নাম ‘পূর্ব পাকিস্তান’ এর পরিবর্তে শুধুমাত্র ‘বাংলাদেশ’।\'- উক্তিটি কার ?\n',
#    nan,
#    nan],
#   ['"একমাত্র ‘বঙ্গোপসাগর’ ছাড়া আর কোনও কিছুর নামের সঙ্গে ‘বাংলা’ কথাটির অস্তিত্ব খুঁজিয়া পাওয়া যায় নাই।"-উক্তিতি কার ?\n',
# ...
#    'কোথায় গিয়ে শেখ মুজিব মনে-প্রাণে ইংরেজ শাসনবিরোধী হয়ে ওঠেন ?'],
#   ['কৈশোরে বঙ্গবন্ধু কার ভক্ত ছিলেন ?',
#    'মুজিব কৈশরে কার ভক্তে পরিনত হন ?',
#    nan,
#    nan]],
#  'হামিদ মাস্টার': [['হামিদ মাস্টার কে ছিলেন ?',
#    'কে ছিলেন হামিদ মাস্টার  ?',
#    'হামিদ মাস্টারের পরিচয় কি ?',
#    'হামিদ মাস্টারের সাথে বঙ্গবন্ধুর কি সম্পর্ক? '],
#   ['বঙ্গবন্ধুর গৃহশিক্ষকের নাম কি ছিলো ?',
#    'বঙ্গবন্ধুর লজিং মাস্টারের নাম কি ছিলো ?',
#    nan,
#    nan]],
#  'এ কে ফজলুল হক ': [['১৯৩৮ সালে অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    'বঙ্গবন্ধু গোপালগঞ্জ মিশন স্কুলের ছাত্র থাকা অবস্থায় অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    '১৯৩৮ সালে বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    nan],
#   ['১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন বঙ্গবন্ধু কোন স্কুলের ছাত্র ছিলেন?',
#    '১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন শেখ মুজিব কোন স্কুলে পড়তেন?',
#    'শেখ মুজিব কোন স্কুলের ছাত্র ছিলেন?',
#    'শেখ মুজিব কোন স্কুলে পড়তেন?'],
#   ['স্কুলের ছাদ মেরামতের জন্য শেরে বাংলা কত টাকা মঞ্জুর করেন?',
#    'স্কুলের ছাদ মেরামতের জন্য অখণ্ড বাংলার মুখ্যমন্ত্রী কত টাকা মঞ্জুর করেন?',
#    'শেরে বাংলা ছাদ মেরামত করতে কত টাকা দিয়েছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কারা এসেছিলেন?',
#    'শেখ মুজিব যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কোন কোন রাজনৈতিক ব্যক্তিবর্গ এসেছিলেন?',
#    'মুজিবদের স্কুলে কে কে পরিদর্শনে গেছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে স্কুলের কোন কোন সমস্যাগুলো তুলে ধরেন?',
#    'বঙ্গবন্ধু ও তার বন্ধুরা শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে স্কুলের কোন কোন সমস্যাগুলো তুলে ধরেন?',
#    'শেখ মুজিব ও তার বন্ধুরা শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে কি কি দাবি তুলে ধরেন?',
#    nan]],
#  'হোসেন শহীদ সোহরাওয়ার্দী': [['১৯৩৯ সালে কলকাতায় গিয়ে শেখ মুজিবুর রহমান কার সঙ্গে সাক্ষাৎ করেন ?',
#    'কলকাতায় গিয়ে শেখ মুজিবুর রহমান কার সঙ্গে দেখা করেন ?',
#    'কলকাতায় কার সাথে দেখা করেন শেখ মুজিব?',
#    nan],
#   ['কার সঙ্গে বঙ্গবন্ধুর গুরু-শিষ্য সম্পর্ক তৈরি হয়?',
#    'কার সঙ্গে শেখ মুজিবের গুরু-শিষ্য সম্পর্ক ছিলো?',
#    nan,
#    nan],
#   ['গণতন্ত্রের মানসপুত্র বলা হয় কাকে?', 'গণতন্ত্রের মানসপুত্র কে?', nan, nan],
#   ['দুর্ভিক্ষের সময় সিভিল সাপ্লাই মন্ত্রী কে ছিলেন?',
#    'পঞ্চাশের মন্বন্তর এর সময় সিভিল সাপ্লাই মন্ত্রী কে ছিলেন?',
#    'ভারতবর্ষে যখন দুর্ভিক্ষ শুরু হয় তখন সিভিল সাপ্লাই মন্ত্রী কে ছিলেন ?',
#    'দুর্ভিক্ষের সময় সিভিল মন্ত্রী কে ছিলেন?'],
#   ['দুর্ভিক্ষের সময় মানুষের প্রাণ বাঁচাতে লঙ্গরখানা খোলার নির্দেশ দেন কে?',
#    'দুর্ভিক্ষের সময়  লঙ্গরখানা খোলার নির্দেশ দেন কে?',
#    'দুর্ভিক্ষের সময়  লঙ্গরখানা খুলতে বলেন  কে?',
#    nan],
#   ['দুর্ভিক্ষের সময় কে কলকাতার অনেকগুলো লঙ্গরখানা তত্ত্বাবধানের দায়িত্ব দেন মুজিবকে?',
#    'কে দুর্ভিক্ষের সময় কলকাতার অধিকাংশ লঙ্গরখানার দায়িত্ব দেন মুজিবকে?',
#    nan,
#    nan]],
#  'কবি কাজী নজরুল ইসলাম': [['ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কই সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে অনুষ্ঠিত হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে হয়?'],
#   ['ফরিদপুর ছাত্রলীগের সম্মেলনে কোন কোন বিশিষ্ট ব্যক্তিদের আমন্ত্রণ জানানো হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলনে আমন্ত্রিত বিশিষ্ট ব্যক্তিদের নাম কি ?',
#    'ফরিদপুুর ছাত্রলীগ সম্মেলনে কারা আমন্ত্রিত হয়েছিলেন?',
#    nan]],
#  'হোসেন শহীদ সোহরাওয়ার্দী': [['কখন প্রথম শেখ মুজিব হোসেন শহীদ সোহরাওয়ার্দীর সংস্পর্শে আসেন ?',
#    'কতসালে বঙ্গবন্ধু সোহরাওয়ার্দীর সংস্পর্শে আসেন ?',
#    'জাতির জনক কবে সোহরাওয়ার্দীর সাথে পরিচিত হন ',
#    'কখন শেখ সাহেব  শহীদ সোহরাওয়ার্দীর সাথে পরিচিত হন ']],
#  'হোসেন শহীদ সোহরাওয়ার্দী': [['১৯৩৮ সালে অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    'বঙ্গবন্ধু গোপালগঞ্জ মিশন স্কুলের ছাত্র থাকা অবস্থায় অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    '১৯৩৮ সালে বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    nan],
#   ['১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন বঙ্গবন্ধু কোন স্কুলের ছাত্র ছিলেন?',
#    '১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন শেখ মুজিব কোন স্কুলে পড়তেন?',
#    'শেখ মুজিব কোন স্কুলের ছাত্র ছিলেন?',
#    'শেখ মুজিব কোন স্কুলে পড়তেন?'],
#   ['স্কুলের ছাদ মেরামতের জন্য শেরে বাংলা কত টাকা মঞ্জুর করেন?',
#    'স্কুলের ছাদ মেরামতের জন্য অখণ্ড বাংলার মুখ্যমন্ত্রী কত টাকা মঞ্জুর করেন?',
#    'শেরে বাংলা ছাদ মেরামত করতে কত টাকা দিয়েছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কারা এসেছিলেন?',
#    'শেখ মুজিব যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কোন কোন রাজনৈতিক ব্যক্তিবর্গ এসেছিলেন?',
#    'মুজিবদের স্কুলে কে কে পরিদর্শনে গেছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে স্কুলের কোন কোন সমস্যাগুলো তুলে ধরেন?',
#    'বঙ্গবন্ধু ও তার বন্ধুরা শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে স্কুলের কোন কোন সমস্যাগুলো তুলে ধরেন?',
#    'শেখ মুজিব ও তার বন্ধুরা শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে কি কি দাবি তুলে ধরেন?',
#    nan],
#   ['১৯৪৬ সালে অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    '১৯৪৬ সালে বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    nan,
#    nan],
#   ['বিহারে ভয়াবহ দাঙ্গার খবর পেয়ে মুসলিম পরিবারদের রক্ষার্থে স্বেচ্ছাসেবকের দায়িত্ব দিয়ে মুজিবকে কে পাঠান?',
#    'বিহারের দাঙ্গা ভয়াবহ হলে স্বেচ্ছাসেবকের দায়িত্ব দিয়ে মুজিবকে সেখানে কে পাঠান?',
#    'বিহারের দাঙ্গায় মুজিবকে স্বেচ্ছাসেবকের দায়িত্ব কে দেন?',
#    nan],
#   ['১৯৪৬ সালে বঙ্গবন্ধু কোন মুখ্যমন্ত্রীর সহকারীর দায়িত্ব পান?',
#    '১৯৪৬ সালে বঙ্গবন্ধু কার সহকারীর দায়িত্ব পান?',
#    'বঙ্গবন্ধু কোন মন্ত্রীর সহকারী ছিলেন?',
#    nan]],
#  'জেনারেল মোহাম্মদ আলী জিন্নাহ': [['কবে উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন পাকিস্তানের গভর্নর জেনারেল মোহাম্মদ আলী জিন্নাহ?',
#    'কবে উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন পাকিস্তানের গভর্নর ?',
#    'কবে উর্দুকে রাষ্ট্রভাষা  ঘোষণা করেন পাকিস্তানের গভর্নর ?',
#    nan],
#   ['কোথায় উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন পাকিস্তানের গভর্নর জেনারেল মোহাম্মদ আলী জিন্নাহ?',
#    'কোথায় বক্তব্য দিতে গিয়ে জিন্নাহ উর্দুকে পাকিস্তানের রাষ্ট্রভাষা করার ঘোষণা দেয়?',
#    nan,
#    nan],
#   ['১৯৪৮ সালে পাকিস্তানের গভর্নর কে ছিলেন?', ' পাকিস্তানের জনক কে?', nan, nan],
#   ['"উর্দুই হবে পাকিস্তানের একমাত্র রাষ্ট্র ভাষা"- উক্তিটি কার?',
#    '"উর্দুই হবে পাকিস্তানের একমাত্র রাষ্ট্র ভাষা"- উক্তিটি কে দিয়েছিলেন?',
#    nan,
#    nan],
#   ['কবে জিন্নাহ ঢাকা বিশ্বিবদ্যালয়ে পুনরায় উর্দুকে রাষ্ট্র ভাষা করার ঘোষণা করে?',
#    nan,
#    nan,
#    nan],
#   ['কে সোহরাওয়ার্দী উদ্যানে (তৎকালীন রেসকোর্স ময়দানে) বক্তব্য দেওয়ার সময় উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন?',
#    'কে সোহরাওয়ার্দী উদ্যানে উর্দুকে একমাত্র রাষ্ট্রভাষা করার ঘোষণা দেন?',
#    'কে সোহরাওয়ার্দী উদ্যানে উর্দুকে  রাষ্ট্রভাষা করার ঘোষণা দেন?',
#    nan],
#   ['কারা পাকিস্তানের গভর্নর জেনারেল মোহাম্মদ আলী জিন্নাহ এর ঘোষণার তীব্র প্রতিবাদ জানায়?',
#    'কারা জিন্নাহ এর উর্দুকে পাকিস্তানের রাষ্ট্র ভাষা করার ঘোষণার প্রতিবাদ করে?',
#    nan,
#    nan],
#   ['কোথায় জিন্নাহ পুনরায় উর্দুকে রাষ্ট্র ভাষা করার ঘোষণা দেয়?',
#    'কই জিন্নাহ পুনরায় উর্দুকে রাষ্ট্র ভাষা করার ঘোষণা দেয়?',
#    nan,
#    nan]],
#  'সালাম': [['কত সালে রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশ গুলি চালায়?',
#    'কবে ভাষা আন্দোলন হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে কোথায় প্রতিবাদ মিছিল হয়?',
#    'ভাষা আন্দোলনের জন্য প্রতিবাদ মিছিল কোথায় হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয়ে প্রতিবাদ মিছিল হয়?',
#    '২১ শে ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    '২১ শে ফেব্রুয়ারি কেন ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশের গুলিতে শহীদ হন কারা?',
#    'ভাষা আন্দোলনে কারা শহীদ হন?',
#    'ভাষা আন্দোলনে পুলিশের গুলিতে নিহত হন কারা?',
#    'ভাষা আন্দোলনে পুলিশের গুলি খায় কারা?']],
#  'শান্তিতে নোবেল বিজয়ী উইলিবান্ট': [['‘মুজিব হত্যার পর বাঙালিদের আর বিশ্বাস করা যায় না। যারা মুজিবকে হত্যা করেছে তারা যেকোনো জঘন্য কাজ করতে পারে।’-উক্তিটি কার?',
#    "‘মুজিব হত্যার পর বাঙালিদের আর বিশ্বাস করা যায় না।'--উক্তিটি কে করেছিলেন?",
#    nan,
#    nan]],
#  'ব্রিটিশ লর্ড ফেন্যার ব্রোকওয়ে': [['‘জর্জ ওয়াশিংটন, গান্ধী এবং দ্য ভ্যালেরার থেকেও মহান নেতা ছিলেন শেখ মুজিব।’-উক্তিটি কার?',
#    'কে শেখ মুজিবকে জর্জ অয়াশিংটন, গান্ধী এবং ভ্যালেরার থেকেও মহান নেতা বলেছিলেন?',
#    nan,
#    nan]],
#  'ফজিলাতুন্নেসা': [['কত সালে শেখ মুজিবুর রহমানের বিয়ে হয়?',
#    'বঙ্গবন্ধু কত সালে বিবাহ বন্ধনে আবদ্ধ হন?',
#    'কবে শেখ মুজিব বিয়ে করেন?',
#    nan],
#   ['বিয়ের সময় শেখ মুজিবুর রহমানের বয়স কত ছিলো?',
#    'বিয়ের সময় বঙ্গবন্ধুর বয়স কত ছিলো?',
#    'কয় বছর বয়সে শেখ মুজিব বিয়ে করেন?',
#    nan],
#   ['কার সাথে শেখ মুজিবুর রহমানের বিয়ে হয়?',
#    'বঙ্গবন্ধু কার সাথে বিবাহ বন্ধনে আবদ্ধ হয়েছিলেন?',
#    'বঙ্গমাতার নাম কি?',
#    'শেখ মুজিব কাকে বিয়ে করেছিলেন?']],
#  'শেখ কামাল': [['শেখ মুজিব রহমানের ছেলেদের নাম কি?',
#    'শেখ মুজিবের পুত্র সন্তানদের নাম কি?',
#    'শেখ মুজিবের পুত্র কে কে?',
#    nan]],
#  'শেখ হাসিনা': [['শেখ মুজিবুর রহমানের মেয়েদের নাম কি?',
#    'শেখ মুজিবের কন্যা সন্তানদের নাম কি?',
#    'শেখ মুজিবের কন্যা কে কে?',
#    nan]],
#  'ইয়াহিয়া খান ': [['আইয়ুব খানের পরে কে ক্ষমতায় আসেন ?',
#    'আইয়ুব খানের ক্ষমতাচ্যুত হওয়ার পরে কে ক্ষমতায় আসেন ? ',
#    nan,
#    nan],
#   ['কে ক্ষমতা নেওয়ার পরে সামরিক শাসন জারি করে ?',
#    'সামরিক শাসন জারি করেন কে ?',
#    'সামরিক শাসনের পথে হাঁটেন কে ?',
#    nan],
#   ['ইয়াহিয়া খান কবে ক্ষমতা লাভ করে ?',
#    'কবে ইয়াহিয়া খান ক্ষমতা লাভ করে ?',
#    'ইয়াহিয়া খান ক্ষমতায় আসেন কবে  ?',
#    nan],
#   ['ইয়াাহিয়া খান কার পরে ক্ষমতায় আসেন ?',
#    'ইয়াহিয়া খানের আগে ক্ষমতায় কে ছিল  ?',
#    'ইয়াহিয়া খান পূর্ব শাসক  কে ছিল  ?',
#    nan],
#   ['জাতীয় নির্বাচন কবে হওয়ার কথা ?', nan, nan, nan],
#   ['কে জাতীয় নির্বাচন অনুষ্ঠানের প্রতিশ্রুতি দেয়?',
#    'জাতীয় নির্বাচন হওয়ার কথা কে জানান ?',
#    nan,
#    nan]],
#  'হোসেন শহীদ সোহরাওয়ার্দী': [[' কবে হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল ?',
#    'হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল  কত তারিখ?',
#    'সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী কবে?',
#    nan]],
#  'ইয়াহিয়া খান': [[' জাতীয় পরিষদের অধিবেশন অনুষ্ঠান স্থগিত করেন কে?',
#    ' কে জাতীয় পরিষদের অধিবেশন অনুষ্ঠান স্থগিত করেন ?',
#    ' জাতীয় পরিষদের অধিবেশন অনুষ্ঠান বন্ধ করেন কে?',
#    nan],
#   ['২৫ তারিখ কে ঢাকা ছাড়ে কে ?',
#    'মার্চের ২৫ তারিখ কে ঢাকা ত্যাগ করে?',
#    nan,
#    nan],
#   ['মুজিব  কারাগারে জীবিত আছে  এ কথা কে বলেছেন?',
#    'কে শেখ মুজিবের জীবিত থাকার কথা প্রকাশ করেন?',
#    'সংবাদ সম্মেলনে কে শেখ মুজিবের জীবিত থাকার কথা বলেছিলেন?',
#    nan],
#   ['কত সালে ইয়াহিয়া খান জানান মুজিব  কারাগারে জীবিত আছেন ?',
#    'কবে শেখ মুজিবের কারাগারে জীবিত থাকার কথা প্রকাশ পায়?',
#    nan,
#    nan],
#   [' জেনারেল ইয়াহিয়া খান কোথায় জানান মুজিব কারাগারে জীবিত আছে ?',
#    'কোন সংবাদকে ইয়াহিয়া খান মুজিবের জীবিত থাকার কথা জানান?',
#    nan,
#    nan]],
#  ' নেলসন ম্যান্ডেলা': [["এটি আসলে স্বাধীনতার মূল দলিল।'- কথাটি কার ?",
#    '৭ মার্চের ভাষণকে বাঙ্গালির স্বাধীনতার মূল দলিল বলে আখ্যায়িত করেছিলেন কে?',
#    nan,
#    nan],
#   ["এটি আসলে স্বাধীনতার মূল দলিল।'- কথাটি কি সম্ভন্ধে বলা হইসে  ?",
#    nan,
#    nan,
#    nan],
#   ['নেলসন ম্যান্ডেলা কোন দেশের ?',
#    'নেলসন ম্যান্ডেলা কোন দেশের নাগরিক ছিলেন?',
#    nan,
#    nan]],
#  'সিদ্দিক সালিক': [['১৯৭১ সালে পাকিস্তানি সেনাবাহিনীর গণসংযোগ কর্মকর্তা কে ছিলেন ?',
#    'যুদ্ধের সময় পাকিস্তানি বাহিনীর গণসংযোগ কর্মকর্তা কে ছিলেন?',
#    nan,
#    nan]],
#  'এডওয়ার্ড হিথ': [['মুক্তিযুদ্ধের সময় ব্রিটেনের প্রধানমন্ত্রী কে ছিলেন?',
#    'যুদ্ধের সময় যুক্তরাজ্যের প্রধানমন্ত্রী কে ছিলেন?',
#    'মুক্তিযুদ্ধের সময় ব্রিটিশ প্রধানমন্ত্রী কে ছিলেন?',
#    nan],
#   ['বাংলাদেশের স্বাধীনতার ঘোষণা নিয়ে ব্রিটেনের প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে ব্রিটেনের প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে ব্রিটিশ প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে  এডওয়ার্ড হিথ কি বলেছিলেন?']],
#  'ডেভিড লোশাক': [['ডেভিড লোশাক কে ছিলেন?',
#    'ডেভিড লোশাক এর পরিচয় কি?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কর্তৃক স্বাধীনতা ঘোষণার বিষয়ে ব্রিটেনের দ্য ডেইলি টেলিগ্রাফ পত্রিকার সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    'স্বাধীনতা ঘোষণার বিষয়ে ব্রিটেনের দ্য ডেইলি টেলিগ্রাফ পত্রিকার সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    'স্বাধীনতা ঘোষণার বিষয়ে  সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    nan]],
#  'সৈয়দ নজরুল ইসলাম': [['মুজিব নগরের উপ-রাষ্ট্র প্রধান কে ?',
#    'মুজিবনগর সরকারের উপরাষ্ট্রপতির নাম কি?',
#    nan,
#    nan]],
#  'তাজউদ্দিন আহমদ': [['মুজিবনগর সরকারের প্রধানমন্ত্রী কে ছিলেন ?',
#    'মুজিবনগর সরকারের প্রধানমন্ত্রী কে নির্বাচিত হন ?',
#    'কাকে  মুজিবনগর সরকারের প্রধানমন্ত্রী বানানো হয়েছিলো ?',
#    nan]],
#  'সৈয়দ নজরুল ইসলাম': [['মুজিবনগর সরকারের উপ-রাস্ত্রপতি  কে ছিলেন ?',
#    nan,
#    nan,
#    nan]],
#  'রমেশ চন্দ্র': [["শেখ মুজিব কে  'জুলিও কুরি' পদক কে পরিয়ে দেয় ?",
#    'এশীয় শান্তি সম্মেলনে কে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেয়?',
#    nan,
#    nan],
#   ['কথাটি কে বলেছিলেন, ‘বঙ্গবন্ধু শুধু বাংলার নন, তিনি বিশ্বের এবং তিনি বিশ্ববন্ধু।?’',
#    'বঙ্গবন্ধুকে বিশ্ববন্ধু কে বলেছিলেন?',
#    "‘বঙ্গবন্ধু শুধু বাংলার নন, তিনি বিশ্বের এবং তিনি বিশ্ববন্ধু' কথাগুলো কে বলেছিলেন?",
#    nan]],
#  'বাঘা যতীন': [['পূর্ণচন্দ্র দাস কার সহকর্মী ছিলেন ?',
#    'পূর্ণ দাসের সহকর্মী ছিলেন কে ?',
#    nan,
#    nan]],
#  'কাজী নজ্রুল ইসলাম': [['বিদ্রোহী কবি কাজী নজ্রুল ইসলাম স্বদেশী আন্দোলনের কোন নেতাকে নিয়ে কবিতা লিখেছিলেন ?',
#    'পূর্ণ অভিনন্দন কবিতাটি কাকে নিয়ে লিখা ?',
#    'নজরুল পূর্ণ অভিনন্দন কবিতাটি কাকে নিয়ে লিখেছেন ?',
#    nan]],
#  'হুমায়ুন কবির': [['ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কই সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে অনুষ্ঠিত হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে হয়?'],
#   ['ফরিদপুর ছাত্রলীগের সম্মেলনে কোন কোন বিশিষ্ট ব্যক্তিদের আমন্ত্রণ জানানো হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলনে আমন্ত্রিত বিশিষ্ট ব্যক্তিদের নাম কি ?',
#    'ফরিদপুুর ছাত্রলীগ সম্মেলনে কারা আমন্ত্রিত হয়েছিলেন?',
#    nan]],
#  'বরকত': [['কত সালে রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশ গুলি চালায়?',
#    'কবে ভাষা আন্দোলন হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে কোথায় প্রতিবাদ মিছিল হয়?',
#    'ভাষা আন্দোলনের জন্য প্রতিবাদ মিছিল কোথায় হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয়ে প্রতিবাদ মিছিল হয়?',
#    '২১ শে ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    '২১ শে ফেব্রুয়ারি কেন ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশের গুলিতে শহীদ হন কারা?',
#    'ভাষা আন্দোলনে কারা শহীদ হন?',
#    'ভাষা আন্দোলনে পুলিশের গুলিতে নিহত হন কারা?',
#    'ভাষা আন্দোলনে পুলিশের গুলি খায় কারা?']],
#  'শেখ জামাল': [['শেখ মুজিব রহমানের ছেলেদের নাম কি?',
#    'শেখ মুজিবের পুত্র সন্তানদের নাম কি?',
#    'শেখ মুজিবের পুত্র কে কে?',
#    nan]],
#  'শেখ রেহানা': [['শেখ মুজিবুর রহমানের মেয়েদের নাম কি?',
#    'শেখ মুজিবের কন্যা সন্তানদের নাম কি?',
#    'শেখ মুজিবের কন্যা কে কে?',
#    nan]],
#  'প্রিন্সিপাল ইব্রাহিম খাঁ': [['ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কই সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে অনুষ্ঠিত হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে হয়?'],
#   ['ফরিদপুর ছাত্রলীগের সম্মেলনে কোন কোন বিশিষ্ট ব্যক্তিদের আমন্ত্রণ জানানো হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলনে আমন্ত্রিত বিশিষ্ট ব্যক্তিদের নাম কি ?',
#    'ফরিদপুুর ছাত্রলীগ সম্মেলনে কারা আমন্ত্রিত হয়েছিলেন?',
#    nan]],
#  'রফিক': [['কত সালে রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশ গুলি চালায়?',
#    'কবে ভাষা আন্দোলন হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে কোথায় প্রতিবাদ মিছিল হয়?',
#    'ভাষা আন্দোলনের জন্য প্রতিবাদ মিছিল কোথায় হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয়ে প্রতিবাদ মিছিল হয়?',
#    '২১ শে ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    '২১ শে ফেব্রুয়ারি কেন ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশের গুলিতে শহীদ হন কারা?',
#    'ভাষা আন্দোলনে কারা শহীদ হন?',
#    'ভাষা আন্দোলনে পুলিশের গুলিতে নিহত হন কারা?',
#    'ভাষা আন্দোলনে পুলিশের গুলি খায় কারা?']],
#  'শেখ রাসেল': [['শেখ মুজিব রহমানের ছেলেদের নাম কি?',
#    'শেখ মুজিবের পুত্র সন্তানদের নাম কি?',
#    'শেখ মুজিবের পুত্র কে কে?',
#    nan]]}

# %%
q_per_people = dict()

for ppl in people_q_dict.keys():
    q_per_people[ppl] = len( people_q_dict[ppl])
q_per_people
# Out:
# {'missing': 1164,
#  'আইয়ুব খান': 3,
#  ' ': 1,
#  'শেখ লুৎফর রহমান': 2,
#  'সায়েরা খাতুন': 2,
#  'পূর্ণ দাস': 7,
#  'সুভাষচন্দ্র বসু': 2,
#  'হামিদ মাস্টার': 2,
#  'এ কে ফজলুল হক ': 5,
#  'হোসেন শহীদ সোহরাওয়ার্দী': 6,
#  'কবি কাজী নজরুল ইসলাম': 2,
#  'হোসেন শহীদ সোহরাওয়ার্দী': 1,
#  'হোসেন শহীদ সোহরাওয়ার্দী': 8,
#  'জেনারেল মোহাম্মদ আলী জিন্নাহ': 8,
#  'সালাম': 4,
#  'শান্তিতে নোবেল বিজয়ী উইলিবান্ট': 1,
#  'ব্রিটিশ লর্ড ফেন্যার ব্রোকওয়ে': 1,
#  'ফজিলাতুন্নেসা': 3,
#  'শেখ কামাল': 1,
#  'শেখ হাসিনা': 1,
#  'ইয়াহিয়া খান ': 6,
#  'হোসেন শহীদ সোহরাওয়ার্দী': 1,
#  'ইয়াহিয়া খান': 5,
#  ' নেলসন ম্যান্ডেলা': 3,
#  'সিদ্দিক সালিক': 1,
#  'এডওয়ার্ড হিথ': 2,
#  'ডেভিড লোশাক': 2,
#  'সৈয়দ নজরুল ইসলাম': 1,
#  'তাজউদ্দিন আহমদ': 1,
#  'সৈয়দ নজরুল ইসলাম': 1,
#  'রমেশ চন্দ্র': 2,
#  'বাঘা যতীন': 1,
#  'কাজী নজ্রুল ইসলাম': 1,
#  'হুমায়ুন কবির': 2,
#  'বরকত': 4,
#  'শেখ জামাল': 1,
#  'শেখ রেহানা': 1,
#  'প্রিন্সিপাল ইব্রাহিম খাঁ': 2,
#  'রফিক': 4,
#  'শেখ রাসেল': 1}

# %%
a = list(q_per_people.keys())[1:]
b = list(q_per_people.values())[1:]
plot_bar_plot(a,
              b,
              "People",
              "Questions",
              "Questions per People",
              show_number=True,
              show_x=True)

# %% [markdown]
# ## Question per Location

# %%
l1 = list(df.L1.unique())
l1
# Out:
# [nan, 'মাদারীপুর', 'কুষ্টিয়া']

# %%
l2 = list(df.L2.unique())
l2
# Out:
# ['পূর্ব বাংলা',
#  'পল্টন ময়দান',
#  'করাচী ',
#  'পূর্ব পাকিস্তান',
#  'ধানমন্ডি ৩২ নম্বর সড়ক',
#  'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন',
#  'পাকিস্তানের লাহোর',
#  'পাকিস্তানের কারাগার',
#  'সোহরাওয়ার্দী উদ্যান',
#  'ঢাকা',
#  nan,
#  'দক্ষিণ আফ্রিকা',
#  'মেহেরপুর',
#  'লন্ডন',
#  'বাংলাদেশ',
#  'ভারত',
#  'আলজেরিয়া',
#  'টুঙ্গিপাড়া',
#  'মাদারীপুর',
#  'গোপালগঞ্জ',
#  'কলকাতা',
#  'ফরিদপুর',
#  'ভারতবর্ষ',
#  ' দিল্লী',
#  'ঢাকা বিশ্ববিদ্যালয়ের ফজলুল হক হল',
#  'ঢাকা বিশ্ববিদ্যালয়',
#  'সচিবালয়',
#  'ঢাকা বিশ্ববিদ্যালয়',
#  'সোহরাওয়ার্দী উদ্যান ',
#  'জেলখানা',
#  'ধানমন্ডি']

# %%
locations = []

locations.extend(l1)
locations.extend(l2)

# %%
c_locations = []

for i in locations:
    if i not in c_locations:
        c_locations.append(i)

print(f"Total uniqe people: {len(c_locations)}")
# Out:
# Total uniqe people: 32

# %%
location_q_dict = dict()

for i in c_locations:
    if type(i) != str:
        text = "location_q_dict['missing'] = []"
        exec(text)
    else:
        text = "location_q_dict['"+i+"'] = []"
        exec(text)

# %%
location_q_dict
# Out:
# {'missing': [],
#  'মাদারীপুর': [],
#  'কুষ্টিয়া': [],
#  'পূর্ব বাংলা': [],
#  'পল্টন ময়দান': [],
#  'করাচী ': [],
#  'পূর্ব পাকিস্তান': [],
#  'ধানমন্ডি ৩২ নম্বর সড়ক': [],
#  'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন': [],
#  'পাকিস্তানের লাহোর': [],
#  'পাকিস্তানের কারাগার': [],
#  'সোহরাওয়ার্দী উদ্যান': [],
#  'ঢাকা': [],
#  'দক্ষিণ আফ্রিকা': [],
#  'মেহেরপুর': [],
#  'লন্ডন': [],
#  'বাংলাদেশ': [],
#  'ভারত': [],
#  'আলজেরিয়া': [],
#  'টুঙ্গিপাড়া': [],
#  'গোপালগঞ্জ': [],
#  'কলকাতা': [],
#  'ফরিদপুর': [],
#  'ভারতবর্ষ': [],
#  ' দিল্লী': [],
#  'ঢাকা বিশ্ববিদ্যালয়ের ফজলুল হক হল': [],
#  'ঢাকা বিশ্ববিদ্যালয়': [],
#  'সচিবালয়': [],
#  'ঢাকা বিশ্ববিদ্যালয়': [],
#  'সোহরাওয়ার্দী উদ্যান ': [],
#  'জেলখানা': [],
#  'ধানমন্ডি': []}

# %%
for loc in location_q_dict.keys():
    for item in data:
        for  qas in  item['qas']:
            for l in qas['location']:
                if type(l) != str:
                    l = "missing"
                    # continue
                if l == loc:
                    location_q_dict[loc].append(qas['qtns'])

# %%
location_q_dict
# Out:
# {'missing': [['পূর্ব বাংলায় ১৯৭০ এর ঝড়ে কত মানুষ মারা যায় ?',
#    '১৯৭০ এর ঝড়ে কত মানুষ বাংলাদেশ মারা যায়?',
#    'কত মানুষ ১৯৭০ এ মারা যায় ?',
#    nan],
#   ['১৯৭০ এ শেখ মুজিব নির্বাচনী প্রচারনা বন্ধ করেন কেন?',
#    '১৯৭০ এ বঙ্গবন্ধু নির্বাচনী প্রচরনা বন্ধ করেন কেন?',
#    ' ',
#    ' '],
#   ['কেন ১৯৭০ সালে ১০ লাখ মানুষ মারা যায় ?', nan, nan, nan],
#   [" কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন বঙ্গবন্ধু শেখ মুজিবুর রহমান ?",
#    " বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সালে 'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন  ?",
#    " বঙ্গবন্ধু  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশনে দলের সাধারন সম্পাদক হিসেবে নির্বাচিত হন কত সালে  ?",
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    'পূর্ব পাকিস্তান মুসলিম লীগের অধিবেশন কতসালে অনুষ্ঠিত হয় ',
#    nan,
#    nan],
#   ['১৯৫৩ সালে বঙ্গবন্ধু কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    'শেখ মজীব  কোন দলের সাধারন সম্পাদক নির্বাচিত হন?',
#    nan,
#    nan],
#   ['১৯৫৩ সালের কোন মাসে পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    '১৯৫৩ সালের কখন পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় ?',
#    ' মুসলিম লীগ এর অধিবেশন অনুষ্ঠিত হয় কখন  ?',
#    nan],
#   ['তৎকালীন পধান বিরোধী দল কোনটি ছিলো?',
#    '১৯৫৩ সালের  কোনটি বিরোধী দল ছিল ?',
#    nan,
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ দলের কোন পদে নির্বাচিত হন শেখ মুজিবুর রহমান?',
#    'শেখ মুজিবুর রহমান পূর্ব পাকিস্তান মুসলিম লীগ দলের কোন পদে নির্বাচিত হন ?',
#    ' মুসলিম লীগ দলের কোন পদে শেখ মজীব ছিলেন  ?',
#    nan],
#   ['পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ কোন ধরণের দল ছিলো?',
#    ' লীগ কোন ধরণের দল ছিলো?',
#    nan,
#    nan],
#   [' যুক্তফ্রন্ট গঠিত হয় কত সালে?',
#    ' কত সালে যুক্তফ্রন্ট গঠিত হয় ?',
#    nan,
#    nan],
#   ['১৯৫৩ সালের কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    ' কোন মাসের কত তারিখ যুক্তফ্রন্টগঠিত হয়?',
#    'যুক্তফ্রন্টগঠিত হয় কত তারিখ ?',
#    nan],
#   ['কার নেতৃত্বে যুক্তফ্রন্ট গঠিত হয় ?',
#    ' যুক্তফ্রন্ট এর  নেতৃত্ব দেন কোন দল?',
#    'কোন রাজনীতিক দল যুক্তফ্রন্ট গঠন করে ',
#    nan],
#   ['কাদের নিয়ে যুক্তফ্রন্ট গঠিত হয়?', 'কারা যুক্তফ্রন্ট গঠন করে?', nan, nan],
#   [' দেশজুড়ে যুক্তফ্রন্ট প্রচারনা শুরু করেন কে?',
#    ' কে যুক্তফ্রন্টের প্রচারনা শুরু করে?',
#    ' যুক্তফ্রন্টের গঠনের প্রচারনা শুরু করে কে?',
#    nan],
#   ['যুক্তফ্রন্ট নির্বাচন কতসালে হয় ?',
#    ' কতসালে যুক্তফ্রন্ট নির্বাচন হয় ?',
#    ' কতসালে  প্রদেশিক পরিষদের সাধারণ নির্বাচন হয় ?',
#    nan],
#   ['২২৩টি আসনে বিজয় হয় কোন দল?',
#    '১৯৫৪ এর নির্বাচনে কোন দল বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে কোন দল বিজয়ী হয় ?',
#    nan],
#   ['আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    '১৯৫৪ এর নির্বাচনে আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  আওয়ামী লীগ কয়টি আসনে বিজয়ী হয় ?',
#    'কয়টি আসনে আওয়ামী লীগ  বিজয়ী হয় ?'],
#   ['মুসলীম লীগ কয়টি আসন পায় ?',
#    'প্রদেশিক পরিষদের সাধারণ নির্বাচনে  মুসলীম লীগ কয়টি আসন লাভ করে ?',
#    '১৯৫৪ এর নির্বাচনে মুসলীম লীগ কয়টি আসন পায় ?',
#    nan],
#   ['যুক্তফ্রন্টে কয়টি মুসলিম আসন ছিলো?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  কয়টি মুসলিম আসন ছিল  ?',
#    nan,
#    nan],
#   ['আওয়ামী লীগের প্রধান মুখপাত্র কে?',
#    'আওয়ামী লীগের প্রধান  কে ছিলেন?',
#    'কে আওয়ামী লীগের প্রধান মুখপাত্র ছিলেন?',
#    nan],
#   ['যুক্তফ্রন্ট মন্ত্রীসভার কনিষ্ঠ মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্ট মন্ত্রীসভার কম বয়সী মন্ত্রী হিসেবে শপথ নেন কে?',
#    'যুক্তফ্রন্টে কে সব চেয়ে কম বয়সী মন্ত্রী ছিলেন?',
#    nan],
#   ['স্বাধীনতা আন্দোলনের প্রাণ পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের প্রাধান পুরুষ কে?',
#    'স্বাধীনতা আন্দোলনের ডাক দেন কে?',
#    nan],
#   ['কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব পান কে?',
#    ' কাকে কৃষি, বন ও সমবায় মন্ত্রণালয়ের দায়িত্ব দেওয়া হয়?',
#    'কৃষি, মন্ত্রণালয়ের দায়িত্ব কে পান?',
#    'বন মন্ত্রণালয়ের দায়িত্ব কে পান?'],
#   ['মুসলীম লীগের প্রভাবশালী নেতাকে ১৩ হাজার ভোটেরব্যবধানে পরাজিত করে কে?',
#    'মুসলীম লীগের প্রভাবশালী নেতাকে  পরাজিত করে কে?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে মুসলীম লীগের প্রভাবশালী নেতাকে বিপুল ভোটেরব্যবধানে পরাজিত করে কে?',
#    nan],
#   [' মন্ত্রীসভাকে পদচ্যুত করে কাকে গ্রেফতার করা হয় ?',
#    ' মন্ত্রীসভাকে ভাঙার পরে  কাকে গ্রেফতার করা হয় ?',
#    nan,
#    nan],
#   ['যুক্তফ্রন্ট কার নেতৃত্বাধীন ছিল?',
#    'যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? ',
#    ' কার নেতৃত্বে যুক্তফ্রন্ট জয় লাভ করে ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  যুক্তফ্রন্ট এর নেতৃত্ব দিয়েছিল কে? '],
#   [' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়ী হয় ?', nan, nan, nan],
#   ['শেখ মুজিবুর রহমান কোন মন্ত্রণালয়ের দায়িত্ব ?',
#    ' প্রদেশিক পরিষদের সাধারণ নির্বাচনে  দল বিজয়রে পরে শেখ মুজিব কোন মন্ত্রণালয়ের দায়িত্ব পান ?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু মুসলীম লীগের প্রভাবশালী নেতাকে কত হাজার ভোটেরব্যবধানে পরাজিত করেন?',
#    'শেখ মুজিব মুসলীম লীগের  নেতাকে কত  ভোটের ব্যবধানে পরাজিত করেন?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু কত সালে পাকিস্তান গণপরিষদের সদস্য নির্বাচিত হন ?',
#    'কবে শেখ মুজীব গণপরিষদের সদস্য হন ? ',
#    nan,
#    nan],
#   ['পূর্ব বাংলার নাম পূর্ব পাকিস্তান করার প্রতিবাদ করেন কে ?',
#    'এঈ দেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বাধা দেন ? ',
#    'বাংলাদেশের নাম পূর্ব পাকিস্তান করতে চাইলে কে বিরোধিতা করেন  ? ',
#    nan],
#   ['পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন  কে ?',
#    'কে পূর্ব পাকিস্তানে স্বায়ত্ত শাসন দাবী করেন ? ',
#    nan,
#    nan],
#   ['কোথায় শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন ?',
#    'শেখ মূজীব পূর্ব পাকিস্তানের স্বায়ত্তশাসন দাবি করেন কোন জায়গায় ?',
#    nan,
#    nan],
#   ['"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- কথাটি কে বলেছেন ?',
#    '"পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"- উক্তিটি কার  ?',
#    ' কে বলেছেন ""পূর্ববাংলা নামের একটি ইতিহাস ও ঐতিহ্য আছে"  ?',
#    nan],
#   ['ধর্মনিরপেক্ষতা কোন দলের মূলনীতি ?',
#    'কোন রাজনৈতিক দল তাদের মূলনীতি করেছিলো ধর্ম নীরপেক্ষতা ?',
#    nan,
#    nan],
#   ['কবে আওয়ামী লীগ ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    'আওয়ামী লীগ কবে থেকে ধর্মনিরপেক্ষতাকে দলের মূলনীতি হিসাবে প্রচার করে ? ',
#    nan,
#    nan],
#   ['আওয়ামী মুসলিম লীগ থেকে কবে দলের নাম মুসলিম লীগ করা হয় ? ',
#    'কবে থেকে আওয়ামী মুসলিম লীগ থেকে দলের নাম মুসলিম লীগ করা হয় ? ',
#    nan,
#    nan],
#   ['২য় বারের মতো শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    ' ১ম বারের পরে  শেখ মুজীব কবে আবার আওয়ামী লীগের সাধারণ সম্পাদক নির্বাচিত হন ? ',
#    nan,
#    nan],
#   ['আওয়াামী লীগ থেকে কেনো মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কী কারনে আওয়াামী লীগ থেকে  মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    'কিসের জন্য আওয়াামী লীগ থেকে মুসলিম কথাটি সরিয়ে ফেলা হয় ?',
#    nan],
#   ['কত সালে প্রাদেশিক সরকার গঠীত হয় ?',
#    ' প্রাদেশিক সরকার কত সালে গঠীত হয় ?',
#    nan,
#    nan],
#   ['কোন দল প্রাদেশিক সরকার গঠন করে ?',
#    'কারা প্রাদেশিক সরকার গঠন করে ?',
#    'প্রাদেশিক সরকার কোন রাজনৈতিক দল গঠন করে ?',
#    nan],
#   ['প্রাদেশিক সরকার গঠনের পরে বঙ্গবন্ধু কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান প্রাদেশিক সরকার গঠনের পরে কোন মন্ত্রী হন ?',
#    'শেখ মুজিবুর রহমান কোন দফতরের মন্ত্রী হন প্রাদেশিক সরকার গঠনের পরে ?',
#    nan],
#   ['১৯৫৬ সালে শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    'প্রাদেশিক সরকার গঠনের পরে  শিল্প, বাণিজ্য, শ্রম, দুর্নীতি দমন ও ভিলেজ-এইড দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে শিল্প ও বাণিজ্য, শ্রম  দফতরের মন্ত্রিত্ব লাভ করেন কে?',
#    '১৯৫৬ সালে  দুর্নীতি দমন বিষয়ক মন্ত্রী হন  কে?'],
#   [' কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    ' প্রাদেশিক সরকার গঠনের পরে কত সালে বঙ্গবন্ধু মন্ত্রিসভা থেকে স্বেচ্ছায় পদত্যাগ করেন?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে সামরিক শাসন জারি করা হয় ?',
#    'পূর্ব পাকিস্তানে সামরিক শাসন কবে জারি হয় ?',
#    nan,
#    nan],
#   ['কত সালে পাকিস্তানে রাজনীতি নিষিদ্ধ করা হয়?',
#    ' পাকিস্তানে কত সালে রাজনীতি নিষিদ্ধ করা হয়?',
#    nan,
#    nan],
#   [' মিথ্যা মামলায় জেল খাটতে হয় কাকে?',
#    ' কে মিথ্যা মামলায় জেল খাটে ?',
#    '১৯৬৩ সালে ভূয়া মামলায় জেল খাটে কে ?',
#    nan],
#   ['কত সাল পর্যন্ত  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কখন  বঙ্গবন্ধুকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    'কোন সালে  শেখ মুজিবুর রহমানকে রাজনীতি না ছাড়ার কারণে জেল খাটতে হয় ?',
#    nan],
#   ['কত সালে জেলের ভয়ে জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কোন সময়ে  জ্যেষ্ঠ রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন ? ',
#    'কত সালে জেলের ভয়ে লিখিত দিয়ে  জ্যেষ্ঠ রাজনীতিবাদরা রাজনীতি ছেড়ে দেন ? ',
#    'সামরিক শাসন আসলে  সালে জেলের ভয়ে  রাজনীতিবাদরা মুচলেকা দিয়ে রাজনীতি ছেড়ে দেন কত সালে  ? '],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয় কত সালে ?',
#    ' কত সালে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকা হয়?',
#    'আওয়ামী লীগে নেতাদের বৈঠক ডাকা হয় কত কবে ?',
#    nan],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা কবে দেয়া হয়?',
#    'কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেয়া হয়?',
#    'শেখ মুজিব কবে আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দিয়েছিলেন ?',
#    nan],
#   ['আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে  কে?',
#    'কোন নেতা আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকে ?',
#    'কোন রাজনৈতিক নেতা আওয়ামী লীগের বড় নেতাদের  বৈঠক ডাকে ?',
#    nan],
#   ['আওয়ামী লীগকে পুনর্জীবিত করার ঘোষণা দেন কে?',
#    'কে ঘোষণা দিয়ে আওয়ামী লীগকে পুনর্জীবিত করেন ?',
#    'আওয়ামী লীগকে পুনর্জীবিত করার ঘোষক কে?',
#    'কার ঘোষণায় আওয়ামী লীগ ৫ বছর পর  পুনর্জীবিত হয় ?'],
#   ['বঙ্গবন্ধু কোথায় আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন ?',
#    '১৯৬৪ সালে শেখ মুজিবুর এর সাথে কোথায় আওয়ামী নেতাদের বৈঠক হয় ?',
#    nan,
#    nan],
#   ['কার হাত ধরে আওয়ামী লীগ আবারো রাজপথে আসে ?',
#    'আওয়ামী লিগের অচল অবস্থা কাটিয়ে তুলে রাজ পথে ফিরিয়ে আনেন কে ?',
#    'কে অচল আওয়ামী লিগকে পুনরায় উজ্জীবিত করেন ?',
#    nan],
#   [' শেখ মুজিবুর রহমানের বাসভবন কোথায় ছিল ?',
#    'বঙ্গবন্ধুর বাসভবন কোথায় ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালে কত বছর পরে আওয়ামী লীগ পুনরায় রাজ পথে নামে ?',
#    'অচল আওয়ামী লীগ কত বছর পর ১৯৬৪ সালে রাস্তায় নামে ?',
#    nan,
#    nan],
#   ['১৯৬৪ সালেে কার বিরুদ্ধে জোরদার আন্দোলন হয় ?',
#    ' কার বিরুদ্ধে ১৯৬৪ সালেে জোরদার আন্দোলন হয় ?',
#    nan,
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    '১৯৬৪ সালে  আইয়ুববিরোধী আন্দোলনের নেতৃত্ব দেন কে ?',
#    ' আইয়ুববিরোধী আন্দোলনের  নেতা কে ছিলেন ?',
#    nan],
#   ['স্বৈরাচার আইয়ুববিরোধী আন্দোলন হয় কত সালে ?',
#    'কবে আইয়ুববিরোধী আন্দোলন হয়  ?',
#    ' আইয়ুববিরোধী আন্দোলনের সময় কাল কত  সালে ?',
#    nan],
#   ['১৯৬৪ সালের কত তারিখে  ধানমন্ডির  বাসভবনে আওয়ামী লীগের কেন্দ্রীয় নেতাদের বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    'নিজ  বাসভবনে আওয়ামী লীগের  নেতাদের নিয়ে কবে  বৈঠক ডাকেন বঙ্গবন্ধু ?',
#    nan,
#    nan],
#   ['১৯৬৬ সালে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলো কোথায় ১৯৬৬ সালে  সম্মেলন করেছিল  ?',
#    nan],
#   ['কত সালে লাহোরে বিরোধী দলগুলোর সম্মেলন কোথায় হয়েছিলো ?',
#    ' বিরোধী দলগুলোর সম্মেলন কত সালে  হয়েছিলো ?',
#    'লাহোরে কত সালে  বিরোধী দলগুলোর সম্মেলন  হয়েছিলো ?',
#    nan],
#   ['ছয় দফা আন্দোলনের শিরোনাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের আরেক নাম কী ছিল ? ',
#    'ছয় দফা আন্দোলনের মুল কথা  কী ছিল ? ',
#    'ছয় দফা আন্দোলনকে কী নামে ডাকা হয়  ? '],
#   ['কোন আন্দোলন কে আমাদের বাঁচার দাবি বলা হয় ?',
#    ' আমাদের বাঁচার দাবি বলা হয় কোন আন্দোলনকে ?',
#    'লাাহোরে কোন আন্দোলন শুরু হয় ?',
#    nan],
#   ['ছয় দফা দাবি পেশ করেন কে ? ',
#    'ছয় দফা আন্দোলনের সুত্রপাত কে ঘটান  ? ',
#    'ছয় দফা দাবির নেতৃত্ব করেন কে ? ',
#    nan],
#   [' শেখ মুজিবুর রহমান কবে আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    '  কবে বঙ্গবন্ধু শেখ মুজিবুর রহমান আওয়ামী লীগের সভাপতি নির্বাচিত হন?',
#    ' কবে আওয়ামী লীগের সভাপতি হিসেবে দায়িত্ব পান  শেখ মুজিবুর রহমান ?',
#    nan],
#   ['ছয় দফা দাবি আদায়ে ৩ মাসে কতটি জনসভা করা হয় ১৯৬৬ সালে ?',
#    'ছয় দফা দাবি আদায়ে আওয়ামী লীগ কতটি জনসভা করে  ১৯৬৬ সালে ?',
#    nan,
#    nan],
#   ['ছয় দফা দাবি চলাকালীন কত তারিখ বঙ্গবন্ধু চূড়ান্তভাবে গ্রেফতার হয়?',
#    'ছয় দফা দাবি চলাকালীন কবে শেখ মুজিবকে গ্রেফতার হয়?',
#    nan,
#    nan],
#   ['৬ দফার সমর্থনে ১৯৬৬ এঁর কত তারিখ ছাত্ররা রাস্তায় নামে ?',
#    'ছাত্ররা কবে ৬ দফা আদায় এ রাস্তায় নামে ?',
#    '৬ দফার সমরথনে কবে জনগন রাস্তায় নামে ?',
#    nan],
#   ['কে ছয় দফা, আওয়ামী লীগ ও বাঙালির অধিকার- একক সত্তায় পরিণত করেন ? ',
#    'ব্যাঙালির অধিকার ও ৬ দফা এক সত্তায় পরিনত করেন কে ?',
#    nan,
#    nan],
#   [' ‘১২টার পরে খবর পাকাপাকি পাওয়া গেল যে, হরতাল হয়েছে। জনগণ স্বতঃস্ফূর্তভাবে হরতাল পালন করেছে। তারা ছয় দফা সমর্থন করে আর মুক্তি চায়। বাঁচতে চায়, খেতে চায়, ব্যক্তিস্বাধীনতা চায়, শ্রমিকের ন্যায্য দাবি, কৃষকদের বাঁচার দাবি তারা চায়, এর প্রমাণ এই হরতালের মধ্যে হয়েই গেল।’ এইটা কত তারিখ সম্বন্ধে বলা হয়েছে ? ',
#    '১৯৬৬ সালের কতও তারিখ জনগন হরতাল পালন করে ? ',
#    nan,
#    nan],
#   ['১৯৬৬ সালের কয় তারিখ হরতাল পালন করা হয় ?',
#    'কবে হারতাল পালন করা হয় ?',
#    '৬ দফার দাবিতে কবে হারতাল পালন করা হয় ?',
#    nan],
#   ['আগরতলা মামলার প্রধান আসামি কে ?',
#    'আগড়তলা ষড়যন্ত্র মামলার প্রধান আসামি কে ?',
#    nan,
#    nan],
#   ['আগরতলা মামলা কত সালে দায়ের করা হয় ?',
#    'কবে আগরতলা ষড়যন্ত্র মামলা দেওয়া হয় ?',
#    'আগরতলাা মামলা কত সালের কত তারিখ দায়ের করা হয় ?',
#    'আগরতলা মামলা দায়ের করার তারিখ কত ?'],
#   ['আগরতলা মামলার সময় শেখ মুজিব কোথায় ছিলেন?',
#    'শেখ মুজিব কোথায় ছিলেন যখন ষড়যন্ত্র মামলা দায়ের করা হয় ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কোনটি ?',
#    nan,
#    nan],
#   [' ইতিহাসের সর্ববৃহৎ গণআন্দোলন কত সালে হয় ?',
#    'যুদ্ধ পূর্ব  সর্ববৃহৎ গণআন্দোলন কবে হয় ?',
#    nan,
#    nan],
#   ['৬ দফার সমর্থনে ছাত্ররা কত দফা দাবি জানায় ?',
#    '৬ দফা সফল করতে কত দফা দাবি জানানো হয় ?',
#    nan,
#    nan],
#   [' ১১ দফা দাবি কত সালে ঘোষণা করা হয় ?',
#    'কবে ১১ দফা দাবি জানায় এই দেশের মানুষ ?',
#    '৬ দফার সমর্থনে কবে ১১ দফা ঘোষণা করে ?',
#    nan],
#   ['কোন ঘটনার সমর্থনে ১১ দফা ঘোষণা করে ছাত্রনেতারা ?',
#    'কোন ঘটনাকে কেন্দ্র করে  ১১ দফা ঘোষণা করা হয়  ?',
#    nan,
#    nan],
#   ['কারা ১১ দফা দাবি জানায় ?', '১১ দফা দাবি কারা ঘোষণা করেছিল ?', nan, nan],
#   ['আগরতলা মামলা কত সালে তুলে নেওয়া হয় ?',
#    'কবে ষড়যন্ত্র মামলা তুলে নেওয়া হয় ?',
#    'মিথ্যা মামলা কবে ফিরিয়ে নেওয়া হয় ?',
#    nan],
#   ["রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' শিরোনামটি কোন মামলার ছিল?",
#    "কোন মামলার শিরোনাম ছিল 'রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য' ?",
#    nan,
#    nan],
#   ['আগরতলা মাামলার শিরোনাম কি ছিল ?',
#    'ষড়যন্ত্র মামলা কি নামে পরিচিত ছিল ?',
#    nan,
#    nan],
#   ['কোন ঘটনার জন্য আগরতলা মামলা তুলে নেওয়া হয় ?',
#    'কি কারনে আগরতলা মামলা প্রত্যাহার করা হয় ? ',
#    'ষড়যন্ত্র মামলা তুলে নেওয়ার পিছনে কি কারন ছিল ? ',
#    nan],
#   ['কবে বঙ্গবন্ধু প্যারোলে মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় ?',
#    'শেখ মুজিবের জেল থেকে  মুক্তির প্রস্তাব প্রত্যাখ্যান করা হয় কবে ',
#    nan,
#    nan],
#   ['কি কারনে জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কিসের জন্য  জনগন তীব্র গণআন্দোলন করে ১৯৬৯ সালে ?',
#    'কেনো  জনগন গণআন্দোলন করে ১৯৬৯ সালে ?',
#    nan],
#   ['ডাকসু কবে শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    'কবে শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    'সোহরাওয়ার্দী উদ্যানে কবে মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan],
#   ['কোথায় ডাকসু  শেখ মুজিবকে বিশাল সংবর্ধনা দেয় ?',
#    '১৯৬৯ সালে কোথায় শেখ মুজিবকে সংবর্ধনা দেওয়া হয় ? ',
#    nan,
#    nan],
#   ['রেসকোর্স ময়দানের বর্তমান নাম কি ?',
#    'রেসকোর্স ময়দানের আগের  নাম কি ?',
#    nan,
#    nan],
#   ['সোহরাওয়ার্দী উদ্যানের পুরাতন নাম কি ?',
#    'সোহরাওয়ার্দী উদ্যানের পূর্ব নাম কি ?',
#    nan,
#    nan],
#   ["শেখ মুজিবকে কবে 'বঙ্গবন্ধু' উপাধিতে ভূষিত করা হয়? ",
#    " কবে 'বঙ্গবন্ধু' উপাধি দেওয়া  হয়? ",
#    nan,
#    nan],
#   ['কবে স্বৈরাচার প্রধান জেনারেল আইয়ুব খান পদত্যাগে বাধ্য হয় ?',
#    ' জেনারেল আইয়ুব খান কবে পদত্যাগ করেন  ?',
#    ' জেনারেল আইয়ুব খান কবে ক্ষমতা  ছাড়েন  ?',
#    ' জেনারেল আইয়ুব খান কবে গদি  ছাড়েন  ?'],
#   ['কার দাবির মুখে আইয়ুব খান পদত্যাগ করেন ?',
#    'কে  আইয়ুব খানকে  পদত্যাগ করতে বাধ্য করেন ?',
#    nan,
#    nan],
#   ['আইয়ুব খানের পরে কে ক্ষমতায় আসেন ?',
#    'আইয়ুব খানের ক্ষমতাচ্যুত হওয়ার পরে কে ক্ষমতায় আসেন ? ',
#    nan,
#    nan],
#   ['কে ক্ষমতা নেওয়ার পরে সামরিক শাসন জারি করে ?',
#    'সামরিক শাসন জারি করেন কে ?',
#    'সামরিক শাসনের পথে হাঁটেন কে ?',
#    nan],
#   ['ইয়াহিয়া খান কবে ক্ষমতা লাভ করে ?',
#    'কবে ইয়াহিয়া খান ক্ষমতা লাভ করে ?',
#    'ইয়াহিয়া খান ক্ষমতায় আসেন কবে  ?',
#    nan],
#   ['ইয়াাহিয়া খান কার পরে ক্ষমতায় আসেন ?',
#    'ইয়াহিয়া খানের আগে ক্ষমতায় কে ছিল  ?',
#    'ইয়াহিয়া খান পূর্ব শাসক  কে ছিল  ?',
#    nan],
#   ['জাতীয় নির্বাচন কবে হওয়ার কথা ?', nan, nan, nan],
#   ['কে জাতীয় নির্বাচন অনুষ্ঠানের প্রতিশ্রুতি দেয়?',
#    'জাতীয় নির্বাচন হওয়ার কথা কে জানান ?',
#    nan,
#    nan],
#   ['এই দেশের নাম বাংলাদেশ রাখেন কে ?',
#    'বাংলাদেশ নামকরন করেন কে ?',
#    ' কে বাংলাদেশ রাখেন এই দেশের নাম ?',
#    nan],
#   ['কত তারিখে বাংলাদেশ নামকরন করা হয় ?',
#    'বাংলাদেশ নামকরন করা হয় কবে  ?',
#    'কবে বাংলাদেশ নামটি আসে ?',
#    nan],
#   [' কবে হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল ?',
#    'হোসেন শহীদ সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী ছিল  কত তারিখ?',
#    'সোহরাওয়ার্দীর ষষ্ঠ মৃত্যুবার্ষিকী কবে?',
#    nan],
#   ['"একমাত্র ‘বঙ্গোপসাগর’ ছাড়া আর কোনও কিছুর নামের সঙ্গে ‘বাংলা’ কথাটির অস্তিত্ব খুঁজিয়া পাওয়া যায় নাই।"-উক্তিতি কার ?\n',
#    '"আজ হইতে পাকিস্তানের পূর্বাঞ্চলীয় প্রদেশটির নাম ‘পূর্ব পাকিস্তান’ এর পরিবর্তে শুধুমাত্র ‘বাংলাদেশ’।\'- উক্তিটি কার ?\n',
#    nan,
#    nan],
#   ['কত সালে ২য় বারের মত শেখ মুজিবের রাজনৈতিক কাজ বন্ধ করা হয় ?',
#    'পরের বার কখন  রাজনৈতিক কর্মসূচির ওপর থেকে নিষেধাজ্ঞা তুলে নেওয়া হয়?',
#    '১৯৫৮ এর পরে কখন  রাজনৈতিক কর্মসূচির ওপর থেকে নিষেধাজ্ঞা তুলে নেওয়া হয়?',
#    nan],
#   ['কত সালে ১ম বারের মত শেখ মুজিবের রাজনৈতিক কাজ বন্ধ করা হয় ?',
#    'কখন  রাজনৈতিক কর্মসূচির ওপর থেকে নিষেধাজ্ঞা তুলে নেওয়া হয়?',
#    '১ম বার কখন  রাজনৈতিক কর্মসূচির ওপর থেকে নিষেধাজ্ঞা তুলে নেওয়া হয়?',
#    nan],
#   ['জাতীয় নির্বাচনের তারিখ কবে দেওয়া হয় ?',
#    ' কবে জাতীয় নির্বাচনের তারিখ দেওয়া হয় ?',
#    ' জাতীয় নির্বাচন কবে হয় ?',
#    nan],
#   ['প্রাদেশিক নির্বাচনের তারিখ কবে দেওয়া হয় ?',
#    ' কবে প্রাদেশিক নির্বাচনের তারিখ দেওয়া হয় ?',
#    'প্রাদেশিক নির্বাচনের কবে হয় ?',
#    nan],
#   ['কোন কারনে শেখ মুজিবের রাজনৈতিক কাজ বন্ধ করা হয় ?',
#    'কিসের জন্য শেখ মুজিবের রাজনৈতিক কর্মসূচির ওপর থেকে নিষেধাজ্ঞা তুলে নেওয়া হয়?',
#    nan,
#    nan],
#   ['কত তারিখে পূর্ব বাংলায় ভয়াবহ ঝড় এবং জলোচ্ছ্বাস হয় ?',
#    'পূর্ব বাংলায় কবে ১০ লক্ষ মানুষ মারা যায় ?',
#    nan,
#    nan],
#   [' ভয়াবহ ঝড় এবং জলোচ্ছ্বাসে কতজন মানুষ, মারা যায় ?',
#    '১৯৭০ শালে কত মানুষ মারা যায় ?',
#    nan,
#    nan],
#   ['শেখ মুজীব ১৯৭০ সালে নির্বাচনের কাজ থামায় কেন ?', nan, nan, nan],
#   ['১৯৭০ সালে বঙ্গবন্ধু কোন কাজ স্থগিত করে ত্রাণ কাজে ঝাঁপিয়ে পড়েন?',
#    'শেখ মুজীব  নির্বাচনের কাজ থামায় দিয়ে কোন কাজে লেগে পরে ?',
#    nan,
#    nan],
#   ['জাতীয় পরিষদ নির্বাচন কবে হয়েছিলো ?',
#    'কোন সময় জাতীয় পরিষদ নির্বাচন হয়েছিলো ?',
#    'জাতীয় পরিষদ নির্বাচনের সময় কাল কত ?',
#    nan],
#   ['১৯৭০ এর নির্বাচনে নেতৃত্ব দিয়েছিলো কে ?',
#    'জাতীয় পরিষদ নির্বাচনের নেতা কে ছিলেন  ?',
#    'কোন নেতা ১৯৭০ সালে নির্বাচনের নেতৃত্ব দেন ?',
#    nan],
#   ['জাাতীয় নির্বাচনে আওয়ামী লীগ কয়টি আসন পায় ?',
#    '১৯৭০ এর নির্বাচনে আওয়ামী লীগ কয়টি আসন পায় ?',
#    '৭০ এর নির্বাচনে মুজিবের দল  কয়টি আসন পেয়েছিলো ?',
#    nan],
#   ['১৯৭০ এর নির্বাচনে মোট কয়টি আসন ছিল ?',
#    '৭০ এর নির্বাচনে কত আসন ছিল ?',
#    'জাাতীয়  পরিষদ নির্বাচনে কত আসন ছিল ?',
#    nan],
#   ['জাতীয় পরিষদ নির্বাচনে বিজয়ী হয় কোন দল ?',
#    '১৯৭০ এর নির্বাচনে নির্বাচনে বিজয়ী দল ?',
#    nan,
#    nan],
#   ['প্রাদেশিক নির্বাচন কবে হয়  ?',
#    'কবে প্রাদেশিক নির্বাচন হয়  ? ',
#    'কত সালে প্রাদেশিক নির্বাচন অনুষ্ঠিত হয়  ? ',
#    nan],
#   ['আওয়ামী লীগ ১৯৭০ সালের নির্বাচনে কতটি আসন লাভ করে ?',
#    'প্রাদেশিক নির্বাচনে আওয়ামী লীগ কতটি আসন লাভ করে   ?',
#    ' ',
#    nan],
#   ['প্রাদেশিক নির্বাচন কত টি আসন ছিল ?',
#    '১৯৭০ এর নির্বাচনে মোট কত আসন ছিল ? ',
#    nan,
#    nan],
#   ['কোন ঘটনার প্রেক্ষিতে ১৯৭০ এর নির্বাচনে আওয়ামী লীগ বিপুল সাড়া পায় ?',
#    'প্রাদেশিক নির্বাচনে কোন ঘটনার জন্য আওয়ামী লীগ বিপুল সাড়া পায় ?',
#    'প্রাদেশিক নির্বাচনে আওয়ামী লীগ বিপুল সাড়া পাওয়ার কারন কি ছিল  ?',
#    nan],
#   ['আওয়ামী লিগের প্রতিনিধিদের কবে শপথ করানো হয় ?',
#    '১৯৭১ এর কত তারিখ আওয়ামী নেতারা শপথ নেন ?',
#    nan,
#    nan],
#   ['কে আওয়ামী লিগের প্রতিনিধিদের শপথ করান ?',
#    'আওয়ামী নেতাদের কে শপথ পাঠ করান ? ',
#    nan,
#    nan],
#   ['আওয়ামী লিগের প্রতিনিধিদের কোথায় শপথ গ্রহন করেন ?',
#    'কোন জায়গায় আওয়ামী নেতারা শেখ মুজিবের সাথে শপথ নেন ? ',
#    '১৯৭০ এর নির্বাচনে জয়ী নেতারা কোথায় শপথ নেন ? ',
#    nan],
#   ['কত তারিখে জাতীয় পরিবেশের অধিবেশন অনুষ্ঠিত হওয়ার কথা ছিল?',
#    ' জাতীয় পরিবেশের অধিবেশন অনুষ্ঠিত হওয়ার  কথা কবে ছিল?',
#    ' ১৯৭১ সালে জাতীয় পরিবেশের অধিবেশন অনুষ্ঠিত হওয়ার  কথা কবে ছিল?',
#    nan],
#   [' জাতীয় পরিষদের অনুষ্ঠান কোথায় হওয়ার কথা ছিল?',
#    ' কোথায় জাতীয় পরিবেশের অধিবেশন অনুষ্ঠিত হওয়ার  কথা  ছিল?',
#    nan,
#    nan],
#   [' জাতীয় পরিষদের অধিবেশন অনুষ্ঠান স্থগিত করেন কে?',
#    ' কে জাতীয় পরিষদের অধিবেশন অনুষ্ঠান স্থগিত করেন ?',
#    ' জাতীয় পরিষদের অধিবেশন অনুষ্ঠান বন্ধ করেন কে?',
#    nan],
#   [' কত তারিখে সারাদেশে হরতাল পালিত হয়?',
#    '১৯৭১  সালে  কত তারিখে সারাদেশে হরতাল পালিত হয়?',
#    '১৯৭১  সালে  কবে সারাদেশে হরতাল পালিত হয়?',
#    nan],
#   ['পাকিস্তানিদের ষড়যন্ত্রের বিরুদ্ধে কোথায় গণবিক্ষোভ শুরু হয়?',
#    '১৯৭১ সালে কোথায় পাকিস্তানিদের ষড়যন্ত্রের বিরুদ্ধে  গণবিক্ষোভ হয়?',
#    'এ দেশের মানুষ কোথায় পাকিস্তানিদের ষড়যন্ত্রের বিরুদ্ধে কোথায় বিক্ষোভ করে?',
#    nan],
#   ['১৯৭১ সালের ২রা মার্চ থেকে সারাদেশ হরতাল পরিচালিত হয় কার নির্দেশে ?',
#    'কে হারতাল পালনের আদেশ দেন ?',
#    'হারতাল পালন করতে বলেন কে ?',
#    nan],
#   ['কত তারিখে জাতীয় পরিষদের অধিবেশন অনুষ্ঠান  স্থগিত ঘোষণা করা হয়?',
#    'কবে জাতীয় পরিষদের অধিবেশন অনুষ্ঠান  স্থগিত ঘোষণা করা হয়?',
#    nan,
#    nan],
#   ['কখন থেকে সারাদেশে বঙ্গবন্ধুর নির্দেশ পালিত হয়?\xa0',
#    'কবে থেকে সারাদেশে বঙ্গবন্ধুর নির্দেশ পালিত হয়?\xa0',
#    'কোন সময়  থেকে সারাদেশে বঙ্গবন্ধুর নির্দেশ পালিত হয়?\xa0',
#    nan],
#   ['কখন থেকে সারাদেশে বঙ্গবন্ধুর নির্দেশ পালিত হয়?\xa0',
#    'কবে থেকে সারাদেশে বঙ্গবন্ধুর নির্দেশ পালিত হয়?\xa0',
#    'কোন সময়  থেকে সারাদেশে বঙ্গবন্ধুর নির্দেশ পালিত হয়?\xa0',
#    nan],
#   [' কত\xa0 তারিখে বঙ্গবন্ধু অসহযোগ আন্দোলনের ডাক দেন ?',
#    'কবে বঙ্গবন্ধু অসহযোগ আন্দোলনের ডাক দেন ?',
#    ' অসহযোগ আন্দোলনের ডাক দেয় কবে ?',
#    nan],
#   ["কত তারিখে বঙ্গবন্ধুকে 'জাতির জনক' উপাধিতে ভূষিত করা হয় ?",
#    'জাতির জনক নাম কবে দেওয়া হয় ?',
#    'কবে জাতির জনক নাম দেওয়া হয় ?',
#    'জাতির জনক উপাধি কবে দেওয়া হয় ?'],
#   ['বঙ্গবন্ধুর অনুমোদন ক্রমে ছাত্রলীগের পক্ষ থেকে কী পাঠ করা হয়?',
#    'বঙ্গবন্ধুর অনুমোদন ক্রমে ছাত্রলীগের পক্ষ থেকে কী পাঠ করা হয়?',
#    ' পল্টন ময়দানে ছাত্রলীগের পক্ষ থেকে কী পাঠ করা হয়?',
#    nan],
#   ['১৯৭১ সালে কাকে বাংলাদেশের সর্বাধিনায়ক ঘোষণা করা হয়?',
#    'বাংলাদেশের সাধিনতের সর্বাধিনায়ক ঘোষণা করা হয়?',
#    nan,
#    nan],
#   ['অসহযোগ আন্দোলনের ডাক দেওয়া হয় কোথায় ?',
#    'কোন জায়গায় অসহযোগ আন্দোলনের ডাক দেওয়া হয়  ?',
#    nan,
#    nan],
#   ['কার অনুমোদনক্রমে স্বাধীনতার ইশতেহার পাঠ করা হয় ? ',
#    'স্বাধীনতার ইশতেহার পাঠ করাতে বলে কে  ? ',
#    'কে অনুমুতি দিলে স্বাধীনতার ইশতেহার পাঠ করা হয় ? ',
#    nan],
#   ['কোথায় বঙ্গবন্ধুকে\xa0 সর্বাধিনায়ক হিসেবে ঘোষণা করা হয়?',
#    ' বঙ্গবন্ধুকে\xa0 সর্বাধিনায়ক হিসেবে কোথায় ঘোষণা করা হয়?',
#    nan,
#    nan],
#   ['স্বাধীনতা যুদ্ধের চূড়ান্ত রণ-কৌশলের ঘোষণা দেন কে ?',
#    'মুক্তিযুদ্ধের চূড়ান্ত রণকৌশলের ঘোষণা দেন কে ?',
#    nan,
#    nan],
#   ['কবে  বঙ্গবন্ধু স্বাধীনতা যুদ্ধের চূড়ান্ত রণ-কৌশলের ঘোষণা দেন ?',
#    'কবে শেখ মুজিব স্বাধীনতা যুদ্ধের চূড়ান্ত রণ-কৌশলের ঘোষণা দেন?',
#    nan,
#    nan],
#   ['কোথায়  বঙ্গবন্ধু স্বাধীনতা যুদ্ধের চূড়ান্ত রণ-কৌশলের ঘোষণা দেন ?',
#    nan,
#    nan,
#    nan],
#   ['কিভাবে শেখ মুজিব পাকিস্তানিদের শাসনকে অস্বীকার করেন?',
#    '৭ মার্চের ভাষণে শেখ মুজিব কিভাবে পাকিস্তানের শাসনকে অস্বীকার করেন?',
#    nan,
#    nan],
#   [' বঙ্গবন্ধু শেখ মুজিবুর রহমান কত সময় ব্যাংক খোলা রাখতে বলেন ?',
#    '৭ মার্চের ভাষণে শেখ মুজিব কতক্ষণ ব্যাংক খোলা রাখার কথা বলেছিলেন?',
#    nan,
#    nan],
#   ["এবারের সংগ্রাম আমাদের মুক্তির সংগ্রাম, এবারের সংগ্রাম আমাদের স্বাধীনতার সংগ্রাম' ভাষণটি শেখ মুজিব কবে দেন ?",
#    nan,
#    nan,
#    nan],
#   [" ট্যাক্স বন্ধ করে দেওয়া হলো 'কথাটি কবে বললেন ?",
#    '৭মার্চে কে ট্যাক্স বন্ধ করে দেওয়ার কথাটি বলেছিলেন?',
#    nan,
#    nan],
#   ['৭ ই মার্চের ভাষণ কত সময় ধরে হয়?',
#    'ঐতিহাসিক ৭মার্চের ভাষণ কত সময় দীর্ঘ ছিল?',
#    nan,
#    nan],
#   ["এটি আসলে স্বাধীনতার মূল দলিল।'- কথাটি কার ?",
#    '৭ মার্চের ভাষণকে বাঙ্গালির স্বাধীনতার মূল দলিল বলে আখ্যায়িত করেছিলেন কে?',
#    nan,
#    nan],
#   ["এটি আসলে স্বাধীনতার মূল দলিল।'- কথাটি কার ?",
#    '৭ মার্চের ভাষণকে বাঙ্গালির স্বাধীনতার মূল দলিল বলে আখ্যায়িত করেছিলেন কে?',
#    nan,
#    nan],
#   ["এটি আসলে স্বাধীনতার মূল দলিল।'- কথাটি কি সম্ভন্ধে বলা হইসে  ?",
#    nan,
#    nan,
#    nan],
#   ["এটি আসলে স্বাধীনতার মূল দলিল।'- কথাটি কি সম্ভন্ধে বলা হইসে  ?",
#    nan,
#    nan,
#    nan],
#   ['নেলসন ম্যান্ডেলা কোন দেশের ?',
#    'নেলসন ম্যান্ডেলা কোন দেশের নাগরিক ছিলেন?',
#    nan,
#    nan],
#   ['শেখ মুজিবকে নিউজ উইক কোন উপাধি দেয় ?',
#    'নিউজ উইক শেখ মুজিবকে কি উপাধি দেয়?',
#    nan,
#    nan],
#   ['পোয়েট অব পলিটিক্স রাজনীতির কবি উপাধি শেখ মুজিবকে কারা দেয়  ?',
#    'কোন ম্যাগাজিন শেখ মুজিবকে পোয়েট অব পলেটিক্স উপাধি দেয়?',
#    nan,
#    nan],
#   ['পোয়েট অব পলিটিক্স রাজনীতির কবি উপাধি শেখ মুজিবকে কারা দেয়  ?',
#    'কোন ম্যাগাজিন শেখ মুজিবকে পোয়েট অব পলেটিক্স উপাধি দেয়?',
#    nan,
#    nan],
#   ['৭ ই মার্চের ভাসন কে কি হিসেবে স্বীকৃতি দিয়েছে ইউনেস্কো ?',
#    'ইউনেস্কো ৭মার্চের ভাষণকে কি হিসেবে  স্বীকৃতি দিয়েছে?',
#    nan,
#    nan],
#   ['৭ ই মার্চের ভাসন কে কি হিসেবে স্বীকৃতি দিয়েছে ইউনেস্কো ?',
#    'ইউনেস্কো ৭মার্চের ভাষণকে কি হিসেবে  স্বীকৃতি দিয়েছে?',
#    nan,
#    nan],
#   ['বাংলাদেশের স্বাধীনতার মৌলিক ঘোষণা কোনটিকে বলে ?', nan, nan, nan],
#   ['বাংলাদেশের স্বাধীনতার মৌলিক ঘোষণা কোনটিকে বলে ?', nan, nan, nan],
#   ['পোয়েট অব পলিটিক্স রাজনীতির কবি  কাকে বলা হয় ?',
#    'নিউজ উইক কাকে রাজনীতির কবি বলে আখ্যায়িত করে?',
#    nan,
#    nan],
#   ['পোয়েট অব পলিটিক্স রাজনীতির কবি  কাকে বলা হয় ?',
#    'নিউজ উইক কাকে রাজনীতির কবি বলে আখ্যায়িত করে?',
#    nan,
#    nan],
#   ['কত তারিখকে কাল রাত্রি বলা হয় ?',
#    'জাতীয় গণহত্যা দিবস কবে?',
#    'কোন দিনটি জাতীয় গণহত্যা দিবস হিসেবে পালিত হয়?',
#    nan],
#   ['২৫ তারিখ কে ঢাকা ছাড়ে কে ?',
#    'মার্চের ২৫ তারিখ কে ঢাকা ত্যাগ করে?',
#    nan,
#    nan],
#   ['কার আদেশে ২৫ মার্চের হত্যাযজ্ঞ চালানো হয়?',
#    '২৫শে মার্চ গণহত্যার মূলহোতা কে ছিল?',
#    'কার আদেশে ২৫ শে মার্চ গণহত্যা চালানো হয়?',
#    nan],
#   ["আমি কোথাও যাব না। আমি যদি আত্মগোপন করি, তাহলে ঢাকা শহর থাকবে না' কথাটি কে বলেন ?",
#    'আমি আত্মগোপন করলে ঢাকা শহর থাকবে না-কথাগুলো কে বলেছিলেন?',
#    nan,
#    nan],
#   ["আমি কোথাও যাব না। আমি যদি আত্মগোপন করি, তাহলে ঢাকা শহর থাকবে না'- কথাটি শেখ মুজিব কবে বলেন ?",
#    'আমি আত্মগোপন করলে ঢাকা শহর থাকবে না-কথাগুলো কথাগুলো শেখ মুজিব কবে বলেছিলেন?',
#    nan,
#    nan],
#   ['সবার আগে  স্বাধীন রাষ্ট্র বলে ঘোষণা করলেন কে  ?',
#    'পূর্ব-পরিকল্পনা অনুসারে সরাসরি বাংলাদেশকে স্বাধীন রাষ্ট্র বলে ঘোষণা করেন কে?',
#    nan,
#    nan],
#   ['শেখ মুজিব কবে বাংলাদেশকে স্বাধীন রাষ্ট্র বলে ঘোষণা করলেন?',
#    'শেখ মুজিব কবে বাংলাদেশকে স্বাধীন বলে ঘোষণা করেন?',
#    nan,
#    nan],
#   ['স্বাধীনতার ঘোষণা প্রথম কে দেন ?',
#    'কে প্রথম স্বাধীনতার ঘোষণা দেয়?',
#    nan,
#    nan],
#   ['স্বাধীনতার ঘোষণা প্রথম শেখ মুজিব কখন দেন ?',
#    'কবে শেখ মুজিব স্বাধীনতার ঘোষণা দেন?',
#    nan,
#    nan],
#   ['১৯৭১ সালে পাকিস্তানি সেনাবাহিনীর গণসংযোগ কর্মকর্তা কে ছিলেন ?',
#    'যুদ্ধের সময় পাকিস্তানি বাহিনীর গণসংযোগ কর্মকর্তা কে ছিলেন?',
#    nan,
#    nan],
#   ['শেখ মুজিবুর রহমানের পূর্ব পাকিস্তানকে গণপ্রজাতন্ত্রী বাংলাদেশ হিসেবে ঘোষণা করেছেন কবে ?',
#    'কবেে শেখ মুজিব পূর্ব পাকিস্তানকে বাংলাদেশ হিসেবে ঘোষণা করেছিলেন?',
#    nan,
#    nan],
#   ["কে প্রথম পূর্ব পাকিস্তানকে গণপ্রজাতন্ত্রী বাংলাদেশ হিসেবে ঘোষণা করেছেন।' ?",
#    'কে সর্বপ্রথম পূর্ব পাকিস্তানকে বাংলাদেশ হিসেবে ঘোষণা দিয়েছিলেন?',
#    nan,
#    nan],
#   ['স্বাধীনতার ঘোষণা প্রথম শেখ মুজিব কিসের মাধ্যমে দেন ?',
#    'কোন মাধ্যমে শেখ মুজিব স্বাধীনতার ঘোষণা দিয়েছিলেন?',
#    'কোন যোগাযোগ মাধ্যমে শেখ মুজিব স্বাধীনতার ঘোষণা দিয়েছিলেন?',
#    nan],
#   ['মুক্তিযুদ্ধের সময় ব্রিটেনের প্রধানমন্ত্রী কে ছিলেন?',
#    'যুদ্ধের সময় যুক্তরাজ্যের প্রধানমন্ত্রী কে ছিলেন?',
#    'মুক্তিযুদ্ধের সময় ব্রিটিশ প্রধানমন্ত্রী কে ছিলেন?',
#    nan],
#   ['মুক্তিযুদ্ধের সময় ব্রিটেনের প্রধানমন্ত্রী কে ছিলেন?',
#    'যুদ্ধের সময় যুক্তরাজ্যের প্রধানমন্ত্রী কে ছিলেন?',
#    'মুক্তিযুদ্ধের সময় ব্রিটিশ প্রধানমন্ত্রী কে ছিলেন?',
#    nan],
#   ['বাংলাদেশের স্বাধীনতার ঘোষণা নিয়ে ব্রিটেনের প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে ব্রিটেনের প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে ব্রিটিশ প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে  এডওয়ার্ড হিথ কি বলেছিলেন?'],
#   ['বাংলাদেশের স্বাধীনতার ঘোষণা নিয়ে ব্রিটেনের প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে ব্রিটেনের প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে ব্রিটিশ প্রধানমন্ত্রী এডওয়ার্ড হিথ কি বলেছিলেন?',
#    'স্বাধীনতার ঘোষণা নিয়ে  এডওয়ার্ড হিথ কি বলেছিলেন?'],
#   ['কোন সংগঠনের স্পট রিপোর্টে শেখ মুজিবের স্বাধীনতা ঘোষণার কথা উল্লেখ আছে?',
#    'কাদের স্পট রিপোর্টে শেখ মুজিবের  স্বাধীনতা ঘোষণার কথা উল্লেখ আছে?',
#    'কোন সংগঠনের রিপোর্টে শেখ মুজিবের স্বাধীনতা ঘোষণার কথা উল্লেখ আছে?',
#    'কোন সংগঠনের রিপোর্টে শেখ মুজিবের স্বাধীনতা ঘোষণার কথা সম্পর্কে বলা আছে?'],
#   ['কোন সংগঠনের স্পট রিপোর্টে শেখ মুজিবের স্বাধীনতা ঘোষণার কথা উল্লেখ আছে?',
#    'কাদের স্পট রিপোর্টে শেখ মুজিবের  স্বাধীনতা ঘোষণার কথা উল্লেখ আছে?',
#    'কোন সংগঠনের রিপোর্টে শেখ মুজিবের স্বাধীনতা ঘোষণার কথা উল্লেখ আছে?',
#    'কোন সংগঠনের রিপোর্টে শেখ মুজিবের স্বাধীনতা ঘোষণার কথা সম্পর্কে বলা আছে?'],
#   ['ডিফেন্স ইন্টেলিজেন্স এজেন্সি (ডিআইএ ) কি?',
#    'ডিআইএ কি?',
#    'ডিফেন্স ইন্টেলিজেন্স এজেন্সি কোন ধরণের সংগঠন?',
#    nan],
#   ['ডিফেন্স ইন্টেলিজেন্স এজেন্সি (ডিআইএ ) কি?',
#    'ডিআইএ কি?',
#    'ডিফেন্স ইন্টেলিজেন্স এজেন্সি কোন ধরণের সংগঠন?',
#    nan],
#   ['ডিআইএ এর কোন রিপোর্টে পাকিস্তানের পূর্ব অংশকে স্বাধীন গণপ্রজাতন্ত্রী বাংলাদেশ হিসেবে ঘোষণা করার কথা উল্লেখ আছে?',
#    'ডিফেন্স ইন্টেলিজেন্স এজেন্সির কোন রিপোর্টে পূর্ব পাকিস্তানকে বাংলাদেশ হিসেবে ঘোষণা করার কথা উল্লেখ আছে?',
#    nan,
#    nan],
#   ['ডিআইএ এর কোন রিপোর্টে পাকিস্তানের পূর্ব অংশকে স্বাধীন গণপ্রজাতন্ত্রী বাংলাদেশ হিসেবে ঘোষণা করার কথা উল্লেখ আছে?',
#    'ডিফেন্স ইন্টেলিজেন্স এজেন্সির কোন রিপোর্টে পূর্ব পাকিস্তানকে বাংলাদেশ হিসেবে ঘোষণা করার কথা উল্লেখ আছে?',
#    nan,
#    nan],
#   ['ডেভিড লোশাক কে ছিলেন?', 'ডেভিড লোশাক এর পরিচয় কি?', nan, nan],
#   ['ডেভিড লোশাক কে ছিলেন?', 'ডেভিড লোশাক এর পরিচয় কি?', nan, nan],
#   ['বঙ্গবন্ধু কর্তৃক স্বাধীনতা ঘোষণার বিষয়ে ব্রিটেনের দ্য ডেইলি টেলিগ্রাফ পত্রিকার সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    'স্বাধীনতা ঘোষণার বিষয়ে ব্রিটেনের দ্য ডেইলি টেলিগ্রাফ পত্রিকার সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    'স্বাধীনতা ঘোষণার বিষয়ে  সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু কর্তৃক স্বাধীনতা ঘোষণার বিষয়ে ব্রিটেনের দ্য ডেইলি টেলিগ্রাফ পত্রিকার সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    'স্বাধীনতা ঘোষণার বিষয়ে ব্রিটেনের দ্য ডেইলি টেলিগ্রাফ পত্রিকার সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    'স্বাধীনতা ঘোষণার বিষয়ে  সাংবাদিক ডেভিড লোশাক কি লিখেছিলেন?',
#    nan],
#   ['বাংলাদেশের প্রথম সরকার কোনটি ?',
#    'বাংলাদেশের প্রথম সরকারের নাম কি?',
#    'গণপ্রজাতন্ত্রী বাংলাদেশ অস্থায়ী সরকার বলা হয় কোন সরকারকে?',
#    'প্রবাসী বাংলাদেশ সরকার কোনটি?'],
#   ['বাংলাদেশের মানুষের অবিসংবাদিত নেতা কে ছিলেন ?',
#    'কাকে অবিসংবাদিত নেতা বলা হয়?',
#    nan,
#    nan],
#   ['মুজিব নগরের রাষ্ট্র প্রধান কে ?',
#    'মুজিবনগর সরকারের রাষ্টপ্রধান কে ছিলেন?',
#    'মুজিবনগর সরকারের রাষ্টপতির নাম কি?',
#    nan],
#   ['মুজিব নগরের উপ-রাষ্ট্র প্রধান কে ?',
#    'মুজিবনগর সরকারের উপরাষ্ট্রপতির নাম কি?',
#    nan,
#    nan],
#   ['বাংলাদেশের প্রথম সরকার কবে গঠিত হয়  ?',
#    'মুজিবনগর সরকার কবে গঠিত হয়?',
#    nan,
#    nan],
#   ['স্বাধীন বাংলাদেশের প্রথম সরকার আনুষ্ঠানিকভাবে শপথ গ্রহণ করে কবে ?',
#    'মুজিবনগর সরকার কবে আনুষ্ঠানিকভাবে শপথ গ্রহণ করে?',
#    'মুজিবনগর সরকার শপথ গ্রহণ করে কবে?',
#    nan],
#   ['কোথায় স্বাধীন বাংলাদেশের প্রথম সরকার আনুষ্ঠানিকভাবে শপথ গ্রহণ করে  ?',
#    'কোথায় মুজিবনগর সরকার শপথ গ্রহণ করে?',
#    nan,
#    nan],
#   ['স্বাধীন বাংলাদেশের প্রথম সরকারের রাষ্ট্রপতি হিসেবে কে শপথ গ্রহণ করে ?',
#    'স্বাধীন দেশের প্রথম রাষ্ট্রপতি কে ছিল?',
#    nan,
#    nan],
#   ['১৯৭১ সালে এ দেশের জনসংখ্যা কত ছিল ?',
#    'মুক্তিযুদ্ধের সময় দেশের জনসংখ্যা কত ছিলো?',
#    nan,
#    nan],
#   ['মুজিবনগর সরকারের প্রধানমন্ত্রী কে ছিলেন ?',
#    'মুজিবনগর সরকারের প্রধানমন্ত্রী কে নির্বাচিত হন ?',
#    'কাকে  মুজিবনগর সরকারের প্রধানমন্ত্রী বানানো হয়েছিলো ?',
#    nan],
#   ['মুজিবনগর সরকারের উপ-রাস্ত্রপতি  কে ছিলেন ?', nan, nan, nan],
#   ['কবে দ্য ফিন্যান্সিয়াল টাইমস পত্রিকার মাধ্যমে প্রথম বঙ্গবন্ধুকে আটকের ঘটনাটি আনুষ্ঠানিকভাবে ঘোষণা দেয় পাকিস্তান সরকার ?',
#    'কবে পাকিস্তান আনুষ্ঠানিকভাবে শেখ মুজিবকে আটক করার ঘটনাটি প্রকাশ করে?',
#    nan,
#    nan],
#   ['কবে দ্য ফিন্যান্সিয়াল টাইমস পত্রিকার মাধ্যমে প্রথম বঙ্গবন্ধুকে আটকের ঘটনাটি আনুষ্ঠানিকভাবে ঘোষণা দেয় পাকিস্তান সরকার ?',
#    'কবে পাকিস্তান আনুষ্ঠানিকভাবে শেখ মুজিবকে আটক করার ঘটনাটি প্রকাশ করে?',
#    nan,
#    nan],
#   ['শেখ মুজিবকে আটকের কথা কোথায় পাকিস্তান সরকার প্রথম জানায় ?',
#    'কোন পত্রিকায় মাধ্যমে পাকিস্তানকে আটক করার ঘটনাটি প্রকাশ করে পাকিস্তান?',
#    nan,
#    nan],
#   ['শেখ মুজিবকে আটকের কথা কোথায় পাকিস্তান সরকার প্রথম জানায় ?',
#    'কোন পত্রিকায় মাধ্যমে পাকিস্তানকে আটক করার ঘটনাটি প্রকাশ করে পাকিস্তান?',
#    nan,
#    nan],
#   ['কিসের অভিযোগে সামরিক আদালতে গোপন বিচারের মাধ্যমে বঙ্গবন্ধুকে হত্যার নীলনকশা করে?',
#    'কিসের অভিযোগে শেখ মুজিবকে হত্যার নীল  নকশা করা হয়?',
#    nan,
#    nan],
#   ['কিসের অভিযোগে সামরিক আদালতে গোপন বিচারের মাধ্যমে বঙ্গবন্ধুকে হত্যার নীলনকশা করে?',
#    'কিসের অভিযোগে শেখ মুজিবকে হত্যার নীল  নকশা করা হয়?',
#    nan,
#    nan],
#   ['কত সালে বঙ্গবন্ধুর কারাজীবন নিয়ে বড় আকারে সংবাদ প্রকাশিত হয় ?',
#    'কবে শেখ মুজিবের কারাজীবন নিয়ে সংবাদ প্রকাশিত হয়েছিল?',
#    nan,
#    nan],
#   ['কত সালে বঙ্গবন্ধুর কারাজীবন নিয়ে বড় আকারে সংবাদ প্রকাশিত হয় ?',
#    'কবে শেখ মুজিবের কারাজীবন নিয়ে সংবাদ প্রকাশিত হয়েছিল?',
#    nan,
#    nan],
#   ['ইরানের কায়হান ইন্টারন্যাশনাল পত্রিকায় বঙ্গবন্ধু কে নিয়ে কী বলা হয়েছিল ?',
#    'কায়হান পত্রিকায় শেখ মুজিব সম্পর্কিত কোন  তথ্য প্রকাশ করা হয়?',
#    nan,
#    nan],
#   ['ইরানের কায়হান ইন্টারন্যাশনাল পত্রিকায় বঙ্গবন্ধু কে নিয়ে কী বলা হয়েছিল ?',
#    'কায়হান পত্রিকায় শেখ মুজিব সম্পর্কিত কোন  তথ্য প্রকাশ করা হয়?',
#    nan,
#    nan],
#   [' কোন পত্রিকায় মুজিবের কারাজীবন নিয়ে সংবাদ প্রকাশিত হয় ?',
#    'কোন আন্তর্জাতিক পত্রিকা শেখ মুজিবের কারাজীবন নিয়ে সংবাদ প্রকাশ করে?',
#    nan,
#    nan],
#   [' কোন পত্রিকায় মুজিবের কারাজীবন নিয়ে সংবাদ প্রকাশিত হয় ?',
#    'কোন আন্তর্জাতিক পত্রিকা শেখ মুজিবের কারাজীবন নিয়ে সংবাদ প্রকাশ করে?',
#    nan,
#    nan],
#   ['কোন পত্রিকা শেখ  মুজিবকে দেশদ্রোহী অপরাধী বলে উল্লেখ করে?', nan, nan, nan],
#   ['কোন পত্রিকা শেখ  মুজিবকে দেশদ্রোহী অপরাধী বলে উল্লেখ করে?', nan, nan, nan],
#   ['মুজিব  কারাগারে জীবিত আছে  এ কথা কে বলেছেন?',
#    'কে শেখ মুজিবের জীবিত থাকার কথা প্রকাশ করেন?',
#    'সংবাদ সম্মেলনে কে শেখ মুজিবের জীবিত থাকার কথা বলেছিলেন?',
#    nan],
#   ['মুজিব  কারাগারে জীবিত আছে  এ কথা কে বলেছেন?',
#    'কে শেখ মুজিবের জীবিত থাকার কথা প্রকাশ করেন?',
#    'সংবাদ সম্মেলনে কে শেখ মুজিবের জীবিত থাকার কথা বলেছিলেন?',
#    nan],
#   ['কত সালে ইয়াহিয়া খান জানান মুজিব  কারাগারে জীবিত আছেন ?',
#    'কবে শেখ মুজিবের কারাগারে জীবিত থাকার কথা প্রকাশ পায়?',
#    nan,
#    nan],
#   ['কত সালে ইয়াহিয়া খান জানান মুজিব  কারাগারে জীবিত আছেন ?',
#    'কবে শেখ মুজিবের কারাগারে জীবিত থাকার কথা প্রকাশ পায়?',
#    nan,
#    nan],
#   [' জেনারেল ইয়াহিয়া খান কোথায় জানান মুজিব কারাগারে জীবিত আছে ?',
#    'কোন সংবাদকে ইয়াহিয়া খান মুজিবের জীবিত থাকার কথা জানান?',
#    nan,
#    nan],
#   [' জেনারেল ইয়াহিয়া খান কোথায় জানান মুজিব কারাগারে জীবিত আছে ?',
#    'কোন সংবাদকে ইয়াহিয়া খান মুজিবের জীবিত থাকার কথা জানান?',
#    nan,
#    nan],
#   ['মুজিবকে খুনের পরিকল্পনা করেন কারা ? ',
#    'মুজিবকে হত্যার পরিকল্পনা করেছিল কারা?',
#    nan,
#    nan],
#   ['মুজিবকে খুনের পরিকল্পনা করেন কারা ? ',
#    'মুজিবকে হত্যার পরিকল্পনা করেছিল কারা?',
#    nan,
#    nan],
#   ['শেখ মুজিবকে কবর খুড়ে কখন মৃত্যুর ভয় দেখানো হয় ?', nan, nan, nan],
#   ['শেখ মুজিবকে কবর খুড়ে কখন মৃত্যুর ভয় দেখানো হয় ?', nan, nan, nan],
#   ['বাংলাদেশের স্বাধীনতার পথে কে অবিচল থাকেন ?',
#    'স্বাধীনতার পথে কে অবিচল থাকেন ?',
#    nan,
#    nan],
#   ['বাংলাদেশের স্বাধীনতার পথে কে অবিচল থাকেন ?',
#    'স্বাধীনতার পথে কে অবিচল থাকেন ?',
#    nan,
#    nan],
#   ['মুক্তিযুদ্ধে কত জন মানুষ শহীদ হন ?',
#    'মুক্তিমুদ্ধে কত জন  প্রাণ হারান?',
#    nan,
#    nan],
#   ['মুক্তিযুদ্ধে কত জন নারী আত্মদান করেছিলেন ?',
#    'মুুক্তিযুদ্ধে কতজন নারী সম্ভ্রম হারায়?',
#    nan,
#    nan],
#   [' বাংলাদেশের স্বাধীনতা অর্জিত হয় কীভাবে?', nan, nan, nan],
#   [' বিজয় দিবস কবে?', 'বাংলাদেশ স্বাধীন হয় কবে ?', nan, nan],
#   [' বাংলাদেশ এর বিজয় অর্জনের দিন বঙ্গবন্ধু কোথায় ছিলেন ?',
#    '\n মুক্তিযুদ্ধের সময় বঙ্গবন্ধু কোথায় ছিলেন?',
#    nan,
#    nan],
#   ['যুদ্ধ পরিচালিত হয়েছিল কার নামে?', nan, nan, nan],
#   ['\n কোন স্লোগানে জনতা উদ্দীপিত হয়ে যুদ্ধ করেছিল আপামর জনতা ?',
#    'মুক্তিযুদ্ধের সময় বাঙালির কী স্লোগান ছিল?',
#    nan,
#    nan],
#   ['\xa0১৬ই ডিসেম্বর - আমাদের কী দিবস?', '১৬ ডিসেম্বর কি দিবস?', nan, nan],
#   ['\xa0১৬ই ডিসেম্বর - আমাদের কী দিবস?', '১৬ ডিসেম্বর কি দিবস?', nan, nan],
#   ['পাকিস্তান কারাগার থেকে কবে মুজিবকে ছাড়া হয় ?',
#    'কবে শেখ মুজিবকে পাকিস্তান সরকার মুক্তি দেয়?',
#    nan,
#    nan],
#   ['পাকিস্তান কারাগার থেকে কবে মুজিবকে ছাড়া হয় ?',
#    'কবে শেখ মুজিবকে পাকিস্তান সরকার মুক্তি দেয়?',
#    nan,
#    nan],
#   ['পাকিস্তান কারাগার থেকে মুজিবকে কোথায় পাঠানো হয় ?',
#    'পাকিস্তান সরকার শেখ মুজিবকে মুক্তি দিয়ে কই পাঠায়?',
#    nan,
#    nan],
#   ["বঙ্গবন্ধু . 'আমি আমার জনগণের কাছে ফিরে যেতে চাই'- কথাটি কোথায় বলেন ?",
#    nan,
#    nan,
#    nan],
#   ["আমি আমার জনগণের কাছে ফিরে যেতে চাই'- কথাগুলো কার?",
#    "আমি আমার জনগণের কাছে ফিরে যেতে চাই'- লন্ডনের হোটেলে কথাগুলো কে বলেছিলেন?",
#    nan,
#    nan],
#   ["বঙ্গবন্ধু কবে বলেছিলেন,'আমি আমার জনগণের কাছে ফিরে যেতে চাই'?",
#    nan,
#    nan,
#    nan],
#   ['স্বাধীনতার পরে কবে শেখ মুজিব এ দেশে আসে ?',
#    'স্বাধীন বাংলাদেশের মাটিতে কবে পা রাখেন বঙ্গবন্ধু?',
#    nan,
#    nan],
#   ['স্বদেশে প্রত্যাবর্তন দিবস কবে ?',
#    'জাতির জনকের স্বদেশে প্রত্যাবর্তন দিবস কবে ?',
#    nan,
#    nan],
#   ['স্বাধীনতার পরে শেখ মুজিব এ দেশে আসে কোন পদে বসেন ?',
#    'দেশে ফিরে শেখ মুজিব কোন পদের দায়িত্ব নেন?',
#    nan,
#    nan],
#   ['১০ ই জানুয়ারী কি দিবস ?', nan, nan, nan],
#   ['দেশে সংসদীয় ব্যবস্থা চালু করেন কে ?',
#    'বাংলাদেশে সংসদীয় ব্যবস্থা প্রণয়ন করেন কে?',
#    nan,
#    nan],
#   ['কত সালে দেশে সংসদীয় ব্যবস্থা চালু করা হয়  ?',
#    'কবে বাংলাদেশে সংসদীয় ব্যবস্থা চালু করা হয়?',
#    nan,
#    nan],
#   ['দেশে সংসদীয় ব্যবস্থা চালু করে শেখ মুজিব কোন পদ পায় ?',
#    'সংসদীয় শাসন ব্যবস্থায় শেখ মুজিব কোন পদ নিয়ে শপথ গ্রহণ করেন?',
#    nan,
#    nan],
#   ['কত সালে মিত্র বাহিনীকে ফেরত পাঠান বঙ্গবন্ধু ?',
#    'কবে শেখ মুজিব মিত্র বাহিনীকে ভারতে ফেরত পাঠান?',
#    nan,
#    nan],
#   ['কত সালে মিত্র বাহিনীকে ফেরত পাঠান বঙ্গবন্ধু ?',
#    'কবে শেখ মুজিব মিত্র বাহিনীকে ভারতে ফেরত পাঠান?',
#    nan,
#    nan],
#   ['মুক্তিযোদ্ধাদের সহযোগীতা করেছিল ভারতীয় কোন বাহিনী ?', nan, nan, nan],
#   ['মুক্তিযোদ্ধাদের সহযোগীতা করেছিল ভারতীয় কোন বাহিনী ?', nan, nan, nan],
#   ['স্বাধীন বাংলাদেশে বঙ্গবন্ধুর প্রথম জন্মদিন পালনের আগেই বঙ্গবন্ধু কাদের দেশে পাঠাতে সক্ষম হন ?',
#    nan,
#    nan,
#    nan],
#   ['স্বাধীন বাংলাদেশে বঙ্গবন্ধুর প্রথম জন্মদিন পালনের আগেই বঙ্গবন্ধু কাদের দেশে পাঠাতে সক্ষম হন ?',
#    nan,
#    nan,
#    nan],
#   ['ভারতে শরণার্থী হিসেবে বাংলাদেশের কত জন মানুষ আশ্রয় নিয়েছিল?',
#    'ভারতে বাংলাদেশের কতজন শরণার্থী আশ্রয় নেয়?',
#    'মুক্তিযুদ্ধের সময় বাংলাদেশের কতজন ভারতে  আশ্রয় নিয়েছিল?',
#    nan],
#   ['ভারতে শরণার্থী হিসেবে বাংলাদেশের কত জন মানুষ আশ্রয় নিয়েছিল?',
#    'ভারতে বাংলাদেশের কতজন শরণার্থী আশ্রয় নেয়?',
#    'মুক্তিযুদ্ধের সময় বাংলাদেশের কতজন ভারতে  আশ্রয় নিয়েছিল?',
#    nan],
#   ['\nমুক্তিযুদ্ধের সময় কোন দেশে বাঙালিরা আশ্রয় নিয়েছিল ?',
#    'মুক্তিযুদ্ধের সময় বাঙ্গালিরা কোথায় আশ্রয় নিয়েছিল?',
#    nan,
#    nan],
#   ['\nকে মিত্র বাহিনীক দেশে ফেরাতে সক্ষম হন ?', nan, nan, nan],
#   ['\nকে মিত্র বাহিনীক দেশে ফেরাতে সক্ষম হন ?', nan, nan, nan],
#   ["শেখ মুজিব কবে 'জুলিও কুরি' পদক পায় ?",
#    'শেখ মুজিবকে কবে জুলিও কুরি পদক দেওয়া হয়?',
#    nan,
#    nan],
#   ["শেখ মুজিব কবে 'জুলিও কুরি' পদক পায় ?",
#    'শেখ মুজিবকে কবে জুলিও কুরি পদক দেওয়া হয়?',
#    nan,
#    nan],
#   ["কারা শেখ মুজিব কবে 'জুলিও কুরি' পদক দেয় ?",
#    'কোন সংগঠন শেখ মুজিবকে জুলিও কুরি পদক দেয়?',
#    nan,
#    nan],
#   ["কারা শেখ মুজিব কবে 'জুলিও কুরি' পদক দেয় ?",
#    'কোন সংগঠন শেখ মুজিবকে জুলিও কুরি পদক দেয়?',
#    nan,
#    nan],
#   ["শেখ মুজিব কে  'জুলিও কুরি' পদক কে পরিয়ে দেয় ?",
#    'এশীয় শান্তি সম্মেলনে কে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেয়?',
#    nan,
#    nan],
#   ["শেখ মুজিব কে  'জুলিও কুরি' পদক কে পরিয়ে দেয় ?",
#    'এশীয় শান্তি সম্মেলনে কে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেয়?',
#    nan,
#    nan],
#   ["শেখ মুজিব কে  'জুলিও কুরি' পদক কবে পরিয়ে দেওয়া হয় ?",
#    'এশীয় শান্তি সম্মেলনে কবে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেওয়া হয়?',
#    nan,
#    nan],
#   ["শেখ মুজিব কে  'জুলিও কুরি' পদক কবে পরিয়ে দেওয়া হয় ?",
#    'এশীয় শান্তি সম্মেলনে কবে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেওয়া হয়?',
#    nan,
#    nan],
#   ["কোন অনুষ্ঠানে মুজিবকে 'জুলিও কুরি' পদক দেওয়া হয় ?",
#    'কোন সম্মেলনে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেওয়া হয়?',
#    nan,
#    nan],
#   ["কোন অনুষ্ঠানে মুজিবকে 'জুলিও কুরি' পদক দেওয়া হয় ?",
#    'কোন সম্মেলনে শেখ মুজিবকে জুলিও কুরি পদক পরিয়ে দেওয়া হয়?',
#    nan,
#    nan],
#   ['কথাটি কে বলেছিলেন, ‘বঙ্গবন্ধু শুধু বাংলার নন, তিনি বিশ্বের এবং তিনি বিশ্ববন্ধু।?’',
#    'বঙ্গবন্ধুকে বিশ্ববন্ধু কে বলেছিলেন?',
#    "‘বঙ্গবন্ধু শুধু বাংলার নন, তিনি বিশ্বের এবং তিনি বিশ্ববন্ধু' কথাগুলো কে বলেছিলেন?",
#    nan],
#   ['কথাটি কে বলেছিলেন, ‘বঙ্গবন্ধু শুধু বাংলার নন, তিনি বিশ্বের এবং তিনি বিশ্ববন্ধু।?’',
#    'বঙ্গবন্ধুকে বিশ্ববন্ধু কে বলেছিলেন?',
#    "‘বঙ্গবন্ধু শুধু বাংলার নন, তিনি বিশ্বের এবং তিনি বিশ্ববন্ধু' কথাগুলো কে বলেছিলেন?",
#    nan],
#   ['স্বাধীন বাংলাদেশে কোনো রাষ্ট্রনেতার   প্রথম আন্তর্জাতিক পদক লাভ কোনটি ?',
#    nan,
#    nan,
#    nan],
#   ['স্বাধীন বাংলাদেশে কোনো রাষ্ট্রনেতার   প্রথম আন্তর্জাতিক পদক লাভ কোনটি ?',
#    nan,
#    nan,
#    nan],
#   ["বিশ্বশান্তি আমার জীবনের মূলনীতি।'-কথাটি কার ?", nan, nan, nan],
#   ["বিশ্বশান্তি আমার জীবনের মূলনীতি।'-কথাটি কার ?", nan, nan, nan],
#   ['স্বাধীন দেশের প্রথম জাতীয় সংসদ নির্বাচন অনুষ্ঠিত হয় কত সালে ?',
#    'বাংলাদেশের প্রথম জাতীয় সংসদ নির্বাচন হয় কবে?',
#    nan,
#    nan],
#   ['\n  সংসদ নির্বাচনে বাংলাদেশ আওয়ামী লীগ কতটি আসনে বিজয়ী হয় ?',
#    'প্রথম জাতীয় নির্বাচনে আওয়ামী লীগ কতটি আসন পায়?',
#    nan,
#    nan],
#   ['\nদেশের প্রথম জাতীয় সংসদ নির্বাচনে আওয়ামী লীগকে নেতৃত্ব দেন কে ?\n',
#    'বাংলাদেশের প্রথম জাতীয় সংসদ নির্বাচনে আওয়ামী লীগকে  নেতৃত্ব দেন কে ?',
#    nan,
#    nan],
#   ['১৯৭৩ সালের জাতীয় সংসদ নির্বাচনে কতটি আসন ছিল ?',
#    'জাতীয় সংসদ নির্বাচনে কতটি আসন ছিল?',
#    nan,
#    nan],
#   ['আলজেরিয়ায় অনুষ্ঠিত জোট নিরপেক্ষ সম্মেলনে ভাষণ দিতে গিয়ে বঙ্গবন্ধু কী বক্তব্য দিয়েছিলেন?',
#    'জোট নিরপেক্ষ সম্মেলনে শেখ মুজিব কি বলেছিলেন?',
#    nan,
#    nan],
#   ['‘পৃথিবী আজ দুই ভাগে বিভক্ত। এক ভাগে শোষক শ্রেণি, আরেক ভাগে শোষিত। আমি শোষিতের দলে।’-কথাটি কে বলেন ?',
#    "আমি শোষিতের দলে'- কথাটি কার?",
#    "আমি শোষিতের দলে'- ভাষণে কে দিয়েছিলেন?",
#    nan],
#   ['১৯৭৩ সালে জোট নিরপেক্ষ সম্মেলন কোথায় হয় ?', nan, nan, nan],
#   [nan, nan, nan, nan],
#   [nan, nan, nan, nan],
#   [nan, nan, nan, nan],
#   [nan, nan, nan, nan],
#   [nan, nan, nan, nan],
#   [nan, nan, nan, nan],
#   ['শেখ মুজিবুর রহমান কোথায় জন্মগ্রহণ করেন ?',
#    'বঙ্গবন্ধুর জন্মস্থান কোথায়? ',
#    'বঙ্গবন্ধুর জন্মস্থান কই ? ',
#    'বঙ্গবন্ধুর গ্রামের বাড়ি কই ?'],
#   ['শেখ মুজিবুর রহমানের ডাকনাম কি ছিলো?',
#    'মুজিবের বাবা তাকে কি নামে ডাকতেন ?',
#    'বঙ্গবন্ধুর মা তাকে কি নামে ডাকতেন?',
#    'মুজিবের মা বাবা তাকে কি নামে ডাকতেন ?'],
#   ['শেখ মুজিবুর রহমানের পিতার নাম কি?',
#    'বঙ্গবন্ধুর বাবার নাম কি ?',
#    'জাতির জনকের বাবার নাম কি ?',
#    'শেখ সাহেবের বাবার নাম কি ?'],
#   ['শেখ মুজিবুর রহমানের মাতার নাম কি?',
#    'বঙ্গবন্ধুর মায়ের নাম কি ?',
#    'জাতির জনকের মায়ের নাম কি ?',
#    'শেখ সাহেবের মায়ের নাম কি ?'],
#   ['শেখ মুজিবের পূর্ব-পুরুষরা কার বংশধর ছিলেন ?',
#    'বঙ্গবন্ধুর পূর্ব-পুরুষরা কার বংশধর ছিলেন ?',
#    'কার বংশধর ছিলেন বঙ্গবন্ধুর পূর্ব-পুরুষরা?',
#    nan],
#   ['শেখ মুজিবুর রহমান কবে জন্মগ্রহন করেন ?',
#    'বঙ্গবন্ধুর জন্মসাল কতো ?',
#    'জাতির জনক কবে জন্মগ্রহন করেন ?',
#    'মুজিব কবে জন্মেছিলেন ?'],
#   ['শেখ মুজিবুর রহমান কত সালে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেন ?',
#    'বঙ্গবন্ধু কত সালে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেন ?',
#    'বঙ্গবন্ধু কত সালে প্রাতিষ্ঠানিক পড়ালেখা শুরু করেন ?',
#    nan],
#   ['শেখ মুজিবুর রহমান কত বছর বয়সে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেছিলেন ?',
#    'বঙ্গবন্ধু কত বছর বয়সে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেছিলেন?',
#    'কয় বছর বয়সে বঙ্গবন্ধু লেখাপড়া শুরু করেছিলেন ?',
#    'বঙ্গবন্ধু যখন পড়ালেখা শুরু করেন তখন তার বয়স কত ছিল?'],
#   ['শেখ মুজিবুর রহমানের প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু হয় কোন বিদ্যালয় থেকে ?',
#    'বঙ্গবন্ধুর প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু হয় কোন বিদ্যালয় থেকে ?',
#    'বঙ্গবন্ধুর কোন স্কুল থেকে লেখাপড়া শুরু করেন?',
#    'বঙ্গবন্ধুর কই থেকে লেখাপড়া শুরু করেন?'],
#   ['গিমাডাঙ্গা প্রাথমিক বিদ্যালয় কোথায় অবস্থিত ?',
#    'গিমাডাঙ্গা প্রাথমিক স্কুল কোথায় ?',
#    nan,
#    nan],
#   ['স্বদেশী আন্দোলন কতোসালে শুরু হয় ?',
#    'কোন সালকে স্বদেশী আন্দোলনের যুগ বলা হয়',
#    'বঙ্গবন্ধু  অসমাপ্ত আত্মজীবনীতে কোন সালকে স্বদেশী আন্দোলনের যুগ বলেছেন ?',
#    nan],
#   ['স্বদেশী আন্দোলন কতোসালে শুরু হয় ?',
#    'কোন সালকে স্বদেশী আন্দোলনের যুগ বলা হয়',
#    'বঙ্গবন্ধু  অসমাপ্ত আত্মজীবনীতে কোন সালকে স্বদেশী আন্দোলনের যুগ বলেছেন ?',
#    nan],
#   ['পূর্ণ দাসের বাসা কোথায় ?',
#    'পূর্ণ দাসের বাড়ি কোথায় ?',
#    'বাড়ি কই পূর্ণ দাসের ?',
#    'পূর্ণ দাসের গ্রামের বাসা কই?'],
#   ['পূর্ণচন্দ্র দাস কার সহকর্মী ছিলেন ?',
#    'পূর্ণ দাসের সহকর্মী ছিলেন কে ?',
#    nan,
#    nan],
#   ['বিদ্রোহী কবি কাজী নজ্রুল ইসলাম স্বদেশী আন্দোলনের কোন নেতাকে নিয়ে কবিতা লিখেছিলেন ?',
#    'পূর্ণ অভিনন্দন কবিতাটি কাকে নিয়ে লিখা ?',
#    'নজরুল পূর্ণ অভিনন্দন কবিতাটি কাকে নিয়ে লিখেছেন ?',
#    nan],
#   ['বিদ্রোহী কবি কাজী নজ্রুল ইসলাম স্বদেশী আন্দোলনের কোন নেতাকে নিয়ে কবিতা লিখেছিলেন ?',
#    'পূর্ণ অভিনন্দন কবিতাটি কাকে নিয়ে লিখা ?',
#    'নজরুল পূর্ণ অভিনন্দন কবিতাটি কাকে নিয়ে লিখেছেন ?',
#    nan],
#   ['পূর্ণ দাসকে নিয়ে কোন কবি কবিতা লিখেছেন ?',
#    'স্বদেশী আন্দোলনের সময় পূর্ণচন্দ্র দাসকে নিয়ে কোন কবি কবিতা লিখেছেন ?',
#    nan,
#    nan],
#   ['পূর্ণ দাসকে নিয়ে কোন কবি কবিতা লিখেছেন ?',
#    'স্বদেশী আন্দোলনের সময় পূর্ণচন্দ্র দাসকে নিয়ে কোন কবি কবিতা লিখেছেন ?',
#    nan,
#    nan],
#   ['পূর্ণ দাসকে  নিয়ে নজরুলের কবিতাটির নাম কি ছিলো ?',
#    'পূর্ণচন্দ্র দাসকে নিয়ে বিদ্রোহী কবি কাজী নজরুলের লিখা কবিতাটির নাম কি ছিলো ?',
#    'কবি নজরুলের পূর্ণচন্দ্র দাসকে নিয়ে লিখা কবিতাটির নাম কি ছিলো ?',
#    'স্বদেশী আন্দোলনের পূর্ণচন্দ্র দাসকে নিয়ে জাতীয়  কবি নজরুলের  লিখা কবিতাটির নাম কি ছিলো ?'],
#   ['পূর্ণ দাসকে  নিয়ে নজরুলের কবিতাটির নাম কি ছিলো ?',
#    'পূর্ণচন্দ্র দাসকে নিয়ে বিদ্রোহী কবি কাজী নজরুলের লিখা কবিতাটির নাম কি ছিলো ?',
#    'কবি নজরুলের পূর্ণচন্দ্র দাসকে নিয়ে লিখা কবিতাটির নাম কি ছিলো ?',
#    'স্বদেশী আন্দোলনের পূর্ণচন্দ্র দাসকে নিয়ে জাতীয়  কবি নজরুলের  লিখা কবিতাটির নাম কি ছিলো ?'],
#   ['পূর্ণ দাসকে  নিয়ে নজরুলের কবিতাটি কতসালে প্রকাশিত হয়? ',
#    'পূর্ণচন্দ্র দাসকে নিয়ে বিদ্রোহী কবি কাজী নজরুলের লিখা কবিতাটি কত সালে প্রকাশিত হয় ?',
#    'পূর্ণ অভিনন্দন কবিতাটি কতসালে প্রকাশিত হয়  ',
#    'পূর্ণ দাসকে নিয়ে লিখা নজরুলের কবিতাটি কতসালে প্রকাশিত হয় ?'],
#   ['পূর্ণ দাসকে  নিয়ে নজরুলের কবিতাটি কতসালে প্রকাশিত হয়? ',
#    'পূর্ণচন্দ্র দাসকে নিয়ে বিদ্রোহী কবি কাজী নজরুলের লিখা কবিতাটি কত সালে প্রকাশিত হয় ?',
#    'পূর্ণ অভিনন্দন কবিতাটি কতসালে প্রকাশিত হয়  ',
#    'পূর্ণ দাসকে নিয়ে লিখা নজরুলের কবিতাটি কতসালে প্রকাশিত হয় ?'],
#   ['পূর্ণ অভিনন্দন কোন কাব্যগ্রন্থে প্রকাশিত হয়ে ?',
#    'পূর্ণচন্দ্র দাসকে নিয়ে কবি নজ্রুলের কবিতাটি কোন কাব্যগ্রন্থে প্রকাশিত হয় ?',
#    nan,
#    nan],
#   ['পূর্ণ অভিনন্দন কোন কাব্যগ্রন্থে প্রকাশিত হয়ে ?',
#    'পূর্ণচন্দ্র দাসকে নিয়ে কবি নজ্রুলের কবিতাটি কোন কাব্যগ্রন্থে প্রকাশিত হয় ?',
#    nan,
#    nan],
#   ['হামিদ মাস্টার কে ছিলেন ?',
#    'কে ছিলেন হামিদ মাস্টার  ?',
#    'হামিদ মাস্টারের পরিচয় কি ?',
#    'হামিদ মাস্টারের সাথে বঙ্গবন্ধুর কি সম্পর্ক? '],
#   ['বঙ্গবন্ধুর গৃহশিক্ষকের নাম কি ছিলো ?',
#    'বঙ্গবন্ধুর লজিং মাস্টারের নাম কি ছিলো ?',
#    nan,
#    nan],
#   ['শেখ মুজিবুর রহমান কত সালে মুসলিম সেবা সমিতির সম্পাদক নিযুক্ত হন ?',
#    'বঙ্গবন্ধু কবে মুসলিম সেবা সমিতির সম্পাদক নিযুক্ত হন ?',
#    'কোন সালে বঙ্গবন্ধুকে মুসলিম সেবা সমিতির সম্পাদক নিযুক্ত করা হয় ?',
#    nan],
#   ['মুসলিম সেবা সমিতির উদ্দেশ্য কি ছিল?',
#    'মুসলিম সেবা সমিতির কি কাজ ছিল?',
#    'মুসলিম সেবা সমিতি কিভাবে অসহায়দের সাহায্য করতো?',
#    nan],
#   ['১৯৩৮ সালে অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    'বঙ্গবন্ধু গোপালগঞ্জ মিশন স্কুলের ছাত্র থাকা অবস্থায় অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    '১৯৩৮ সালে বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    nan],
#   ['১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন বঙ্গবন্ধু কোন স্কুলের ছাত্র ছিলেন?',
#    '১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন শেখ মুজিব কোন স্কুলে পড়তেন?',
#    'শেখ মুজিব কোন স্কুলের ছাত্র ছিলেন?',
#    'শেখ মুজিব কোন স্কুলে পড়তেন?'],
#   ['স্কুলের ছাদ মেরামতের জন্য শেরে বাংলা কত টাকা মঞ্জুর করেন?',
#    'স্কুলের ছাদ মেরামতের জন্য অখণ্ড বাংলার মুখ্যমন্ত্রী কত টাকা মঞ্জুর করেন?',
#    'শেরে বাংলা ছাদ মেরামত করতে কত টাকা দিয়েছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কারা এসেছিলেন?',
#    'শেখ মুজিব যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কোন কোন রাজনৈতিক ব্যক্তিবর্গ এসেছিলেন?',
#    'মুজিবদের স্কুলে কে কে পরিদর্শনে গেছিলেন?',
#    nan],
#   ['কত সালে বঙ্গবন্ধু প্রথম কারাগারে যান?',
#    'কবে শেখ মুজিব প্রথম কারাগারে যান?',
#    'কবে শেখ মুজিব প্রথম জেলবন্দী হন?',
#    nan],
#   ['স্কুলে ছাত্র থাকা অবস্থায় ১৯৩৮ সালে বঙ্গবন্ধুকে কেন কারাগারে যেতে হয়?',
#    'ছাত্রজীবনে কেন শেখ মুজিবকে কারাগারে যেতে হয়?',
#    'ছাত্রাবস্থায় কেন শেখ মুজিবকে কারা ভোগ করতে হয়?',
#    'ছাত্রজীবনে কেন শেখ মুজিবকে জেলে যেতে হয়?'],
#   ['১৯৩৮ সালে বঙ্গবন্ধুকে কতদিন কারাগারে থাকতে হয়?',
# ...
#    "আমি শোষিতের দলে'- কথাটি কার?",
#    "আমি শোষিতের দলে'- ভাষণে কে দিয়েছিলেন?",
#    nan],
#   ['১৯৭৩ সালে জোট নিরপেক্ষ সম্মেলন কোথায় হয় ?', nan, nan, nan]],
#  'টুঙ্গিপাড়া': [['শেখ মুজিবুর রহমান কোথায় জন্মগ্রহণ করেন ?',
#    'বঙ্গবন্ধুর জন্মস্থান কোথায়? ',
#    'বঙ্গবন্ধুর জন্মস্থান কই ? ',
#    'বঙ্গবন্ধুর গ্রামের বাড়ি কই ?'],
#   ['শেখ মুজিবুর রহমানের ডাকনাম কি ছিলো?',
#    'মুজিবের বাবা তাকে কি নামে ডাকতেন ?',
#    'বঙ্গবন্ধুর মা তাকে কি নামে ডাকতেন?',
#    'মুজিবের মা বাবা তাকে কি নামে ডাকতেন ?'],
#   ['শেখ মুজিবুর রহমানের পিতার নাম কি?',
#    'বঙ্গবন্ধুর বাবার নাম কি ?',
#    'জাতির জনকের বাবার নাম কি ?',
#    'শেখ সাহেবের বাবার নাম কি ?'],
#   ['শেখ মুজিবুর রহমানের মাতার নাম কি?',
#    'বঙ্গবন্ধুর মায়ের নাম কি ?',
#    'জাতির জনকের মায়ের নাম কি ?',
#    'শেখ সাহেবের মায়ের নাম কি ?'],
#   ['শেখ মুজিবের পূর্ব-পুরুষরা কার বংশধর ছিলেন ?',
#    'বঙ্গবন্ধুর পূর্ব-পুরুষরা কার বংশধর ছিলেন ?',
#    'কার বংশধর ছিলেন বঙ্গবন্ধুর পূর্ব-পুরুষরা?',
#    nan],
#   ['শেখ মুজিবুর রহমান কবে জন্মগ্রহন করেন ?',
#    'বঙ্গবন্ধুর জন্মসাল কতো ?',
#    'জাতির জনক কবে জন্মগ্রহন করেন ?',
#    'মুজিব কবে জন্মেছিলেন ?'],
#   ['শেখ মুজিবুর রহমান কত সালে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেন ?',
#    'বঙ্গবন্ধু কত সালে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেন ?',
#    'বঙ্গবন্ধু কত সালে প্রাতিষ্ঠানিক পড়ালেখা শুরু করেন ?',
#    nan],
#   ['শেখ মুজিবুর রহমান কত বছর বয়সে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেছিলেন ?',
#    'বঙ্গবন্ধু কত বছর বয়সে প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু করেছিলেন?',
#    'কয় বছর বয়সে বঙ্গবন্ধু লেখাপড়া শুরু করেছিলেন ?',
#    'বঙ্গবন্ধু যখন পড়ালেখা শুরু করেন তখন তার বয়স কত ছিল?'],
#   ['শেখ মুজিবুর রহমানের প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু হয় কোন বিদ্যালয় থেকে ?',
#    'বঙ্গবন্ধুর প্রাতিষ্ঠানিক শিক্ষা-জীবন শুরু হয় কোন বিদ্যালয় থেকে ?',
#    'বঙ্গবন্ধুর কোন স্কুল থেকে লেখাপড়া শুরু করেন?',
#    'বঙ্গবন্ধুর কই থেকে লেখাপড়া শুরু করেন?'],
#   ['গিমাডাঙ্গা প্রাথমিক বিদ্যালয় কোথায় অবস্থিত ?',
#    'গিমাডাঙ্গা প্রাথমিক স্কুল কোথায় ?',
#    nan,
#    nan],
#   ['হামিদ মাস্টার কে ছিলেন ?',
#    'কে ছিলেন হামিদ মাস্টার  ?',
#    'হামিদ মাস্টারের পরিচয় কি ?',
#    'হামিদ মাস্টারের সাথে বঙ্গবন্ধুর কি সম্পর্ক? '],
#   ['বঙ্গবন্ধুর গৃহশিক্ষকের নাম কি ছিলো ?',
#    'বঙ্গবন্ধুর লজিং মাস্টারের নাম কি ছিলো ?',
#    nan,
#    nan]],
#  'গোপালগঞ্জ': [['কোন সভায় গিয়ে শেখ মুজিব ইংরেজ শাসনবিরোধী হয়ে ওঠেন ?',
#    'কোন সভায় গিয়ে শেখ মুজিব সুভাষচন্দ্র বসুর একজন ভক্তে পরিণত হন ?',
#    'কোথাকার সভায় গিয়ে শেখ মুজিব সুভাষচন্দ্র বসুর একজন ভক্তে পরিণত হন?',
#    'কোথায় গিয়ে শেখ মুজিব মনে-প্রাণে ইংরেজ শাসনবিরোধী হয়ে ওঠেন ?'],
#   ['কৈশোরে বঙ্গবন্ধু কার ভক্ত ছিলেন ?',
#    'মুজিব কৈশরে কার ভক্তে পরিনত হন ?',
#    nan,
#    nan],
#   ['শেখ মুজিবুর রহমান কত সালে মুসলিম সেবা সমিতির সম্পাদক নিযুক্ত হন ?',
#    'বঙ্গবন্ধু কবে মুসলিম সেবা সমিতির সম্পাদক নিযুক্ত হন ?',
#    'কোন সালে বঙ্গবন্ধুকে মুসলিম সেবা সমিতির সম্পাদক নিযুক্ত করা হয় ?',
#    nan],
#   ['মুসলিম সেবা সমিতির উদ্দেশ্য কি ছিল?',
#    'মুসলিম সেবা সমিতির কি কাজ ছিল?',
#    'মুসলিম সেবা সমিতি কিভাবে অসহায়দের সাহায্য করতো?',
#    nan],
#   ['১৯৩৮ সালে অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    'বঙ্গবন্ধু গোপালগঞ্জ মিশন স্কুলের ছাত্র থাকা অবস্থায় অখণ্ড বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    '১৯৩৮ সালে বাংলার মুখ্যমন্ত্রী কে ছিলেন?',
#    nan],
#   ['১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন বঙ্গবন্ধু কোন স্কুলের ছাত্র ছিলেন?',
#    '১৯৩৮ সালে অখণ্ড বাংলার তৎকালীন মুখ্যমন্ত্রী এ কে ফজলুল হক এবং হোসেন শহীদ সোহরাওয়ার্দী গোপালগঞ্জ সফরে যান তখন শেখ মুজিব কোন স্কুলে পড়তেন?',
#    'শেখ মুজিব কোন স্কুলের ছাত্র ছিলেন?',
#    'শেখ মুজিব কোন স্কুলে পড়তেন?'],
#   ['স্কুলের ছাদ মেরামতের জন্য শেরে বাংলা কত টাকা মঞ্জুর করেন?',
#    'স্কুলের ছাদ মেরামতের জন্য অখণ্ড বাংলার মুখ্যমন্ত্রী কত টাকা মঞ্জুর করেন?',
#    'শেরে বাংলা ছাদ মেরামত করতে কত টাকা দিয়েছিলেন?',
#    nan],
#   ['বঙ্গবন্ধু যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কারা এসেছিলেন?',
#    'শেখ মুজিব যখন গোপালগঞ্জ মিশন স্কুলের ছাত্র তখন স্কুল পরিদর্শনে কোন কোন রাজনৈতিক ব্যক্তিবর্গ এসেছিলেন?',
#    'মুজিবদের স্কুলে কে কে পরিদর্শনে গেছিলেন?',
#    nan],
#   ['কত সালে বঙ্গবন্ধু প্রথম কারাগারে যান?',
#    'কবে শেখ মুজিব প্রথম কারাগারে যান?',
#    'কবে শেখ মুজিব প্রথম জেলবন্দী হন?',
#    nan],
#   ['স্কুলে ছাত্র থাকা অবস্থায় ১৯৩৮ সালে বঙ্গবন্ধুকে কেন কারাগারে যেতে হয়?',
#    'ছাত্রজীবনে কেন শেখ মুজিবকে কারাগারে যেতে হয়?',
#    'ছাত্রাবস্থায় কেন শেখ মুজিবকে কারা ভোগ করতে হয়?',
#    'ছাত্রজীবনে কেন শেখ মুজিবকে জেলে যেতে হয়?'],
#   ['১৯৩৮ সালে বঙ্গবন্ধুকে কতদিন কারাগারে থাকতে হয়?',
#    'ছাত্রজীবনে বঙ্গবন্ধুকে কতদিন কারাগারে থাকতে হয়?',
#    'ছাত্রজীবনে বঙ্গবন্ধুকে কতদিন জেলে থাকতে হয়?',
#    nan],
#   ['গোপালগঞ্জের মিশন হাইস্কুলে পড়াকালে শেখ মুজিবুর রহমান কোন ছাত্র সংগঠনের সদস্য ছিলেন?',
#    'স্কুলে পড়ার সময় শেখ মুজিব কিসের সদস্য ছিলেন?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে স্কুলের কোন কোন সমস্যাগুলো তুলে ধরেন?',
#    'বঙ্গবন্ধু ও তার বন্ধুরা শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে স্কুলের কোন কোন সমস্যাগুলো তুলে ধরেন?',
#    'শেখ মুজিব ও তার বন্ধুরা শেরে বাংলা এবং সোহরাওয়ার্দীর কাছে কি কি দাবি তুলে ধরেন?',
#    nan],
#   ['১৯৩৯ সালে গোপালগঞ্জে বঙ্গবন্ধু কোন সংগঠন প্রতিষ্ঠা করেন?',
#    '১৯৩৯ সালে গোপালগঞ্জে বঙ্গবন্ধু কি প্রতিষ্ঠা করেন?',
#    nan,
#    nan],
#   ['দুর্ভিক্ষের সময় রিলিফের কাজে কোথায় যান শেখ মুজিব?',
#    'দুর্ভিক্ষের সময় বঙ্গবন্ধুকে রিলিফের কাজে কোথায় যেতে হয় ?',
#    'রিলিফের কাজে বঙ্গবন্ধু  কই যান?',
#    nan]],
#  'কলকাতা': [['১৯৩৯ সালে কলকাতায় গিয়ে শেখ মুজিবুর রহমান কার সঙ্গে সাক্ষাৎ করেন ?',
#    'কলকাতায় গিয়ে শেখ মুজিবুর রহমান কার সঙ্গে দেখা করেন ?',
#    'কলকাতায় কার সাথে দেখা করেন শেখ মুজিব?',
#    nan],
#   ['কতো সালে শেখ মুজিব ম্যাট্রিক পাস করেন?',
#    'বঙ্গবন্ধু ম্যাট্রিক পাস করেন কবে ?',
#    'কবে মুজিব এস,এস,সি পাস করেন ?',
#    nan],
#   ['বঙ্গবন্ধু কোথায় থেকে আইএ পড়েন ?',
#    'মুজিব কই থেকে এইচ এস সি পাশ করেন ?',
#    'মুজিব কই থেকে ইন্টার পাশ করেন ?',
#    'বঙ্গবন্ধু কোথায় থেকে আইএ পাশ করেন ?'],
#   ['বঙ্গবন্ধু কোথায় থেকে বিএ পড়েন ?',
#    'বঙ্গবন্ধু কোথায় থেকে বিএ পাশ করেন ?',
#    'জাতির জনক কই থেকে বিএ পাশ করেন ?',
#    'শেখ মুজিব কই থেকে স্নাতক সম্পন্ন করেন?'],
#   ['ইসলামিয়া কলেজের বর্তমান নাম কি ?',
#    'ইসলামিয়া কলেজের বর্তমানে কি নামে পরিচিত ?',
#    'এখন ইসলামিয়া কলেজের কি নাম ?',
#    nan],
#   ['কত সালে শেখ মুজিবুর রহমান মুসলিম লীগের রাজনীতিতে জড়িয়ে পড়েন ?',
#    'মুসলীম লীগে বঙ্গবন্ধু কবে থেকে যোগ দেন ',
#    'কোনসালে মুজিব মুসলীম লীগে যোগ দেন ?',
#    nan],
#   ['কখন প্রথম শেখ মুজিব হোসেন শহীদ সোহরাওয়ার্দীর সংস্পর্শে আসেন ?',
#    'কতসালে বঙ্গবন্ধু সোহরাওয়ার্দীর সংস্পর্শে আসেন ?',
#    'জাতির জনক কবে সোহরাওয়ার্দীর সাথে পরিচিত হন ',
#    'কখন শেখ সাহেব  শহীদ সোহরাওয়ার্দীর সাথে পরিচিত হন '],
#   ['দুর্ভিক্ষের সময় সিভিল সাপ্লাই মন্ত্রী কে ছিলেন?',
#    'পঞ্চাশের মন্বন্তর এর সময় সিভিল সাপ্লাই মন্ত্রী কে ছিলেন?',
#    'ভারতবর্ষে যখন দুর্ভিক্ষ শুরু হয় তখন সিভিল সাপ্লাই মন্ত্রী কে ছিলেন ?',
#    'দুর্ভিক্ষের সময় সিভিল মন্ত্রী কে ছিলেন?'],
#   ['দুর্ভিক্ষের সময় মানুষের প্রাণ বাঁচাতে লঙ্গরখানা খোলার নির্দেশ দেন কে?',
#    'দুর্ভিক্ষের সময়  লঙ্গরখানা খোলার নির্দেশ দেন কে?',
#    'দুর্ভিক্ষের সময়  লঙ্গরখানা খুলতে বলেন  কে?',
#    nan],
#   ['দুর্ভিক্ষের সময় কে কলকাতার অনেকগুলো লঙ্গরখানা তত্ত্বাবধানের দায়িত্ব দেন মুজিবকে?',
#    'কে দুর্ভিক্ষের সময় কলকাতার অধিকাংশ লঙ্গরখানার দায়িত্ব দেন মুজিবকে?',
#    nan,
#    nan]],
#  'ফরিদপুর': [['ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কই সম্পন্ন হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে অনুষ্ঠিত হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলন কার বাড়িতে হয়?'],
#   ['ফরিদপুর ছাত্রলীগের সম্মেলনে কোন কোন বিশিষ্ট ব্যক্তিদের আমন্ত্রণ জানানো হয়?',
#    'ফরিদপুর ছাত্রলীগের সম্মেলনে আমন্ত্রিত বিশিষ্ট ব্যক্তিদের নাম কি ?',
#    'ফরিদপুুর ছাত্রলীগ সম্মেলনে কারা আমন্ত্রিত হয়েছিলেন?',
#    nan],
#   ['শেখ মুজিবকে ঢাকা থেকে কোন জেলে পাঠানো হয়?',
#    'শেখ মুজিবকে কোন জেলে শিফট করা হয়?',
#    nan,
#    nan],
#   ['কবে শেখ মুজিবকে ফরিদপুর জেলে পাঠানো হয়?',
#    'কেন শেখ মুজিবকে ঢাকা থেকে অন্য জেলে পাঠানো হয়?',
#    'শেখ মুজিবকে অন্য জেলে পাঠানো হয় কেন?',
#    nan],
#   ['শেখ মুজিব জেল থেকে চিরকুট এর মাধ্যমে কিসের নির্দেশনা দিয়েছিলেন?',
#    'চিরকুটে শেখ মুজিব কিসের নির্দেশ দিয়েছিলেন?',
#    'চিরকুটে শেখ মুজিব কি লিখেছিলেন?',
#    nan],
#   ['শেখ মুজিব জেল থেকে কাদের কে চিরকুট এর মাধ্যমে ২১ শে ফেব্রুয়ারির আন্দোলনের নির্দেশনা দিয়েছিলেন?',
#    'শেখ মুজিব জেল থেকে কাদের মাধ্যমে ২১ শে ফেব্রুয়ারির আন্দোলনের নির্দেশনা দিয়েছিলেন?',
#    'কাদের মাধ্যমে শেখ মুজিব ভাষা আন্দোলনের নির্দেশনা দিছিলেন?',
#    nan],
#   ['কবে অসুস্থ অবস্থায় মুক্তি দেওয়া হয় বঙ্গবন্ধুকে?', nan, nan, nan]],
#  'ভারতবর্ষ': [['কত সালে পঞ্চাশের মন্বন্তর শুরু হয় ভারতবর্ষে?',
#    'কবে পঞ্চাশের মন্বন্তর শুরু হয় ভারতবর্ষে?',
#    'কবে ভারতবর্ষে দুর্ভিক্ষ শুরু হয়?',
#    'কবে ভারত উপমহাদেশে দুর্ভিক্ষ হয়?']],
#  ' দিল্লী': [['দুর্ভিক্ষের সময় বঙ্গবন্ধু কোন কোন সম্মেলনে যোগ দিয়েছিলেন?',
#    '১৯৪৩ সালে বঙ্গবন্ধু কোন কোন সম্মেলনে যোগ দিয়েছিলেন?',
#    nan,
#    nan]],
#  'ঢাকা বিশ্ববিদ্যালয়ের ফজলুল হক হল': [['কবে শেখ মুজিব ছাত্রলীগ প্রতিষ্ঠা করেন?',
#    'কত সালে বঙ্গবন্ধু ছাত্রলীগ প্রতিষ্ঠা করেন?',
#    'কবে ছাত্রলীগ প্রতিষ্ঠা করা হয়?',
#    nan],
#   ['ছাত্রলীগ কত দফা দাবি করেছিল?',
#    'বঙ্গবন্ধুর নেতৃত্বে প্রতিষ্ঠিত ছাত্রলীগ কয় দফা দাবি পেশ করেছিল?',
#    'ছাত্রলীগ কয় দফা দাবি দিয়েছিল?',
#    nan],
#   ['কোন হলের সম্মেলনে শেখ মুজিব ছাত্রলীগ প্রতিষ্ঠা করার ঘোষণা দেন?',
#    'ঢাকা বিশ্ববিদ্যালয়ের কোন হলে বঙ্গবন্ধু ছাত্রলীগ প্রতিষ্ঠা করেন?',
#    nan,
#    nan]],
#  'ঢাকা বিশ্ববিদ্যালয়': [['কবে সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়?',
#    'কত সালে সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনরায় গঠন করা হয়?',
#    'সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠিত হয়েছিল কবে?',
#    nan],
#   ['সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করার উদ্দেশ্য কি ছিল?',
#    'কোন উদ্দেশ্যকে সামনে রেখে সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়েছিল?',
#    'কি কারণে সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়েছিল?',
#    nan],
#   ['ঢাকা বিশ্ববিদ্যালয়ের কোন হলে সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়?',
#    'কোথায় সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়েছিল?',
#    nan,
#    nan],
#   ['কাদের যৌথ সভায় সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়?',
#    'কোন কোন সংগঠনের যৌথ প্রচেষ্টায় সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়েছিল?',
#    'কাদের চেষ্টায় সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন করা হয়?',
#    nan]],
#  'সচিবালয়': [['ধর্মঘটে সক্রিয় নেতৃত্ব দেওয়ার সময় শেখ মুজিব কই থেকে গ্রেফতার হন?',
#    'ধর্মঘট চলাকালে বঙ্গবন্ধুকে কোন জায়গা থেকে গ্রেফতার করা হয়েছিল?',
#    nan,
#    nan]],
#  'ঢাকা বিশ্ববিদ্যালয়': [['কবে ভাষা আন্দোলনকে বেগবান করার লক্ষ্যে ঢাকা বিশ্ববিদ্যালয়ের বটতলায় এক সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    'কবে ভাষা আন্দোলনকে বেগবান করার লক্ষ্যে বটতলায় সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    nan,
#    nan],
#   ['ভাষা আন্দোলনকে বেগবান করার লক্ষ্যে ঢাকা বিশ্ববিদ্যালয়ের বটতলায় অনুষ্ঠিত সাধারণ ছাত্রসভায় সভাপতিত্ব করেন কে?',
#    'ভাষা আন্দোলনকে সামনে রেখে বটতলায় অনুষ্ঠিত সাধারণ ছাত্রসভায় সভাপতিত্ব করেন কে?',
#    'বটতলার সাধারণ ছাত্রসভায় সভাপতিত্ব করেন কে?',
#    nan],
#   ['সভা শেষে শিক্ষার্থীরা কোন পরিষদের অভিমুখে মিছিল বের করে?',
#    'বটতলার সভা শেষে শিক্ষার্থীরা কোন ভবনের অভিমুখে মিছিল বের করে?',
#    nan,
#    nan],
#   ['১৯৪৮ সালের ১৬ মার্চ ভাষা আন্দোলনকে বেগবান করার লক্ষ্যে কোথায় এক সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    'কোথায় ভাষা আন্দোলনকে সামনে রেখে বঙ্গবন্ধুর সভাপতিত্বে সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    'কোথায় ভাষা আন্দোলনের জন্য  সাধারণ ছাত্রসভা  হয়?',
#    nan],
#   ['কোন উদ্দেশ্যকে সামনে রেখে বটতলায় সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    'কেন বটতলায় সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    'কেন বঙ্গবন্ধুর সভাপতিত্বে বটতলায় সাধারণ ছাত্রসভা অনুষ্ঠিত হয়?',
#    nan],
#   ['কারা পাকিস্তানের গভর্নর জেনারেল মোহাম্মদ আলী জিন্নাহ এর ঘোষণার তীব্র প্রতিবাদ জানায়?',
#    'কারা জিন্নাহ এর উর্দুকে পাকিস্তানের রাষ্ট্র ভাষা করার ঘোষণার প্রতিবাদ করে?',
#    nan,
#    nan],
#   ['কোথায় জিন্নাহ পুনরায় উর্দুকে রাষ্ট্র ভাষা করার ঘোষণা দেয়?',
#    'কই জিন্নাহ পুনরায় উর্দুকে রাষ্ট্র ভাষা করার ঘোষণা দেয়?',
#    nan,
#    nan],
#   ['কত সালে রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশ গুলি চালায়?',
#    'কবে ভাষা আন্দোলন হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে কোথায় প্রতিবাদ মিছিল হয়?',
#    'ভাষা আন্দোলনের জন্য প্রতিবাদ মিছিল কোথায় হয়েছিল?',
#    nan,
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয়ে প্রতিবাদ মিছিল হয়?',
#    '২১ শে ফেব্রুয়ারি কিসের দাবিতে ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    '২১ শে ফেব্রুয়ারি কেন ঢাকা বিশ্ববিদ্যালয় মিছিল করে শিক্ষার্থীরা?',
#    nan],
#   ['১৯৫২ সালের ২১ ফেব্রুয়ারি রাষ্ট্রভাষা বাংলার দাবিতে ঢাকা বিশ্ববিদ্যালয়ের প্রতিবাদ মিছিলে পুলিশের গুলিতে শহীদ হন কারা?',
#    'ভাষা আন্দোলনে কারা শহীদ হন?',
#    'ভাষা আন্দোলনে পুলিশের গুলিতে নিহত হন কারা?',
#    'ভাষা আন্দোলনে পুলিশের গুলি খায় কারা?']],
#  'সোহরাওয়ার্দী উদ্যান ': [['কবে উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন পাকিস্তানের গভর্নর জেনারেল মোহাম্মদ আলী জিন্নাহ?',
#    'কবে উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন পাকিস্তানের গভর্নর ?',
#    'কবে উর্দুকে রাষ্ট্রভাষা  ঘোষণা করেন পাকিস্তানের গভর্নর ?',
#    nan],
#   ['কোথায় উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন পাকিস্তানের গভর্নর জেনারেল মোহাম্মদ আলী জিন্নাহ?',
#    'কোথায় বক্তব্য দিতে গিয়ে জিন্নাহ উর্দুকে পাকিস্তানের রাষ্ট্রভাষা করার ঘোষণা দেয়?',
#    nan,
#    nan],
#   ['১৯৪৮ সালে পাকিস্তানের গভর্নর কে ছিলেন?', ' পাকিস্তানের জনক কে?', nan, nan],
#   ['"উর্দুই হবে পাকিস্তানের একমাত্র রাষ্ট্র ভাষা"- উক্তিটি কার?',
#    '"উর্দুই হবে পাকিস্তানের একমাত্র রাষ্ট্র ভাষা"- উক্তিটি কে দিয়েছিলেন?',
#    nan,
#    nan],
#   ['কবে জিন্নাহ ঢাকা বিশ্বিবদ্যালয়ে পুনরায় উর্দুকে রাষ্ট্র ভাষা করার ঘোষণা করে?',
#    nan,
#    nan,
#    nan],
#   ['কে সোহরাওয়ার্দী উদ্যানে (তৎকালীন রেসকোর্স ময়দানে) বক্তব্য দেওয়ার সময় উর্দুকে একমাত্র রাষ্ট্রভাষা হিসেবে ঘোষণা করেন?',
#    'কে সোহরাওয়ার্দী উদ্যানে উর্দুকে একমাত্র রাষ্ট্রভাষা করার ঘোষণা দেন?',
#    'কে সোহরাওয়ার্দী উদ্যানে উর্দুকে  রাষ্ট্রভাষা করার ঘোষণা দেন?',
#    nan]],
#  'জেলখানা': [["দুনিয়ার বিভিন্ন দেশের মুসলমানরা বিভিন্ন ভাষায় কথা বলে। আরব দেশের লোকেরা আরবি বলে। পারস্যের লোকেরা ফার্সি বলে। তুরস্কের লোকেরা তুর্কি বলে। ইন্দোনেশিয়ার লোকেরা ইন্দোনেশিয়ান ভাষায় কথা বলে। মালয়েশিয়ার লোকেরা মালয় ভাষায় কথা বলে। চীনের মুসলমানরা চীনা ভাষায় কথা বলে। শুধু পূর্ব পাকিস্তানের ধর্মভীরু মুসলমানদের ইসলামের কথা বলে ধোঁকা দেওয়া যাবে বলে ভেবেছিল, কিন্তু পারে নাই।'-উক্তিটি কে দিয়েছিলেন?",
#    nan,
#    nan,
#    nan],
#   ['ভাষা আন্দোলন প্রসঙ্গে বঙ্গবন্ধু কি লিখেছিলেন?',
#    'ভাষা আন্দোলনে পুলিশের গুলি চালানোর নিন্দা জানিয়ে বঙ্গবন্ধু কি লিখেছিলেন?',
#    nan,
#    nan],
#   ["দুনিয়ার বিভিন্ন দেশের মুসলমানরা বিভিন্ন ভাষায় কথা বলে। আরব দেশের লোকেরা আরবি বলে। পারস্যের লোকেরা ফার্সি বলে। তুরস্কের লোকেরা তুর্কি বলে। ইন্দোনেশিয়ার লোকেরা ইন্দোনেশিয়ান ভাষায় কথা বলে। মালয়েশিয়ার লোকেরা মালয় ভাষায় কথা বলে। চীনের মুসলমানরা চীনা ভাষায় কথা বলে। শুধু পূর্ব পাকিস্তানের ধর্মভীরু মুসলমানদের ইসলামের কথা বলে ধোঁকা দেওয়া যাবে বলে ভেবেছিল, কিন্তু পারে নাই।'-উক্তিটি বঙ্গবন্ধু কোন প্রসঙ্গে দিয়েছিলেন?",
#    nan,
#    nan,
#    nan],
#   ['ভাষা আন্দোলনের সময় বঙ্গবন্ধু কই ছিলেন?',
#    'ভাষা আন্দোলনের সময় শেখ মুজিব কোথায় ছিলেন?',
#    nan,
#    nan],
#   ['ভাষা আন্দোলনের সময় পুলিশের গুলি চালানোর ঘটনার নিন্দা জানান কে?',
#    'ভাষা আন্দোলনে পুলিশের গুলি চালানোর নিন্দা জানান কে?',
#    nan,
#    nan],
#   ['ভাষা আন্দোলনের সময় পুলিশের গুলি চালানোর ঘটনার নিন্দা কতদিন অব্যাহত রেখেছিলেন বঙ্গবন্ধু ?',
#    nan,
#    nan,
#    nan]],
#  'ধানমন্ডি': [['কবে বঙ্গবন্ধু শেখ মুজিবুর রহমানকে সপরিবারে হত্যা করা হয়?',
#    'কত সালে বঙ্গবন্ধুকে হত্যা করে?',
#    nan,
#    nan],
#   ['কোন দিনটি বাঙালি জাতির জীবনের এক কলঙ্কময় অধ্যায়?', nan, nan, nan],
#   ['বাংলাদেশের প্রতিষ্ঠাতা কে?', 'বাঙালি জাতির মুক্তিদাতা কে?', nan, nan],
#   ['‘মুজিব হত্যার পর বাঙালিদের আর বিশ্বাস করা যায় না। যারা মুজিবকে হত্যা করেছে তারা যেকোনো জঘন্য কাজ করতে পারে।’-উক্তিটি কার?',
#    "‘মুজিব হত্যার পর বাঙালিদের আর বিশ্বাস করা যায় না।'--উক্তিটি কে করেছিলেন?",
#    nan,
#    nan],
#   ['কারা শেখ মুজিবকে সপরিবারে হত্যা করে?',
#    'কাদের ষড়যন্ত্রে শেখ মুজিবকে হত্যা করা হয়?',
#    'কারা শেখ মুজিবকে হত্যা করে?',
#    nan],
#   ['‘জর্জ ওয়াশিংটন, গান্ধী এবং দ্য ভ্যালেরার থেকেও মহান নেতা ছিলেন শেখ মুজিব।’-উক্তিটি কার?',
#    'কে শেখ মুজিবকে জর্জ অয়াশিংটন, গান্ধী এবং ভ্যালেরার থেকেও মহান নেতা বলেছিলেন?',
#    nan,
#    nan],
#   ['‘মুজিব না থাকলে বাংলাদেশ কখনই জন্ম নিত না।’- সংবাদটি কোন গণমাধ্যমের?',
#    nan,
#    nan,
#    nan],
#   ['বঙ্গবন্ধু হত্যার খবর পেয়ে কোন দেশ শোক দিবস পালন করে?',
#    'শেখ মুজিবকে হত্যার ঘটনায় শোক পালন করে কোন দেশ?',
#    nan,
#    nan],
#   ['বঙ্গবন্ধু হত্যার খবর পেয়ে কোন দেশের মসজিদে বিশেষ দোয়ার আয়োজন হয়?',
#    nan,
#    nan,
#    nan]]}

# %%
q_per_location = dict()

for loc in location_q_dict.keys():
    q_per_location[loc] = len( location_q_dict[loc])
q_per_location
# Out:
# {'missing': 537,
#  'মাদারীপুর': 4,
#  'কুষ্টিয়া': 1,
#  'পূর্ব বাংলা': 47,
#  'পল্টন ময়দান': 9,
#  'করাচী ': 1,
#  'পূর্ব পাকিস্তান': 71,
#  'ধানমন্ডি ৩২ নম্বর সড়ক': 4,
#  'ধানমন্ডি ৩২ নম্বর সড়কের বাসভবন': 5,
#  'পাকিস্তানের লাহোর': 5,
#  'পাকিস্তানের কারাগার': 1,
#  'সোহরাওয়ার্দী উদ্যান': 16,
#  'ঢাকা': 30,
#  'দক্ষিণ আফ্রিকা': 2,
#  'মেহেরপুর': 6,
#  'লন্ডন': 4,
#  'বাংলাদেশ': 10,
#  'ভারত': 1,
#  'আলজেরিয়া': 4,
#  'টুঙ্গিপাড়া': 12,
#  'গোপালগঞ্জ': 15,
#  'কলকাতা': 10,
#  'ফরিদপুর': 7,
#  'ভারতবর্ষ': 1,
#  ' দিল্লী': 1,
#  'ঢাকা বিশ্ববিদ্যালয়ের ফজলুল হক হল': 3,
#  'ঢাকা বিশ্ববিদ্যালয়': 4,
#  'সচিবালয়': 1,
#  'ঢাকা বিশ্ববিদ্যালয়': 11,
#  'সোহরাওয়ার্দী উদ্যান ': 6,
#  'জেলখানা': 6,
#  'ধানমন্ডি': 9}

# %%
a = list(q_per_location.keys())[1:]
b = list(q_per_location.values())[1:]
plot_bar_plot(a,
              b,
              "Location",
              "Questions",
              "Questions per Location",
              show_number=True,
              show_x=True)

# %% [markdown]
# ##  Question by Event

# %%
q1_event_ct = pd.crosstab(df['Q1'],df['Event'])
len(q1_event_ct)
# Out:
# 401

# %%
q1_event_dv = q1_event_ct.describe()
len(q1_event_dv)
# Out:
# 8

# %%
events = q1_event_dv.loc['mean'].index.tolist()

# %%
events
# Out:
# [' ভাষা আন্দোলন',
#  'অপপ্রচার',
#  'আইয়ুব খানের পদত্যাগ',
#  'আওয়ামী লীগ এর পুনরুত্থান',
#  'আওয়ামী লীগ নামকরণ',
#  'আগরতলা ষড়যন্ত্র মামলা',
#  'ইসলামিয়া কলেজ ছাত্র সংসদ',
#  'ঐতিহাসিক ৭ই মার্চের ভাষণ',
#  'কুষ্টিয়ায় নিখিল বঙ্গ মুসলিম ছাত্রলীগের সম্মেলন এবং অল ইন্ডিয়া মুসলিম লীগের সম্মেলন',
#  'গণবিক্ষোভ',
#  'গোপালগঞ্জ মহকুমা মুসলিম লীগ',
#  'ছাত্রজীবন',
#  'ছাত্রলীগের প্রতিষ্ঠা',
#  'ছয় দফা দাবি',
#  'জন্ম',
#  'জলোচ্ছ্বাস',
#  'জাতির জনক উপাধি',
#  'জাতিসংঘে ভাষণ',
#  'জাতীয় ও প্রাদেশিক নির্বাচন',
#  'জাতীয় পরিষদ নির্বাচনে আওয়ামী লীগের জয়',
#  'দুর্ভিক্ষ (পঞ্চাশের মন্বন্তর)',
#  'দেশ পরিচালনা',
#  'নিখিল বঙ্গ মুসলিম ছাত্রলীগ',
#  'পরিবার',
#  'পূর্ব পাকিস্তান আওয়ামী মুসলিম লীগ',
#  'প্রাদেশিক পরিষদ নির্বাচনে আওয়ামী লীগের জয়',
#  'প্রাদেশিক মুসলিম লীগ',
#  'প্রাদেশিক সরকার গঠন',
#  'ফরিদপুর ছাত্রলীগের সম্মেলন',
#  "বঙ্গবন্ধু' উপাধি লাভ",
#  'বঙ্গবন্ধুকে হত্যার নীলনকশা',
#  'বঙ্গবন্ধুর আন্তর্জাতিক স্বীকৃতি',
#  "বাংলাদেশ' নামকরণ",
#  'বাংলাদেশের প্রথম জাতীয় সংসদ নির্বাচন',
#  'ভারত উপমহাদেশ ভাগ',
#  'ভাষা আন্দোলন',
#  'মন্ত্রীসভা ত্যাগ',
#  'মিত্র বাহিনীকে ফেরত পাঠানো',
#  'মুক্তিযুদ্ধে বিজয় লাভ',
#  'মুজিবনগর সরকার গঠন',
#  'মুসলিম সেবা সমিতি',
#  'মুুজিবনগর সরকারের শপথ গ্রহণ',
#  'মৃত্যু',
#  'যুক্তফ্রন্ট গঠন',
#  'যুুক্তফ্রন্ট এর জয় ও সরকার গঠন',
#  'রাজনীতি',
#  'রাষ্ট্র বনাম শেখ মুজিবুর রহমান ও অন্যান্য',
#  'রাষ্ট্রভাষা বাংলার দাবিতে সর্বাত্মক সাধারণ ধর্মঘট',
#  'শপথ গ্রহণ',
#  'শিক্ষা-জীবন',
#  'শেখ মুজিবের কারামুক্তি',
#  'শেখ মুুজিবের স্বদেশ প্রত্যাবর্তন',
#  'ষড়যন্ত্র',
#  'সংসদীয় শাসন ব্যবস্থা চালু',
#  'সর্বদলীয় রাষ্ট্রভাষা সংগ্রাম পরিষদ পুনর্গঠন',
#  'সামরিক শাসন জারি',
#  'সাম্প্রদায়িক দাঙ্গা',
#  'স্বদেশী আন্দোলন',
#  'স্বাধীনতার ঘোষণা নিয়ে আন্তর্জাতিক মিডিয়ার মতামত',
#  'স্বাধীনতার ঘোষণা',
#  '২৫ শে মার্চ (কালরাত)',
#  '৭ই মার্চের ভাষণের আন্তর্জাতিক স্বীকৃতি']

# %%
event_mean_value = q1_event_dv.loc['mean'].tolist()
event_mean_value
# Out:
# [0.014962593516209476,
#  0.00997506234413965,
#  0.0199501246882793,
#  0.029925187032418952,
#  0.02493765586034913,
#  0.022443890274314215,
#  0.004987531172069825,
#  0.0199501246882793,
#  0.0024937655860349127,
#  0.0199501246882793,
#  0.0024937655860349127,
#  0.022443890274314215,
#  0.00997506234413965,
#  0.029925187032418952,
#  0.014962593516209476,
#  0.017456359102244388,
#  0.017456359102244388,
#  0.012468827930174564,
#  0.012468827930174564,
#  0.012468827930174564,
#  0.014962593516209476,
#  0.0199501246882793,
#  0.004987531172069825,
#  0.022443890274314215,
#  0.00997506234413965,
#  0.00997506234413965,
#  0.0024937655860349127,
#  0.00997506234413965,
#  0.004987531172069825,
#  0.012468827930174564,
#  0.007481296758104738,
#  0.0199501246882793,
#  0.00997506234413965,
#  0.017456359102244388,
#  0.007481296758104738,
#  0.09476309226932668,
#  0.0024937655860349127,
#  0.014962593516209476,
#  0.0199501246882793,
#  0.012468827930174564,
#  0.004987531172069825,
#  0.014962593516209476,
#  0.022443890274314215,
#  0.029925187032418952,
#  0.03740648379052369,
#  0.017456359102244388,
#  0.014962593516209476,
#  0.017456359102244388,
#  0.007481296758104738,
#  0.00997506234413965,
#  0.00997506234413965,
#  0.00997506234413965,
#  0.014962593516209476,
#  0.007481296758104738,
#  0.00997506234413965,
#  0.012468827930174564,
#  0.017456359102244388,
#  0.029925187032418952,
#  0.017456359102244388,
#  0.014962593516209476,
#  0.017456359102244388,
#  0.0199501246882793]

# %%
q_per_event = [i * len(q1_event_ct) for i in event_mean_value]

# %%
plot_bar_plot(events,q_per_event,"Events","# Ques / Event ",
              "Event vs # Question",True,show_x=True)

# %% [markdown]
# ## Questions by Year

# %%
q1_year_ct = pd.crosstab(df['Q1'],df['Year'])
len(q1_year_ct)
# Out:
# 408

# %%
q1_year_dv = q1_year_ct.describe()
len(q1_year_dv)
# Out:
# 8

# %%
years = q1_year_dv.loc['mean'].index.tolist()

# %%
years
# Out:
# [1920.0,
#  1924.0,
#  1927.0,
#  1936.0,
#  1937.0,
#  1938.0,
#  1939.0,
#  1940.0,
#  1942.0,
#  1943.0,
#  1946.0,
#  1947.0,
#  1948.0,
#  1949.0,
#  1952.0,
#  1953.0,
#  1954.0,
#  1955.0,
#  1956.0,
#  1958.0,
#  1963.0,
#  1964.0,
#  1966.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0]

# %%
year_mean_value = q1_year_dv.loc['mean'].tolist()
year_mean_value
# Out:
# [0.014705882352941176,
#  0.004901960784313725,
#  0.00980392156862745,
#  0.024509803921568627,
#  0.004901960784313725,
#  0.04411764705882353,
#  0.012254901960784314,
#  0.00980392156862745,
#  0.014705882352941176,
#  0.0196078431372549,
#  0.031862745098039214,
#  0.03431372549019608,
#  0.08088235294117647,
#  0.03431372549019608,
#  0.03676470588235294,
#  0.029411764705882353,
#  0.03676470588235294,
#  0.024509803921568627,
#  0.012254901960784314,
#  0.012254901960784314,
#  0.0024509803921568627,
#  0.029411764705882353,
#  0.029411764705882353,
#  0.022058823529411766,
#  0.051470588235294115,
#  0.05392156862745098,
#  0.18382352941176472,
#  0.06862745098039216,
#  0.031862745098039214,
#  0.012254901960784314,
#  0.022058823529411766]

# %%
q_per_year = [i * len(q1_year_ct) for i in year_mean_value]

# %%
plot_bar_plot(years,q_per_year,"Years","# Ques / Year ",
              "Year vs # Question",True,show_x=True,figsize=(26,10))

# %% [markdown]
# ## Questions per Tags

# %%
t1 = list(df.T1.unique())
t1
# Out:
# [nan,
#  'যুক্তফ্রন্ট',
#  'ইতিহাস',
#  'রাজনীতি',
#  ' দেশ পরিচালনা',
#  'পরিচিতি তথ্য',
#  'শিক্ষা-জীবন',
#  ' আন্দোলন',
#  'কৈশোর',
#  'ছাত্রজীবন',
#  'মানবসেবা',
#  'ভাষা আন্দোলন',
#  ' ভাষা আন্দোলন',
#  'দেশ পরিচালনা']

# %%
t2 = list(df.T2.unique())
t2
# Out:
# ['ইতিহাস',
#  'পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ যোগদান',
#  'রাজনীতিতে অণুপ্রবেশ',
#  'রাজনীতি',
#  'ষড়যন্ত্র',
#  ' ষড়যন্ত্র',
#  nan,
#  ' ব্যাক্তিগত',
#  'পড়ালেখা',
#  'কৈশোর',
#  ' মানবসেবা',
#  ' ইতিহাস',
#  'ছাত্র রাজনীতি',
#  'পড়াশোনা',
#  ' মুসলিম লীগ',
#  'ব্যাক্তিগত']

# %%
tags = []

tags.extend(t1)
tags.extend(t2)

len(tags), len(t2)
# Out:
# (30, 16)

# %%
c_tags = []

for i in tags:
    if i not in c_tags:
        c_tags.append(i)

len(c_tags), len(tags)
# Out:
# (26, 30)

# %%
tags_q_dict = dict()

for i in c_tags:
    if type(i) != str:
        text = "tags_q_dict['missing'] = []"
        exec(text)
    else:
        text = "tags_q_dict['"+i+"'] = []"
        exec(text)

# %%
tags_q_dict
# Out:
# {'missing': [],
#  'যুক্তফ্রন্ট': [],
#  'ইতিহাস': [],
#  'রাজনীতি': [],
#  ' দেশ পরিচালনা': [],
#  'পরিচিতি তথ্য': [],
#  'শিক্ষা-জীবন': [],
#  ' আন্দোলন': [],
#  'কৈশোর': [],
#  'ছাত্রজীবন': [],
#  'মানবসেবা': [],
#  'ভাষা আন্দোলন': [],
#  ' ভাষা আন্দোলন': [],
#  'দেশ পরিচালনা': [],
#  'পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ যোগদান': [],
#  'রাজনীতিতে অণুপ্রবেশ': [],
#  'ষড়যন্ত্র': [],
#  ' ষড়যন্ত্র': [],
#  ' ব্যাক্তিগত': [],
#  'পড়ালেখা': [],
#  ' মানবসেবা': [],
#  ' ইতিহাস': [],
#  'ছাত্র রাজনীতি': [],
#  'পড়াশোনা': [],
#  ' মুসলিম লীগ': [],
#  'ব্যাক্তিগত': []}

# %%
for tag in tags_q_dict.keys():
    for item in data:
        for  qas in  item['qas']:
            for t in qas['tags']:
                if type(t) != str:
                    t = "missing"
                    # continue
                if t == tag:
                    tags_q_dict[tag].append(qas['qtns'])

# %%
q_per_tags = dict()

for tag in tags_q_dict.keys():
    if tag == 'missing':
        continue
    q_per_tags[tag] = len( tags_q_dict[tag])
q_per_tags
# Out:
# {'যুক্তফ্রন্ট': 15,
#  'ইতিহাস': 294,
#  'রাজনীতি': 226,
#  ' দেশ পরিচালনা': 9,
#  'পরিচিতি তথ্য': 15,
#  'শিক্ষা-জীবন': 4,
#  ' আন্দোলন': 3,
#  'কৈশোর': 5,
#  'ছাত্রজীবন': 10,
#  'মানবসেবা': 4,
#  'ভাষা আন্দোলন': 3,
#  ' ভাষা আন্দোলন': 40,
#  'দেশ পরিচালনা': 8,
#  'পূর্বপাকিস্তান আওয়ামী মুসলিম লীগ যোগদান': 1,
#  'রাজনীতিতে অণুপ্রবেশ': 1,
#  'ষড়যন্ত্র': 4,
#  ' ষড়যন্ত্র': 6,
#  ' ব্যাক্তিগত': 6,
#  'পড়ালেখা': 4,
#  ' মানবসেবা': 2,
#  ' ইতিহাস': 15,
#  'ছাত্র রাজনীতি': 4,
#  'পড়াশোনা': 4,
#  ' মুসলিম লীগ': 2,
#  'ব্যাক্তিগত': 9}

# %%
a = list(q_per_tags.keys())
b = list(q_per_tags.values())
plot_bar_plot(a,
              b,
              "Tags",
              "Questions",
              "Questions per Tag",
              show_number=True,
              show_x=True)
